# %% [markdown]
# # Week 11: Working with Web APIs #
#
# ## Task Summary: ##
# The requirement for this assignment is to choose to work on New York Times (NYT) API and create an interface in Python that will allow you to access the dataset and then transform it as Pandas data frame in Python.
#
# ### Pre-coding Steps: ###
# 1. Created an account in New York Times (NYT) developer website.
# 2. Choose an app (in this case, all apps were chosen) to be able to get an API key. API key is important and is used as authentication key to be able to access the different datasets.
# 3. Try previewing some of the dataset using the API key to understand the data.

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# ### Steps to Complete Task: ###
# (Same steps were followed for all datasets)
#
# 1. Use the **requests** library and call the **get** method to open and access the URL NYT web API interface.
# 2. Transform data into a more readable json data.
# 3. Study the json data and find where the actual data begins. Extract this information.
# 4. Transform extracted json data into a Pandas data frame.
#
# **Note:** Some datasets involve some kind of a parent-child relationships. In this scenario, only the parent data table was created since the requirement was only to transform data as Pandas data frame. If an analyst would really want to analyze a certain dataset given in this task, he/she will need to create additional child tables and later on join these tables to have one whole clean dataset to analyze.

# %% [markdown]
# #### Dataset 1: ####
# This dataset came from the NYT top stories from the movies section (and those that where also tagged as movies).

# %%
#use requests library and call get method to access URL and open the API
movie_reviews = requests.get('https://api.nytimes.com/svc/topstories/v2/movies.json?api-key=GsQu4h8IDfExzCiiJWehGDgRPEQ9Ajka')
print(movie_reviews.text)
# Out:
# {"status":"OK","copyright":"Copyright (c) 2019 The New York Times Company. All Rights Reserved.","section":"movies","last_updated":"2019-04-06T22:27:16-04:00","num_results":32,"results":[{"section":"Movies","subsection":"","title":"\u2018Shazam!\u2019 Review: A Boy\u2019s Supersized Alter Ego in a Sunny Superhero Flick","abstract":"A nicely matched Asher Angel and Zachary Levi together play a superhero who has been taken out of mothballs with humor and fine performances.","url":"https:\/\/www.nytimes.com\/2019\/04\/03\/movies\/shazam-review.html","byline":"By MANOHLA DARGIS","item_type":"Article","updated_date":"2019-04-05T10:32:45-04:00","created_date":"2019-04-03T17:47:11-04:00","published_date":"2019-04-03T17:47:11-04:00","material_type_facet":"","kicker":"","des_facet":["Movies","Shazam! (Movie)"],"org_facet":[],"per_facet":["Sandberg, David F","Gayden, Henry","Levi, Zachary","Hounsou, Djimon","Angel, Asher (2002- )"],"geo_facet":[],"multimedia":[{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/05\/arts\/04shazam-1\/00shazam-1-thumbStandard.jpg","format":"Standard Thumbnail","height":75,"width":75,"type":"image","subtype":"photo","caption":"Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.","copyright":"Steve Wilkie\/Warner Bros. Pictures"},{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/05\/arts\/04shazam-1\/00shazam-1-thumbLarge.jpg","format":"thumbLarge","height":150,"width":150,"type":"image","subtype":"photo","caption":"Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.","copyright":"Steve Wilkie\/Warner Bros. Pictures"},{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/05\/arts\/04shazam-1\/merlin_152839509_708fbe71-6887-41c5-9433-85e9c625f0b3-articleInline.jpg","format":"Normal","height":107,"width":190,"type":"image","subtype":"photo","caption":"Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.","copyright":"Steve Wilkie\/Warner Bros. Pictures"},{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/05\/arts\/04shazam-1\/00shazam-1-mediumThreeByTwo210.jpg","format":"mediumThreeByTwo210","height":140,"width":210,"type":"image","subtype":"photo","caption":"Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.","copyright":"Steve Wilkie\/Warner Bros. Pictures"},{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/05\/arts\/04shazam-1\/merlin_152839509_708fbe71-6887-41c5-9433-85e9c625f0b3-superJumbo.jpg","format":"superJumbo","height":1098,"width":1952,"type":"image","subtype":"photo","caption":"Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.","copyright":"Steve Wilkie\/Warner Bros. Pictures"}],"short_url":"https:\/\/nyti.ms\/2OMshsX"},{"section":"Movies","subsection":"","title":"\u2018Pet Sematary\u2019 Review: An Unsettling New Take on a Stephen King Classic","abstract":"This one has a smoother feel than the 1989 movie, our critic writes. But despite some great jolts, it\u2019s an uneven horror film.","url":"https:\/\/www.nytimes.com\/2019\/04\/04\/movies\/pet-sematary-review.html","byline":"By GLENN KENNY","item_type":"Article","updated_date":"2019-04-04T13:17:17-04:00","created_date":"2019-04-04T10:11:31-04:00","published_date":"2019-04-04T10:11:31-04:00","material_type_facet":"","kicker":"","des_facet":["Movies","Pet Sematary (Movie)"],"org_facet":[],"per_facet":["King, Stephen","Widmyer, Dennis","Kolsch, Kevin"],"geo_facet":[],"multimedia":[{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/05\/arts\/04petsematary\/04petsematary-thumbStandard.jpg","format":"Standard Thumbnail","height":75,"width":75,"type":"image","subtype":"photo","caption":"Jet&eacute; Laurence and the family cat in &ldquo;Pet Sematary.&rdquo;","copyright":"Kerry Hayes\/Paramount Pictures."},{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/05\/arts\/04petsemat ...

# %%
#translates data into a readable json file
movie = movie_reviews.json()
movie
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'section': 'movies',
#  'last_updated': '2019-04-06T22:27:16-04:00',
#  'num_results': 32,
#  'results': [{'section': 'Movies',
#    'subsection': '',
#    'title': '‘Shazam!’ Review: A Boy’s Supersized Alter Ego in a Sunny Superhero Flick',
#    'abstract': 'A nicely matched Asher Angel and Zachary Levi together play a superhero who has been taken out of mothballs with humor and fine performances.',
#    'url': 'https://www.nytimes.com/2019/04/03/movies/shazam-review.html',
#    'byline': 'By MANOHLA DARGIS',
#    'item_type': 'Article',
#    'updated_date': '2019-04-05T10:32:45-04:00',
#    'created_date': '2019-04-03T17:47:11-04:00',
#    'published_date': '2019-04-03T17:47:11-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies', 'Shazam! (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Sandberg, David F',
#     'Gayden, Henry',
#     'Levi, Zachary',
#     'Hounsou, Djimon',
#     'Angel, Asher (2002- )'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/04shazam-1/00shazam-1-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.',
#      'copyright': 'Steve Wilkie/Warner Bros. Pictures'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04shazam-1/00shazam-1-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.',
#      'copyright': 'Steve Wilkie/Warner Bros. Pictures'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04shazam-1/merlin_152839509_708fbe71-6887-41c5-9433-85e9c625f0b3-articleInline.jpg',
#      'format': 'Normal',
#      'height': 107,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.',
#      'copyright': 'Steve Wilkie/Warner Bros. Pictures'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04shazam-1/00shazam-1-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.',
#      'copyright': 'Steve Wilkie/Warner Bros. Pictures'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04shazam-1/merlin_152839509_708fbe71-6887-41c5-9433-85e9c625f0b3-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1098,
#      'width': 1952,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.',
#      'copyright': 'Steve Wilkie/Warner Bros. Pictures'}],
#    'short_url': 'https://nyti.ms/2OMshsX'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': '‘Pet Sematary’ Review: An Unsettling New Take on a Stephen King Classic',
#    'abstract': 'This one has a smoother feel than the 1989 movie, our critic writes. But despite some great jolts, it’s an uneven horror film.',
#    'url': 'https://www.nytimes.com/2019/04/04/movies/pet-sematary-review.html',
#    'byline': 'By GLENN KENNY',
#    'item_type': 'Article',
#    'updated_date': '2019-04-04T13:17:17-04:00',
#    'created_date': '2019-04-04T10:11:31-04:00',
#    'published_date': '2019-04-04T10:11:31-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies', 'Pet Sematary (Movie)'],
#    'org_facet': [],
#    'per_facet': ['King, Stephen', 'Widmyer, Dennis', 'Kolsch, Kevin'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/04petsematary/04petsematary-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jet&eacute; Laurence and the family cat in &ldquo;Pet Sematary.&rdquo;',
#      'copyright': 'Kerry Hayes/Paramount Pictures.'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04petsematary/04petsematary-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jet&eacute; Laurence and the family cat in &ldquo;Pet Sematary.&rdquo;',
#      'copyright': 'Kerry Hayes/Paramount Pictures.'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04petsematary/merlin_152839077_35d29315-7167-4e58-a7ea-6f0dae1f7934-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jet&eacute; Laurence and the family cat in &ldquo;Pet Sematary.&rdquo;',
#      'copyright': 'Kerry Hayes/Paramount Pictures.'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04petsematary/04petsematary-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jet&eacute; Laurence and the family cat in &ldquo;Pet Sematary.&rdquo;',
#      'copyright': 'Kerry Hayes/Paramount Pictures.'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04petsematary/merlin_152839077_35d29315-7167-4e58-a7ea-6f0dae1f7934-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1366,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jet&eacute; Laurence and the family cat in &ldquo;Pet Sematary.&rdquo;',
#      'copyright': 'Kerry Hayes/Paramount Pictures.'}],
#    'short_url': 'https://nyti.ms/2K7506o'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': 'The Agnès Varda I Knew: Showing Women Their Real Place in Movies',
#    'abstract': 'In encounters over the years, our critic met a filmmaker with an acute sense of the oppressed and of her standing in the French New Wave.',
#    'url': 'https://www.nytimes.com/2019/04/02/movies/agnes-varda-memory.html',
#    'byline': 'By MANOHLA DARGIS',
#    'item_type': 'Article',
#    'updated_date': '2019-04-03T10:14:35-04:00',
#    'created_date': '2019-04-02T14:51:25-04:00',
#    'published_date': '2019-04-02T14:51:25-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies',
#     'Women and Girls',
#     'Vagabond (Movie)',
#     'The Beaches of Agnes (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Varda, Agnes'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/arts/7Agnes-1/7Agnes-1-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Agn&egrave;s Varda at work on &ldquo;Cl&eacute;o From 5 to 7,&rdquo; released in 1962.',
#      'copyright': 'Roger Viollet/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/7Agnes-1/7Agnes-1-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Agn&egrave;s Varda at work on &ldquo;Cl&eacute;o From 5 to 7,&rdquo; released in 1962.',
#      'copyright': 'Roger Viollet/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/7Agnes-1/merlin_152797479_48bbaef7-e61c-4436-a2ea-cfc6ca9a43d6-articleInline.jpg',
#      'format': 'Normal',
#      'height': 195,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Agn&egrave;s Varda at work on &ldquo;Cl&eacute;o From 5 to 7,&rdquo; released in 1962.',
#      'copyright': 'Roger Viollet/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/7Agnes-1/7Agnes-1-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Agn&egrave;s Varda at work on &ldquo;Cl&eacute;o From 5 to 7,&rdquo; released in 1962.',
#      'copyright': 'Roger Viollet/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/7Agnes-1/merlin_152797479_48bbaef7-e61c-4436-a2ea-cfc6ca9a43d6-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 2048,
#      'width': 2001,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Agn&egrave;s Varda at work on &ldquo;Cl&eacute;o From 5 to 7,&rdquo; released in 1962.',
#      'copyright': 'Roger Viollet/Getty Images'}],
#    'short_url': 'https://nyti.ms/2Uo7KQO'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': '‘The Best of Enemies’ Review: A Klansman and a Civil Rights Activist Become Friends',
#    'abstract': 'Taraji P. Henson and Sam Rockwell star in a clumsy drama of racial reconciliation. It’s based on a true story.',
#    'url': 'https://www.nytimes.com/2019/04/03/movies/the-best-of-enemies-review.html',
#    'byline': 'By A.O. SCOTT',
#    'item_type': 'Article',
#    'updated_date': '2019-04-04T09:43:05-04:00',
#    'created_date': '2019-04-03T15:01:59-04:00',
#    'published_date': '2019-04-03T15:01:59-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies', 'The Best of Enemies (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Bissell, Robin (1968- )',
#     'Henson, Taraji P',
#     'Rockwell, Sam',
#     'Bentley, Wes',
#     'Heche, Anne'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/03bestofenemies/03bestofenemies-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'From left, Sam Rockwell, Babou Ceesay and Taraji P. Henson in &ldquo;The Best of Enemies,&rdquo; a story of race and reconciliation.',
#      'copyright': 'Annette Brown/STXfilms'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/03bestofenemies/03bestofenemies-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'From left, Sam Rockwell, Babou Ceesay and Taraji P. Henson in &ldquo;The Best of Enemies,&rdquo; a story of race and reconciliation.',
#      'copyright': 'Annette Brown/STXfilms'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/03bestofenemies/03bestofenemies-articleInline.jpg',
#      'format': 'Normal',
#      'height': 145,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'From left, Sam Rockwell, Babou Ceesay and Taraji P. Henson in &ldquo;The Best of Enemies,&rdquo; a story of race and reconciliation.',
#      'copyright': 'Annette Brown/STXfilms'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/03bestofenemies/03bestofenemies-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'From left, Sam Rockwell, Babou Ceesay and Taraji P. Henson in &ldquo;The Best of Enemies,&rdquo; a story of race and reconciliation.',
#      'copyright': 'Annette Brown/STXfilms'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/03bestofenemies/03bestofenemies-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1565,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'From left, Sam Rockwell, Babou Ceesay and Taraji P. Henson in &ldquo;The Best of Enemies,&rdquo; a story of race and reconciliation.',
#      'copyright': 'Annette Brown/STXfilms'}],
#    'short_url': 'https://nyti.ms/2UuUYji'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': 'Watch a Boy Discover His Superpowers in ‘Shazam!’',
#    'abstract': 'The director David F. Sandberg discusses a scene featuring Zachary Levi and Jack Dylan Grazer.',
#    'url': 'https://www.nytimes.com/2019/04/05/movies/shazam-scene.html',
#    'byline': 'By MEKADO MURPHY',
#    'item_type': 'Article',
#    'updated_date': '2019-04-05T17:38:34-04:00',
#    'created_date': '2019-04-05T07:02:01-04:00',
#    'published_date': '2019-04-05T07:02:01-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies', 'Shazam! (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Levi, Zachary', 'Sandberg, David F'],
#    'geo_facet': [],
#    'multimedia': [],
#    'short_url': 'https://nyti.ms/2CYgyTf'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': '‘High Life’ Review: Robert Pattinson Is Lost in Space',
#    'abstract': 'The director Claire Denis fills her science-fiction fantasy with drift, fluids and beautiful people, including Juliette Binoche and André Benjamin.',
#    'url': 'https://www.nytimes.com/2019/04/04/movies/high-life-review.html',
#    'byline': 'By MANOHLA DARGIS',
#    'item_type': 'Article',
#    'updated_date': '2019-04-04T12:27:22-04:00',
#    'created_date': '2019-04-04T12:27:22-04:00',
#    'published_date': '2019-04-04T12:27:22-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies', 'High Life (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Denis, Claire',
#     'Pattinson, Robert',
#     'Binoche, Juliette',
#     'Benjamin, Andre (Andre 3000)'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/04highlife/04highlife-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jessie Ross and Robert Pattinson in &ldquo;High Life,&rdquo; a new science-fiction movie from Claire Denis.',
#      'copyright': 'A24'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04highlife/04highlife-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jessie Ross and Robert Pattinson in &ldquo;High Life,&rdquo; a new science-fiction movie from Claire Denis.',
#      'copyright': 'A24'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04highlife/merlin_152838792_e9c6dee7-0377-415c-b58f-ec4ed9650156-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jessie Ross and Robert Pattinson in &ldquo;High Life,&rdquo; a new science-fiction movie from Claire Denis.',
#      'copyright': 'A24'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04highlife/merlin_152838792_e9c6dee7-0377-415c-b58f-ec4ed9650156-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jessie Ross and Robert Pattinson in &ldquo;High Life,&rdquo; a new science-fiction movie from Claire Denis.',
#      'copyright': 'A24'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04highlife/merlin_152838792_e9c6dee7-0377-415c-b58f-ec4ed9650156-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1067,
#      'width': 1600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jessie Ross and Robert Pattinson in &ldquo;High Life,&rdquo; a new science-fiction movie from Claire Denis.',
#      'copyright': 'A24'}],
#    'short_url': 'https://nyti.ms/2WJ2tAD'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': '‘Amazing Grace’ Review: Aretha Franklin Is Glorious in a Rousing Concert Film',
#    'abstract': 'The film Aretha Franklin didn’t want you to see arrives in theaters. It captures an incandescent Queen of Soul recording her 1972 live album.',
#    'url': 'https://www.nytimes.com/2018/12/05/movies/amazing-grace-review.html',
#    'byline': 'By WESLEY MORRIS',
#    'item_type': 'Article',
#    'updated_date': '2018-12-05T20:17:11-05:00',
#    'created_date': '2018-12-05T20:17:11-05:00',
#    'published_date': '2018-12-05T20:17:11-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Documentary Films and Programs',
#     'Amazing Grace (2018) (Movie)',
#     'Blacks',
#     'Gospel Music',
#     'Music'],
#    'org_facet': [],
#    'per_facet': ['Franklin, Aretha', 'Pollack, Sydney'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2018/12/07/arts/07AMAZINGGRACE-1/07AMAZINGGRACE-1-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Aretha Franklin in the 1972 documentary “Amazing Grace.”',
#      'copyright': 'Amazing Grace Film, LLC'},
#     {'url': 'https://static01.nyt.com/images/2018/12/07/arts/07AMAZINGGRACE-1/07AMAZINGGRACE-1-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Aretha Franklin in the 1972 documentary “Amazing Grace.”',
#      'copyright': 'Amazing Grace Film, LLC'},
#     {'url': 'https://static01.nyt.com/images/2018/12/07/arts/07AMAZINGGRACE-1/07AMAZINGGRACE-1-articleInline.jpg',
#      'format': 'Normal',
#      'height': 109,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Aretha Franklin in the 1972 documentary “Amazing Grace.”',
#      'copyright': 'Amazing Grace Film, LLC'},
#     {'url': 'https://static01.nyt.com/images/2018/12/07/arts/07AMAZINGGRACE-1/07AMAZINGGRACE-1-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Aretha Franklin in the 1972 documentary “Amazing Grace.”',
#      'copyright': 'Amazing Grace Film, LLC'},
#     {'url': 'https://static01.nyt.com/images/2018/12/07/arts/07AMAZINGGRACE-1/07AMAZINGGRACE-1-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1080,
#      'width': 1874,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Aretha Franklin in the 1972 documentary “Amazing Grace.”',
#      'copyright': 'Amazing Grace Film, LLC'}],
#    'short_url': 'https://nyti.ms/2zJrRxh'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': 'Shazam Is Back. Wait, Who Is He Again?',
#    'abstract': 'Although many viewers may be unfamiliar with the character, he is one of the most important superheroes in comic history, dating back to 1939.',
#    'url': 'https://www.nytimes.com/2019/04/05/movies/shazam-history-captain-marvel.html',
#    'byline': 'By DEVIN FULLER',
#    'item_type': 'Article',
#    'updated_date': '2019-04-05T11:00:01-04:00',
#    'created_date': '2019-04-05T11:00:01-04:00',
#    'published_date': '2019-04-05T11:00:01-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Comic Books and Strips', 'Movies', 'Shazam! (Movie)'],
#    'org_facet': ['DC Comics', 'Republic Pictures', 'Marvel Comics'],
#    'per_facet': ['Johns, Geoff'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/14/arts/14SHAZAM-1/14SHAZAM-1-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Zachary Levi, left, and Jack Dylan Grazer in a scene from “Shazam!”',
#      'copyright': 'Steve Wilkie/Warner Bros. Entertainment'},
#     {'url': 'https://static01.nyt.com/images/2019/04/14/arts/14SHAZAM-1/14SHAZAM-1-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Zachary Levi, left, and Jack Dylan Grazer in a scene from “Shazam!”',
#      'copyright': 'Steve Wilkie/Warner Bros. Entertainment'},
#     {'url': 'https://static01.nyt.com/images/2019/04/14/arts/14SHAZAM-1/merlin_152399808_7eaefa8c-f7cc-4bfa-9b50-dee3c187fbfb-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Zachary Levi, left, and Jack Dylan Grazer in a scene from “Shazam!”',
#      'copyright': 'Steve Wilkie/Warner Bros. Entertainment'},
#     {'url': 'https://static01.nyt.com/images/2019/04/14/arts/14SHAZAM-1/merlin_152399808_7eaefa8c-f7cc-4bfa-9b50-dee3c187fbfb-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Zachary Levi, left, and Jack Dylan Grazer in a scene from “Shazam!”',
#      'copyright': 'Steve Wilkie/Warner Bros. Entertainment'},
#     {'url': 'https://static01.nyt.com/images/2019/04/14/arts/14SHAZAM-1/merlin_152399808_7eaefa8c-f7cc-4bfa-9b50-dee3c187fbfb-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Zachary Levi, left, and Jack Dylan Grazer in a scene from “Shazam!”',
#      'copyright': 'Steve Wilkie/Warner Bros. Entertainment'}],
#    'short_url': 'https://nyti.ms/2TZM6xQ'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': 'It May Be the Most Cursed Film Ever. These 5 Crew Members Saw It Through.',
#    'abstract': 'Terry Gilliam’s “The Man Who Killed Don Quixote” is reaching screens after 30 years, several cast changes and a flash flood. Those who were there at the start look back.',
#    'url': 'https://www.nytimes.com/2019/04/04/movies/terry-gilliam-don-quixote.html',
#    'byline': 'By SOPAN DEB',
#    'item_type': 'Article',
#    'updated_date': '2019-04-04T10:00:09-04:00',
#    'created_date': '2019-04-04T10:00:09-04:00',
#    'published_date': '2019-04-04T10:00:09-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies',
#     'The Man Who Killed Don Quixote (Movie)',
#     'Cannes International Film Festival'],
#    'org_facet': [],
#    'per_facet': ['Gilliam, Terry', 'Driver, Adam'],
#    'geo_facet': ['Spain'],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/arts/07quixote-veterans-promo/07QUIXOTE-promo-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Tom Jamieson for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07quixote-veterans-promo/07QUIXOTE-promo-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Tom Jamieson for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07quixote-veterans-promo/merlin_152467806_01484a2f-ed31-48ca-a2e8-b0bb785e0b1d-articleInline.jpg',
#      'format': 'Normal',
#      'height': 136,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Tom Jamieson for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07quixote-veterans-promo/07QUIXOTE-promo-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Tom Jamieson for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07quixote-veterans-promo/merlin_152467806_01484a2f-ed31-48ca-a2e8-b0bb785e0b1d-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1463,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Tom Jamieson for The New York Times'}],
#    'short_url': 'https://nyti.ms/2K6qNLz'},
#   {'section': 'Style',
#    'subsection': '',
#    'title': 'Hot Topic Is Still Hot',
#    'abstract': 'How has an enclave for emo kids and mall goths resisted the retail apocalypse? With merch.',
#    'url': 'https://www.nytimes.com/2019/04/06/style/hot-topic-stores.html',
#    'byline': 'By PAULA MEJÍA',
#    'item_type': 'Article',
#    'updated_date': '2019-04-06T06:00:02-04:00',
#    'created_date': '2019-04-06T06:00:01-04:00',
#    'published_date': '2019-04-06T06:00:01-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Shopping and Retail'],
#    'org_facet': ['Hot Topic'],
#    'per_facet': [],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/04/fashion/04HOTTOPIC1/04HOTTOPIC1-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'T-shirts on display at the Westfield Garden State Plaza shopping center’s Hot Topic. The store, now in its 30th year, has become a haven for merchandise tied to a wide range of fandoms.',
#      'copyright': "Pat O'Malley for The New York Times"},
#     {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/04HOTTOPIC1/04HOTTOPIC1-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'T-shirts on display at the Westfield Garden State Plaza shopping center’s Hot Topic. The store, now in its 30th year, has become a haven for merchandise tied to a wide range of fandoms.',
#      'copyright': "Pat O'Malley for The New York Times"},
#     {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/04HOTTOPIC1/merlin_152972241_37cb430e-8686-4ce9-b113-688e9019ef16-articleInline.jpg',
#      'format': 'Normal',
#      'height': 136,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'T-shirts on display at the Westfield Garden State Plaza shopping center’s Hot Topic. The store, now in its 30th year, has become a haven for merchandise tied to a wide range of fandoms.',
#      'copyright': "Pat O'Malley for The New York Times"},
#     {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/04HOTTOPIC1/04HOTTOPIC1-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'T-shirts on display at the Westfield Garden State Plaza shopping center’s Hot Topic. The store, now in its 30th year, has become a haven for merchandise tied to a wide range of fandoms.',
#      'copyright': "Pat O'Malley for The New York Times"},
#     {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/04HOTTOPIC1/merlin_152972241_37cb430e-8686-4ce9-b113-688e9019ef16-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1463,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'T-shirts on display at the Westfield Garden State Plaza shopping center’s Hot Topic. The store, now in its 30th year, has become a haven for merchandise tied to a wide range of fandoms.',
#      'copyright': "Pat O'Malley for The New York Times"}],
#    'short_url': 'https://nyti.ms/2IfXdQZ'},
#   {'section': 'Arts',
#    'subsection': '',
#    'title': 'The Week in Arts: The Criterion Channel, Charlotte Gainsbourg and ‘Queens of Mystery’',
#    'abstract': 'A classic movie streaming service arrives; a singer tours in Brooklyn; and Acorn TV debuts a new series.',
#    'url': 'https://www.nytimes.com/2019/04/06/arts/the-week-in-arts-the-criterion-channel-charlotte-gainsbourg-and-queens-of-mystery.html',
#    'byline': 'By THE NEW YORK TIMES',
#    'item_type': 'Article',
#    'updated_date': '2019-04-06T02:00:06-04:00',
#    'created_date': '2019-04-06T02:00:06-04:00',
#    'published_date': '2019-04-06T02:00:06-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Culture (Arts)',
#     'Rest (Album)',
#     'Queens of Mystery (TV Program)'],
#    'org_facet': ['Acorn TV',
#     'American Composers Orchestra',
#     'Brooklyn Steel (Brooklyn, NY, Music Venue)',
#     'Carnegie Hall',
#     'Criterion Collection',
#     'Performance Space New York (Manhattan, NY)',
#     'Public Theater'],
#    'per_facet': ['Gainsbourg, Charlotte', 'Jorn, Asger (1914-73)'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/arts/07week-film/07week-film-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Gloria Grahame and Glenn Ford in &ldquo;The Big Heat.&rdquo;',
#      'copyright': 'Columbia Pictures, via The Criterion Channel'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07week-film/07week-film-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Gloria Grahame and Glenn Ford in &ldquo;The Big Heat.&rdquo;',
#      'copyright': 'Columbia Pictures, via The Criterion Channel'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07week-film/merlin_152602617_27833eb4-1fb5-4a50-945a-4a7af022ee65-articleInline.jpg',
#      'format': 'Normal',
#      'height': 138,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Gloria Grahame and Glenn Ford in &ldquo;The Big Heat.&rdquo;',
#      'copyright': 'Columbia Pictures, via The Criterion Channel'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07week-film/07week-film-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Gloria Grahame and Glenn Ford in &ldquo;The Big Heat.&rdquo;',
#      'copyright': 'Columbia Pictures, via The Criterion Channel'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07week-film/merlin_152602617_27833eb4-1fb5-4a50-945a-4a7af022ee65-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1160,
#      'width': 1600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Gloria Grahame and Glenn Ford in &ldquo;The Big Heat.&rdquo;',
#      'copyright': 'Columbia Pictures, via The Criterion Channel'}],
#    'short_url': 'https://nyti.ms/2G2NXhw'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': 'Issa Rae Is Learning to Make Her Big Voice Heard',
#    'abstract': 'She talks about “Little,” her new film with Regina Hall and Marsai Martin; the future of “Insecure” — including a drinks- and pool-fueled discussion of its end — and a golden moment for black women.',
#    'url': 'https://www.nytimes.com/2019/04/05/movies/issa-rae-insecure-future.html',
#    'byline': 'By KATHRYN SHATTUCK',
#    'item_type': 'Article',
#    'updated_date': '2019-04-05T18:26:51-04:00',
#    'created_date': '2019-04-05T10:00:01-04:00',
#    'published_date': '2019-04-05T10:00:01-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Television',
#     'Movies',
#     'Actors and Actresses',
#     'Blacks',
#     'Insecure (TV Program)',
#     'Little (Movie)',
#     'The Hate U Give (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Rae, Issa'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/arts/07snapshot/07snapshot-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Rozette Rago for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07snapshot/07snapshot-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Rozette Rago for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07snapshot/07snapshot-articleInline.jpg',
#      'format': 'Normal',
#      'height': 253,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Rozette Rago for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07snapshot/07snapshot-mediumThreeByTwo210-v2.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Rozette Rago for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07snapshot/07snapshot-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 2048,
#      'width': 1537,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Rozette Rago for The New York Times'}],
#    'short_url': 'https://nyti.ms/2VqOqPZ'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': '‘Unicorn Store’ Review: When It’s Never Time to Put Away Childish Things',
#    'abstract': 'The message of the movie, directed by and starring Brie Larson, is that there’s no one-size-fits-all formula for adulthood.',
#    'url': 'https://www.nytimes.com/2019/04/05/movies/unicorn-store-review.html',
#    'byline': 'By SCOTT TOBIAS',
#    'item_type': 'Article',
#    'updated_date': '2019-04-05T09:54:55-04:00',
#    'created_date': '2019-04-05T09:54:55-04:00',
#    'published_date': '2019-04-05T09:54:55-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies'],
#    'org_facet': ['Netflix Inc'],
#    'per_facet': ['Larson, Brie', 'Jackson, Samuel L'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/05unicornstore/05unicornstore-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Samuel L. Jackson and Brie Larson in “Unicorn Store,” on Netflix. Larson also directed the film.',
#      'copyright': 'Logan White/Netflix'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05unicornstore/05unicornstore-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Samuel L. Jackson and Brie Larson in “Unicorn Store,” on Netflix. Larson also directed the film.',
#      'copyright': 'Logan White/Netflix'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05unicornstore/merlin_152975937_cec78afc-47a9-49fa-8856-f17796c7c222-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Samuel L. Jackson and Brie Larson in “Unicorn Store,” on Netflix. Larson also directed the film.',
#      'copyright': 'Logan White/Netflix'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05unicornstore/merlin_152975937_cec78afc-47a9-49fa-8856-f17796c7c222-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Samuel L. Jackson and Brie Larson in “Unicorn Store,” on Netflix. Larson also directed the film.',
#      'copyright': 'Logan White/Netflix'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05unicornstore/merlin_152975937_cec78afc-47a9-49fa-8856-f17796c7c222-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Samuel L. Jackson and Brie Larson in “Unicorn Store,” on Netflix. Larson also directed the film.',
#      'copyright': 'Logan White/Netflix'}],
#    'short_url': 'https://nyti.ms/2CVJ9ss'},
#   {'section': 'Arts',
#    'subsection': 'Art & Design',
#    'title': '‘Hamilton’ Set Designer Goes Whimsical, Using Sotheby’s Galleries as a Stage',
#    'abstract': 'David Korins is bringing some of Chatsworth House, the stately home from the movie “Pride and Prejudice,” to New York — for a show at Sotheby’s.',
#    'url': 'https://www.nytimes.com/2019/04/05/arts/design/sothebys-hamilton-chatsworth-house.html',
#    'byline': 'By SOPHIE HAIGNEY',
#    'item_type': 'Article',
#    'updated_date': '2019-04-05T00:01:06-04:00',
#    'created_date': '2019-04-05T00:01:06-04:00',
#    'published_date': '2019-04-05T00:01:06-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Art',
#     'Historic Buildings and Sites',
#     'Theater',
#     'Movies',
#     'Pride and Prejudice (Movie)',
#     'Treasures From Chatsworth (Exhibit)',
#     'the Devonshire Collection'],
#    'org_facet': ["Sotheby's", 'Chatsworth House (Derbyshire, England)'],
#    'per_facet': ['Korins, David'],
#    'geo_facet': ['New York City'],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/04/arts/04chatsworth-item-3-rendering/04chatsworth-item-3-rendering-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A rendering of the galleries for “Treasures From Chatsworth,” for which David Korins magnified details — like table legs, moldings, chair feet — for vitrines and set pieces for the display.',
#      'copyright': 'Rendering courtesy of David Korins'},
#     {'url': 'https://static01.nyt.com/images/2019/04/04/arts/04chatsworth-item-3-rendering/04chatsworth-item-3-rendering-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A rendering of the galleries for “Treasures From Chatsworth,” for which David Korins magnified details — like table legs, moldings, chair feet — for vitrines and set pieces for the display.',
#      'copyright': 'Rendering courtesy of David Korins'},
#     {'url': 'https://static01.nyt.com/images/2019/04/04/arts/04chatsworth-item-3-rendering/04chatsworth-item-3-rendering-articleInline.jpg',
#      'format': 'Normal',
#      'height': 88,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A rendering of the galleries for “Treasures From Chatsworth,” for which David Korins magnified details — like table legs, moldings, chair feet — for vitrines and set pieces for the display.',
#      'copyright': 'Rendering courtesy of David Korins'},
#     {'url': 'https://static01.nyt.com/images/2019/04/04/arts/04chatsworth-item-3-rendering/04chatsworth-item-3-rendering-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A rendering of the galleries for “Treasures From Chatsworth,” for which David Korins magnified details — like table legs, moldings, chair feet — for vitrines and set pieces for the display.',
#      'copyright': 'Rendering courtesy of David Korins'},
#     {'url': 'https://static01.nyt.com/images/2019/04/04/arts/04chatsworth-item-3-rendering/04chatsworth-item-3-rendering-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 631,
#      'width': 1365,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A rendering of the galleries for “Treasures From Chatsworth,” for which David Korins magnified details — like table legs, moldings, chair feet — for vitrines and set pieces for the display.',
#      'copyright': 'Rendering courtesy of David Korins'}],
#    'short_url': 'https://nyti.ms/2Ia67zo'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': '4 Film Series to Catch in N.Y.C. This Weekend',
#    'abstract': 'Our guide to film series and special screenings.',
#    'url': 'https://www.nytimes.com/2019/04/04/movies/nyc-this-weekend-film-series.html',
#    'byline': 'By BEN KENIGSBERG',
#    'item_type': 'Article',
#    'updated_date': '2019-04-04T17:00:08-04:00',
#    'created_date': '2019-04-04T17:00:08-04:00',
#    'published_date': '2019-04-04T17:00:08-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': ['New York City'],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/05LISTINGS-FILM/05LISTINGS-FILM-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Kurt Russell in “Breakdown,” one of several big-rig-themed films screening for Jammin’ Gears: Truckers on Film, at Anthology Film Archives until April 21.',
#      'copyright': 'Paramount Pictures'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05LISTINGS-FILM/05LISTINGS-FILM-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Kurt Russell in “Breakdown,” one of several big-rig-themed films screening for Jammin’ Gears: Truckers on Film, at Anthology Film Archives until April 21.',
#      'copyright': 'Paramount Pictures'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05LISTINGS-FILM/merlin_152968686_46b9249e-61ce-4e70-b254-891f223d8527-articleInline.jpg',
#      'format': 'Normal',
#      'height': 107,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Kurt Russell in “Breakdown,” one of several big-rig-themed films screening for Jammin’ Gears: Truckers on Film, at Anthology Film Archives until April 21.',
#      'copyright': 'Paramount Pictures'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05LISTINGS-FILM/05LISTINGS-FILM-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Kurt Russell in “Breakdown,” one of several big-rig-themed films screening for Jammin’ Gears: Truckers on Film, at Anthology Film Archives until April 21.',
#      'copyright': 'Paramount Pictures'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05LISTINGS-FILM/merlin_152968686_46b9249e-61ce-4e70-b254-891f223d8527-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1152,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Kurt Russell in “Breakdown,” one of several big-rig-themed films screening for Jammin’ Gears: Truckers on Film, at Anthology Film Archives until April 21.',
#      'copyright': 'Paramount Pictures'}],
#    'short_url': 'https://nyti.ms/2uIZnAI'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': '‘Peterloo’ Review: Political Violence of the Past Mirrors the Present',
#    'abstract': 'Mike Leigh’s historical drama has the sweep of Tolstoy and the bustling energy of Dickens.',
#    'url': 'https://www.nytimes.com/2019/04/04/movies/peterloo-review.html',
#    'byline': 'By A.O. SCOTT',
#    'item_type': 'Article',
#    'updated_date': '2019-04-04T12:47:37-04:00',
#    'created_date': '2019-04-04T11:58:33-04:00',
#    'published_date': '2019-04-04T11:58:33-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies', 'Peterloo (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Leigh, Mike', 'Kinnear, Rory'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/05peterloo/05peterloo-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Mike Leigh&rsquo;s new movie, &ldquo;Peterloo,&rdquo; is filled with images of oppression and fiery exhortations to revolt.',
#      'copyright': 'Simon Mein/Amazon Studios'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05peterloo/05peterloo-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Mike Leigh&rsquo;s new movie, &ldquo;Peterloo,&rdquo; is filled with images of oppression and fiery exhortations to revolt.',
#      'copyright': 'Simon Mein/Amazon Studios'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05peterloo/merlin_152838888_fc67ae89-4a23-40a8-9e17-4bdc9556f099-articleInline.jpg',
#      'format': 'Normal',
#      'height': 107,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Mike Leigh&rsquo;s new movie, &ldquo;Peterloo,&rdquo; is filled with images of oppression and fiery exhortations to revolt.',
#      'copyright': 'Simon Mein/Amazon Studios'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05peterloo/05peterloo-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Mike Leigh&rsquo;s new movie, &ldquo;Peterloo,&rdquo; is filled with images of oppression and fiery exhortations to revolt.',
#      'copyright': 'Simon Mein/Amazon Studios'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05peterloo/merlin_152838888_fc67ae89-4a23-40a8-9e17-4bdc9556f099-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1152,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Mike Leigh&rsquo;s new movie, &ldquo;Peterloo,&rdquo; is filled with images of oppression and fiery exhortations to revolt.',
#      'copyright': 'Simon Mein/Amazon Studios'}],
#    'short_url': 'https://nyti.ms/2UtIXLa'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': '‘The Fate of Lee Khan’ Review: King Hu Directs Angela Mao',
#    'abstract': 'Lady Kung Fu and a renowned wuxia director in their only feature together, this restored 1973 film.',
#    'url': 'https://www.nytimes.com/2019/04/04/movies/the-fate-of-lee-khan-review.html',
#    'byline': 'By GLENN KENNY',
#    'item_type': 'Article',
#    'updated_date': '2019-04-04T22:11:13-04:00',
#    'created_date': '2019-04-04T07:00:05-04:00',
#    'published_date': '2019-04-04T07:00:05-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies', 'The Fate of Lee Khan (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Hu, King', 'Mao, Angela (1950- )'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/04fateofleepix/04fateofleepix-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Left to right, Angela Mao, Chin Hu and Helen Ma in the restored film "The Fate of Lee Khan."',
#      'copyright': 'Film Movement Classics'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04fateofleepix/04fateofleepix-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Left to right, Angela Mao, Chin Hu and Helen Ma in the restored film "The Fate of Lee Khan."',
#      'copyright': 'Film Movement Classics'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04fateofleepix/merlin_152838666_3bd38ad0-8dab-4e67-9e58-8f452ba09566-articleInline.jpg',
#      'format': 'Normal',
#      'height': 119,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Left to right, Angela Mao, Chin Hu and Helen Ma in the restored film "The Fate of Lee Khan."',
#      'copyright': 'Film Movement Classics'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04fateofleepix/04fateofleepix-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Left to right, Angela Mao, Chin Hu and Helen Ma in the restored film "The Fate of Lee Khan."',
#      'copyright': 'Film Movement Classics'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04fateofleepix/merlin_152838666_3bd38ad0-8dab-4e67-9e58-8f452ba09566-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1200,
#      'width': 1920,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Left to right, Angela Mao, Chin Hu and Helen Ma in the restored film "The Fate of Lee Khan."',
#      'copyright': 'Film Movement Classics'}],
#    'short_url': 'https://nyti.ms/2K61CJ3'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': '‘Storm Boy’ Review: Raising Pelicans in a Film That Never Fully Takes Flight',
#    'abstract': 'The film tries to present itself as a modern fable, but the themes come across as didactic rather than moving.',
#    'url': 'https://www.nytimes.com/2019/04/04/movies/storm-boy-review.html',
#    'byline': 'By TEO BUGBEE',
#    'item_type': 'Article',
#    'updated_date': '2019-04-04T07:00:05-04:00',
# ...
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The steeple lantern of Christ Church in Philadelphia. The church was awarded a grant by the National Endowment for the Humanities to restore its steeple and church tower.',
#      'copyright': 'Matt Rourke/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/02/arts/02neh-item/merlin_152733675_2df331a7-be96-4ebf-9ec4-24ff2a73e011-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The steeple lantern of Christ Church in Philadelphia. The church was awarded a grant by the National Endowment for the Humanities to restore its steeple and church tower.',
#      'copyright': 'Matt Rourke/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/02/arts/02neh-item/merlin_152733675_2df331a7-be96-4ebf-9ec4-24ff2a73e011-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The steeple lantern of Christ Church in Philadelphia. The church was awarded a grant by the National Endowment for the Humanities to restore its steeple and church tower.',
#      'copyright': 'Matt Rourke/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/02/arts/02neh-item/merlin_152733675_2df331a7-be96-4ebf-9ec4-24ff2a73e011-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The steeple lantern of Christ Church in Philadelphia. The church was awarded a grant by the National Endowment for the Humanities to restore its steeple and church tower.',
#      'copyright': 'Matt Rourke/Associated Press'}],
#    'short_url': 'https://nyti.ms/2UkDrdG'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': 'From the Boxing Ring to ‘Dumbo’: Michael Buffer Is Still Ready to Rumble',
#    'abstract': 'You might not recognize his name, but you definitely recognize his voice. Michael Buffer came up with one of the most recognizable catchphrases in history and has continued cashing in since.',
#    'url': 'https://www.nytimes.com/2019/04/02/movies/dumbo-michael-buffer-lets-get-ready-to-rumble.html',
#    'byline': 'By SOPAN DEB',
#    'item_type': 'Article',
#    'updated_date': '2019-04-02T11:18:40-04:00',
#    'created_date': '2019-04-02T11:18:40-04:00',
#    'published_date': '2019-04-02T11:18:40-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies', 'Dumbo (Movie)'],
#    'org_facet': ['Walt Disney Company'],
#    'per_facet': ['Burton, Tim'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/03/arts/02dumbo-buffer-2/02dumbo-buffer-2-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Michael Buffer in &ldquo;Dumbo.&rdquo;',
#      'copyright': 'Jay Maidment/Disney'},
#     {'url': 'https://static01.nyt.com/images/2019/04/03/arts/02dumbo-buffer-2/02dumbo-buffer-2-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Michael Buffer in &ldquo;Dumbo.&rdquo;',
#      'copyright': 'Jay Maidment/Disney'},
#     {'url': 'https://static01.nyt.com/images/2019/04/03/arts/02dumbo-buffer-2/merlin_152940573_f57757a2-0f19-475d-a557-84d96892aee0-articleInline.jpg',
#      'format': 'Normal',
#      'height': 132,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Michael Buffer in &ldquo;Dumbo.&rdquo;',
#      'copyright': 'Jay Maidment/Disney'},
#     {'url': 'https://static01.nyt.com/images/2019/04/03/arts/02dumbo-buffer-2/02dumbo-buffer-2-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Michael Buffer in &ldquo;Dumbo.&rdquo;',
#      'copyright': 'Jay Maidment/Disney'},
#     {'url': 'https://static01.nyt.com/images/2019/04/03/arts/02dumbo-buffer-2/merlin_152940573_f57757a2-0f19-475d-a557-84d96892aee0-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1419,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Michael Buffer in &ldquo;Dumbo.&rdquo;',
#      'copyright': 'Jay Maidment/Disney'}],
#    'short_url': 'https://nyti.ms/2uGqNHm'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': '‘Christ Stopped at Eboli’: An Italian Saga Returns in Full',
#    'abstract': 'Francesco Rosi’s adaptation of Carlo Levi’s best-selling memoir, “Christ Stopped at Eboli,” is an absorbing immersion in peasant poverty under Fascism.',
#    'url': 'https://www.nytimes.com/2019/04/02/movies/christ-stopped-at-eboli-levi-rosi.html',
#    'byline': 'By J. HOBERMAN',
#    'item_type': 'Article',
#    'updated_date': '2019-04-02T10:00:04-04:00',
#    'created_date': '2019-04-02T10:00:04-04:00',
#    'published_date': '2019-04-02T10:00:04-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies',
#     'Christ Stopped at Eboli (Movie)',
#     'Italian Language'],
#    'org_facet': ['Film Forum'],
#    'per_facet': ['Rosi, Francesco', 'Levi, Carlo'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/02rewind/03rewind-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Paolo Bonacelli, left, as a pro-Fascist mayor, and Gian Maria Volont&egrave; as the exiled writer Carlo Levi in &ldquo;Christ Stopped at Eboli,&rdquo; a film adaptation of Levi&rsquo;s memoir directed by Francesco Rosi.',
#      'copyright': 'Rialto Pictures'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/02rewind/03rewind-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Paolo Bonacelli, left, as a pro-Fascist mayor, and Gian Maria Volont&egrave; as the exiled writer Carlo Levi in &ldquo;Christ Stopped at Eboli,&rdquo; a film adaptation of Levi&rsquo;s memoir directed by Francesco Rosi.',
#      'copyright': 'Rialto Pictures'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/02rewind/merlin_152789544_fcbc5015-a424-4122-8ce3-eff6e889e2af-articleInline.jpg',
#      'format': 'Normal',
#      'height': 152,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Paolo Bonacelli, left, as a pro-Fascist mayor, and Gian Maria Volont&egrave; as the exiled writer Carlo Levi in &ldquo;Christ Stopped at Eboli,&rdquo; a film adaptation of Levi&rsquo;s memoir directed by Francesco Rosi.',
#      'copyright': 'Rialto Pictures'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/02rewind/03rewind-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Paolo Bonacelli, left, as a pro-Fascist mayor, and Gian Maria Volont&egrave; as the exiled writer Carlo Levi in &ldquo;Christ Stopped at Eboli,&rdquo; a film adaptation of Levi&rsquo;s memoir directed by Francesco Rosi.',
#      'copyright': 'Rialto Pictures'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/arts/02rewind/merlin_152789544_fcbc5015-a424-4122-8ce3-eff6e889e2af-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1643,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Paolo Bonacelli, left, as a pro-Fascist mayor, and Gian Maria Volont&egrave; as the exiled writer Carlo Levi in &ldquo;Christ Stopped at Eboli,&rdquo; a film adaptation of Levi&rsquo;s memoir directed by Francesco Rosi.',
#      'copyright': 'Rialto Pictures'}],
#    'short_url': 'https://nyti.ms/2UolAmc'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': '‘Wall’ Review: A Writer Reflects on Borders',
#    'abstract': 'In the animated feature “Wall,” David Hare meditates on the partition that divides Israel and the West Bank.',
#    'url': 'https://www.nytimes.com/2019/04/02/movies/the-wall-review.html',
#    'byline': 'By BEN KENIGSBERG',
#    'item_type': 'Article',
#    'updated_date': '2019-04-02T07:00:01-04:00',
#    'created_date': '2019-04-02T07:00:01-04:00',
#    'published_date': '2019-04-02T07:00:01-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies', 'Wall (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Hare, David'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/03/arts/wall1/wall1-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The writer David Hare in the animated film &ldquo;Wall.&rdquo;',
#      'copyright': 'The National Film Board of Canada'},
#     {'url': 'https://static01.nyt.com/images/2019/04/03/arts/wall1/wall1-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The writer David Hare in the animated film &ldquo;Wall.&rdquo;',
#      'copyright': 'The National Film Board of Canada'},
#     {'url': 'https://static01.nyt.com/images/2019/04/03/arts/wall1/wall1-articleInline.jpg',
#      'format': 'Normal',
#      'height': 107,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The writer David Hare in the animated film &ldquo;Wall.&rdquo;',
#      'copyright': 'The National Film Board of Canada'},
#     {'url': 'https://static01.nyt.com/images/2019/04/03/arts/wall1/wall1-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The writer David Hare in the animated film &ldquo;Wall.&rdquo;',
#      'copyright': 'The National Film Board of Canada'},
#     {'url': 'https://static01.nyt.com/images/2019/04/03/arts/wall1/wall1-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1152,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The writer David Hare in the animated film &ldquo;Wall.&rdquo;',
#      'copyright': 'The National Film Board of Canada'}],
#    'short_url': 'https://nyti.ms/2uCk4OO'},
#   {'section': 'Style',
#    'subsection': '',
#    'title': 'Confirm or Deny: Sam Rockwell',
#    'abstract': 'More on the actor’s friends and influences.',
#    'url': 'https://www.nytimes.com/2019/04/01/style/confirm-or-deny-sam-rockwell.html',
#    'byline': 'By MAUREEN DOWD',
#    'item_type': 'Article',
#    'updated_date': '2019-04-04T00:52:01-04:00',
#    'created_date': '2019-04-01T11:38:18-04:00',
#    'published_date': '2019-04-01T11:38:18-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies', 'Television', 'Actors and Actresses'],
#    'org_facet': [],
#    'per_facet': ['Rockwell, Sam'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/04/fashion/01CONFIRMORDENY2/01CONFIRMORDENY2-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Sam Rockwell',
#      'copyright': 'Daniel Dorsa for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/01CONFIRMORDENY2/01CONFIRMORDENY2-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Sam Rockwell',
#      'copyright': 'Daniel Dorsa for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/01CONFIRMORDENY2/merlin_152280909_1f3ecfe4-006c-4d19-a117-e64380a4e58f-articleInline.jpg',
#      'format': 'Normal',
#      'height': 238,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Sam Rockwell',
#      'copyright': 'Daniel Dorsa for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/01CONFIRMORDENY2/merlin_152280909_1f3ecfe4-006c-4d19-a117-e64380a4e58f-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Sam Rockwell',
#      'copyright': 'Daniel Dorsa for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/01CONFIRMORDENY2/merlin_152280909_1f3ecfe4-006c-4d19-a117-e64380a4e58f-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 2048,
#      'width': 1639,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Sam Rockwell',
#      'copyright': 'Daniel Dorsa for The New York Times'}],
#    'short_url': 'https://nyti.ms/2FTUvy3'},
#   {'section': 'Movies',
#    'subsection': '',
#    'title': '‘Dumbo’ Falls Short of Box-Office Expectations but Still Comes in First',
#    'abstract': 'Tim Burton’s moody Disney remake sold $45 million in tickets in its first weekend. And Jordan Peele’s “Us” has crossed well over the $100 million mark.',
#    'url': 'https://www.nytimes.com/2019/03/31/movies/dumbo-box-office-us.html',
#    'byline': 'By GABE COHN',
#    'item_type': 'Article',
#    'updated_date': '2019-03-31T15:12:31-04:00',
#    'created_date': '2019-03-31T15:12:31-04:00',
#    'published_date': '2019-03-31T15:12:31-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies', 'Dumbo (Movie)', 'Us (Movie)'],
#    'org_facet': ['Walt Disney Company'],
#    'per_facet': ['Burton, Tim', 'Peele, Jordan'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/03/31/arts/31boxoffice-item/merlin_152482068_a6ae7443-f57a-4c35-b4f0-c296cea46a4a-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'From left, Danny DeVito, Nico Parker and Colin Farrell in “Dumbo,” the latest live-action remake of an animated Disney classic.',
#      'copyright': 'Jay Maidment/Disney'},
#     {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31boxoffice-item/merlin_152482068_a6ae7443-f57a-4c35-b4f0-c296cea46a4a-thumbLarge.jpg',
#      'format': 'thumbLarge',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'From left, Danny DeVito, Nico Parker and Colin Farrell in “Dumbo,” the latest live-action remake of an animated Disney classic.',
#      'copyright': 'Jay Maidment/Disney'},
#     {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31boxoffice-item/merlin_152482068_a6ae7443-f57a-4c35-b4f0-c296cea46a4a-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'From left, Danny DeVito, Nico Parker and Colin Farrell in “Dumbo,” the latest live-action remake of an animated Disney classic.',
#      'copyright': 'Jay Maidment/Disney'},
#     {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31boxoffice-item/merlin_152482068_a6ae7443-f57a-4c35-b4f0-c296cea46a4a-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'From left, Danny DeVito, Nico Parker and Colin Farrell in “Dumbo,” the latest live-action remake of an animated Disney classic.',
#      'copyright': 'Jay Maidment/Disney'},
#     {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31boxoffice-item/merlin_152482068_a6ae7443-f57a-4c35-b4f0-c296cea46a4a-superJumbo.jpg',
#      'format': 'superJumbo',
#      'height': 1200,
#      'width': 1800,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'From left, Danny DeVito, Nico Parker and Colin Farrell in “Dumbo,” the latest live-action remake of an animated Disney classic.',
#      'copyright': 'Jay Maidment/Disney'}],
#    'short_url': 'https://nyti.ms/2WBRyc8'}]}

# %%
#extract actual data from the json file
movie_res = movie['results']
movie_res
# Out:
# [{'section': 'Movies',
#   'subsection': '',
#   'title': '‘Shazam!’ Review: A Boy’s Supersized Alter Ego in a Sunny Superhero Flick',
#   'abstract': 'A nicely matched Asher Angel and Zachary Levi together play a superhero who has been taken out of mothballs with humor and fine performances.',
#   'url': 'https://www.nytimes.com/2019/04/03/movies/shazam-review.html',
#   'byline': 'By MANOHLA DARGIS',
#   'item_type': 'Article',
#   'updated_date': '2019-04-05T10:32:45-04:00',
#   'created_date': '2019-04-03T17:47:11-04:00',
#   'published_date': '2019-04-03T17:47:11-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies', 'Shazam! (Movie)'],
#   'org_facet': [],
#   'per_facet': ['Sandberg, David F',
#    'Gayden, Henry',
#    'Levi, Zachary',
#    'Hounsou, Djimon',
#    'Angel, Asher (2002- )'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/04shazam-1/00shazam-1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.',
#     'copyright': 'Steve Wilkie/Warner Bros. Pictures'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04shazam-1/00shazam-1-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.',
#     'copyright': 'Steve Wilkie/Warner Bros. Pictures'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04shazam-1/merlin_152839509_708fbe71-6887-41c5-9433-85e9c625f0b3-articleInline.jpg',
#     'format': 'Normal',
#     'height': 107,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.',
#     'copyright': 'Steve Wilkie/Warner Bros. Pictures'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04shazam-1/00shazam-1-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.',
#     'copyright': 'Steve Wilkie/Warner Bros. Pictures'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04shazam-1/merlin_152839509_708fbe71-6887-41c5-9433-85e9c625f0b3-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1098,
#     'width': 1952,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Asher Angel plays Billy Batson, the boy who can say &ldquo;shazam&rdquo; and turn into ... a superhero.',
#     'copyright': 'Steve Wilkie/Warner Bros. Pictures'}],
#   'short_url': 'https://nyti.ms/2OMshsX'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': '‘Pet Sematary’ Review: An Unsettling New Take on a Stephen King Classic',
#   'abstract': 'This one has a smoother feel than the 1989 movie, our critic writes. But despite some great jolts, it’s an uneven horror film.',
#   'url': 'https://www.nytimes.com/2019/04/04/movies/pet-sematary-review.html',
#   'byline': 'By GLENN KENNY',
#   'item_type': 'Article',
#   'updated_date': '2019-04-04T13:17:17-04:00',
#   'created_date': '2019-04-04T10:11:31-04:00',
#   'published_date': '2019-04-04T10:11:31-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies', 'Pet Sematary (Movie)'],
#   'org_facet': [],
#   'per_facet': ['King, Stephen', 'Widmyer, Dennis', 'Kolsch, Kevin'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/04petsematary/04petsematary-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Jet&eacute; Laurence and the family cat in &ldquo;Pet Sematary.&rdquo;',
#     'copyright': 'Kerry Hayes/Paramount Pictures.'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04petsematary/04petsematary-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Jet&eacute; Laurence and the family cat in &ldquo;Pet Sematary.&rdquo;',
#     'copyright': 'Kerry Hayes/Paramount Pictures.'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04petsematary/merlin_152839077_35d29315-7167-4e58-a7ea-6f0dae1f7934-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Jet&eacute; Laurence and the family cat in &ldquo;Pet Sematary.&rdquo;',
#     'copyright': 'Kerry Hayes/Paramount Pictures.'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04petsematary/04petsematary-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Jet&eacute; Laurence and the family cat in &ldquo;Pet Sematary.&rdquo;',
#     'copyright': 'Kerry Hayes/Paramount Pictures.'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04petsematary/merlin_152839077_35d29315-7167-4e58-a7ea-6f0dae1f7934-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1366,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Jet&eacute; Laurence and the family cat in &ldquo;Pet Sematary.&rdquo;',
#     'copyright': 'Kerry Hayes/Paramount Pictures.'}],
#   'short_url': 'https://nyti.ms/2K7506o'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': 'The Agnès Varda I Knew: Showing Women Their Real Place in Movies',
#   'abstract': 'In encounters over the years, our critic met a filmmaker with an acute sense of the oppressed and of her standing in the French New Wave.',
#   'url': 'https://www.nytimes.com/2019/04/02/movies/agnes-varda-memory.html',
#   'byline': 'By MANOHLA DARGIS',
#   'item_type': 'Article',
#   'updated_date': '2019-04-03T10:14:35-04:00',
#   'created_date': '2019-04-02T14:51:25-04:00',
#   'published_date': '2019-04-02T14:51:25-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies',
#    'Women and Girls',
#    'Vagabond (Movie)',
#    'The Beaches of Agnes (Movie)'],
#   'org_facet': [],
#   'per_facet': ['Varda, Agnes'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/arts/7Agnes-1/7Agnes-1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Agn&egrave;s Varda at work on &ldquo;Cl&eacute;o From 5 to 7,&rdquo; released in 1962.',
#     'copyright': 'Roger Viollet/Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/7Agnes-1/7Agnes-1-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Agn&egrave;s Varda at work on &ldquo;Cl&eacute;o From 5 to 7,&rdquo; released in 1962.',
#     'copyright': 'Roger Viollet/Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/7Agnes-1/merlin_152797479_48bbaef7-e61c-4436-a2ea-cfc6ca9a43d6-articleInline.jpg',
#     'format': 'Normal',
#     'height': 195,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Agn&egrave;s Varda at work on &ldquo;Cl&eacute;o From 5 to 7,&rdquo; released in 1962.',
#     'copyright': 'Roger Viollet/Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/7Agnes-1/7Agnes-1-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Agn&egrave;s Varda at work on &ldquo;Cl&eacute;o From 5 to 7,&rdquo; released in 1962.',
#     'copyright': 'Roger Viollet/Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/7Agnes-1/merlin_152797479_48bbaef7-e61c-4436-a2ea-cfc6ca9a43d6-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 2048,
#     'width': 2001,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Agn&egrave;s Varda at work on &ldquo;Cl&eacute;o From 5 to 7,&rdquo; released in 1962.',
#     'copyright': 'Roger Viollet/Getty Images'}],
#   'short_url': 'https://nyti.ms/2Uo7KQO'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': '‘The Best of Enemies’ Review: A Klansman and a Civil Rights Activist Become Friends',
#   'abstract': 'Taraji P. Henson and Sam Rockwell star in a clumsy drama of racial reconciliation. It’s based on a true story.',
#   'url': 'https://www.nytimes.com/2019/04/03/movies/the-best-of-enemies-review.html',
#   'byline': 'By A.O. SCOTT',
#   'item_type': 'Article',
#   'updated_date': '2019-04-04T09:43:05-04:00',
#   'created_date': '2019-04-03T15:01:59-04:00',
#   'published_date': '2019-04-03T15:01:59-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies', 'The Best of Enemies (Movie)'],
#   'org_facet': [],
#   'per_facet': ['Bissell, Robin (1968- )',
#    'Henson, Taraji P',
#    'Rockwell, Sam',
#    'Bentley, Wes',
#    'Heche, Anne'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/03bestofenemies/03bestofenemies-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'From left, Sam Rockwell, Babou Ceesay and Taraji P. Henson in &ldquo;The Best of Enemies,&rdquo; a story of race and reconciliation.',
#     'copyright': 'Annette Brown/STXfilms'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/03bestofenemies/03bestofenemies-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'From left, Sam Rockwell, Babou Ceesay and Taraji P. Henson in &ldquo;The Best of Enemies,&rdquo; a story of race and reconciliation.',
#     'copyright': 'Annette Brown/STXfilms'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/03bestofenemies/03bestofenemies-articleInline.jpg',
#     'format': 'Normal',
#     'height': 145,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'From left, Sam Rockwell, Babou Ceesay and Taraji P. Henson in &ldquo;The Best of Enemies,&rdquo; a story of race and reconciliation.',
#     'copyright': 'Annette Brown/STXfilms'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/03bestofenemies/03bestofenemies-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'From left, Sam Rockwell, Babou Ceesay and Taraji P. Henson in &ldquo;The Best of Enemies,&rdquo; a story of race and reconciliation.',
#     'copyright': 'Annette Brown/STXfilms'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/03bestofenemies/03bestofenemies-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1565,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'From left, Sam Rockwell, Babou Ceesay and Taraji P. Henson in &ldquo;The Best of Enemies,&rdquo; a story of race and reconciliation.',
#     'copyright': 'Annette Brown/STXfilms'}],
#   'short_url': 'https://nyti.ms/2UuUYji'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': 'Watch a Boy Discover His Superpowers in ‘Shazam!’',
#   'abstract': 'The director David F. Sandberg discusses a scene featuring Zachary Levi and Jack Dylan Grazer.',
#   'url': 'https://www.nytimes.com/2019/04/05/movies/shazam-scene.html',
#   'byline': 'By MEKADO MURPHY',
#   'item_type': 'Article',
#   'updated_date': '2019-04-05T17:38:34-04:00',
#   'created_date': '2019-04-05T07:02:01-04:00',
#   'published_date': '2019-04-05T07:02:01-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies', 'Shazam! (Movie)'],
#   'org_facet': [],
#   'per_facet': ['Levi, Zachary', 'Sandberg, David F'],
#   'geo_facet': [],
#   'multimedia': [],
#   'short_url': 'https://nyti.ms/2CYgyTf'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': '‘High Life’ Review: Robert Pattinson Is Lost in Space',
#   'abstract': 'The director Claire Denis fills her science-fiction fantasy with drift, fluids and beautiful people, including Juliette Binoche and André Benjamin.',
#   'url': 'https://www.nytimes.com/2019/04/04/movies/high-life-review.html',
#   'byline': 'By MANOHLA DARGIS',
#   'item_type': 'Article',
#   'updated_date': '2019-04-04T12:27:22-04:00',
#   'created_date': '2019-04-04T12:27:22-04:00',
#   'published_date': '2019-04-04T12:27:22-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies', 'High Life (Movie)'],
#   'org_facet': [],
#   'per_facet': ['Denis, Claire',
#    'Pattinson, Robert',
#    'Binoche, Juliette',
#    'Benjamin, Andre (Andre 3000)'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/04highlife/04highlife-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Jessie Ross and Robert Pattinson in &ldquo;High Life,&rdquo; a new science-fiction movie from Claire Denis.',
#     'copyright': 'A24'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04highlife/04highlife-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Jessie Ross and Robert Pattinson in &ldquo;High Life,&rdquo; a new science-fiction movie from Claire Denis.',
#     'copyright': 'A24'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04highlife/merlin_152838792_e9c6dee7-0377-415c-b58f-ec4ed9650156-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Jessie Ross and Robert Pattinson in &ldquo;High Life,&rdquo; a new science-fiction movie from Claire Denis.',
#     'copyright': 'A24'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04highlife/merlin_152838792_e9c6dee7-0377-415c-b58f-ec4ed9650156-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Jessie Ross and Robert Pattinson in &ldquo;High Life,&rdquo; a new science-fiction movie from Claire Denis.',
#     'copyright': 'A24'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04highlife/merlin_152838792_e9c6dee7-0377-415c-b58f-ec4ed9650156-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1067,
#     'width': 1600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Jessie Ross and Robert Pattinson in &ldquo;High Life,&rdquo; a new science-fiction movie from Claire Denis.',
#     'copyright': 'A24'}],
#   'short_url': 'https://nyti.ms/2WJ2tAD'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': '‘Amazing Grace’ Review: Aretha Franklin Is Glorious in a Rousing Concert Film',
#   'abstract': 'The film Aretha Franklin didn’t want you to see arrives in theaters. It captures an incandescent Queen of Soul recording her 1972 live album.',
#   'url': 'https://www.nytimes.com/2018/12/05/movies/amazing-grace-review.html',
#   'byline': 'By WESLEY MORRIS',
#   'item_type': 'Article',
#   'updated_date': '2018-12-05T20:17:11-05:00',
#   'created_date': '2018-12-05T20:17:11-05:00',
#   'published_date': '2018-12-05T20:17:11-05:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Documentary Films and Programs',
#    'Amazing Grace (2018) (Movie)',
#    'Blacks',
#    'Gospel Music',
#    'Music'],
#   'org_facet': [],
#   'per_facet': ['Franklin, Aretha', 'Pollack, Sydney'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2018/12/07/arts/07AMAZINGGRACE-1/07AMAZINGGRACE-1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Aretha Franklin in the 1972 documentary “Amazing Grace.”',
#     'copyright': 'Amazing Grace Film, LLC'},
#    {'url': 'https://static01.nyt.com/images/2018/12/07/arts/07AMAZINGGRACE-1/07AMAZINGGRACE-1-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Aretha Franklin in the 1972 documentary “Amazing Grace.”',
#     'copyright': 'Amazing Grace Film, LLC'},
#    {'url': 'https://static01.nyt.com/images/2018/12/07/arts/07AMAZINGGRACE-1/07AMAZINGGRACE-1-articleInline.jpg',
#     'format': 'Normal',
#     'height': 109,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Aretha Franklin in the 1972 documentary “Amazing Grace.”',
#     'copyright': 'Amazing Grace Film, LLC'},
#    {'url': 'https://static01.nyt.com/images/2018/12/07/arts/07AMAZINGGRACE-1/07AMAZINGGRACE-1-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Aretha Franklin in the 1972 documentary “Amazing Grace.”',
#     'copyright': 'Amazing Grace Film, LLC'},
#    {'url': 'https://static01.nyt.com/images/2018/12/07/arts/07AMAZINGGRACE-1/07AMAZINGGRACE-1-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1080,
#     'width': 1874,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Aretha Franklin in the 1972 documentary “Amazing Grace.”',
#     'copyright': 'Amazing Grace Film, LLC'}],
#   'short_url': 'https://nyti.ms/2zJrRxh'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': 'Shazam Is Back. Wait, Who Is He Again?',
#   'abstract': 'Although many viewers may be unfamiliar with the character, he is one of the most important superheroes in comic history, dating back to 1939.',
#   'url': 'https://www.nytimes.com/2019/04/05/movies/shazam-history-captain-marvel.html',
#   'byline': 'By DEVIN FULLER',
#   'item_type': 'Article',
#   'updated_date': '2019-04-05T11:00:01-04:00',
#   'created_date': '2019-04-05T11:00:01-04:00',
#   'published_date': '2019-04-05T11:00:01-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Comic Books and Strips', 'Movies', 'Shazam! (Movie)'],
#   'org_facet': ['DC Comics', 'Republic Pictures', 'Marvel Comics'],
#   'per_facet': ['Johns, Geoff'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/14/arts/14SHAZAM-1/14SHAZAM-1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Zachary Levi, left, and Jack Dylan Grazer in a scene from “Shazam!”',
#     'copyright': 'Steve Wilkie/Warner Bros. Entertainment'},
#    {'url': 'https://static01.nyt.com/images/2019/04/14/arts/14SHAZAM-1/14SHAZAM-1-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Zachary Levi, left, and Jack Dylan Grazer in a scene from “Shazam!”',
#     'copyright': 'Steve Wilkie/Warner Bros. Entertainment'},
#    {'url': 'https://static01.nyt.com/images/2019/04/14/arts/14SHAZAM-1/merlin_152399808_7eaefa8c-f7cc-4bfa-9b50-dee3c187fbfb-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Zachary Levi, left, and Jack Dylan Grazer in a scene from “Shazam!”',
#     'copyright': 'Steve Wilkie/Warner Bros. Entertainment'},
#    {'url': 'https://static01.nyt.com/images/2019/04/14/arts/14SHAZAM-1/merlin_152399808_7eaefa8c-f7cc-4bfa-9b50-dee3c187fbfb-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Zachary Levi, left, and Jack Dylan Grazer in a scene from “Shazam!”',
#     'copyright': 'Steve Wilkie/Warner Bros. Entertainment'},
#    {'url': 'https://static01.nyt.com/images/2019/04/14/arts/14SHAZAM-1/merlin_152399808_7eaefa8c-f7cc-4bfa-9b50-dee3c187fbfb-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Zachary Levi, left, and Jack Dylan Grazer in a scene from “Shazam!”',
#     'copyright': 'Steve Wilkie/Warner Bros. Entertainment'}],
#   'short_url': 'https://nyti.ms/2TZM6xQ'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': 'It May Be the Most Cursed Film Ever. These 5 Crew Members Saw It Through.',
#   'abstract': 'Terry Gilliam’s “The Man Who Killed Don Quixote” is reaching screens after 30 years, several cast changes and a flash flood. Those who were there at the start look back.',
#   'url': 'https://www.nytimes.com/2019/04/04/movies/terry-gilliam-don-quixote.html',
#   'byline': 'By SOPAN DEB',
#   'item_type': 'Article',
#   'updated_date': '2019-04-04T10:00:09-04:00',
#   'created_date': '2019-04-04T10:00:09-04:00',
#   'published_date': '2019-04-04T10:00:09-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies',
#    'The Man Who Killed Don Quixote (Movie)',
#    'Cannes International Film Festival'],
#   'org_facet': [],
#   'per_facet': ['Gilliam, Terry', 'Driver, Adam'],
#   'geo_facet': ['Spain'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/arts/07quixote-veterans-promo/07QUIXOTE-promo-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Tom Jamieson for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07quixote-veterans-promo/07QUIXOTE-promo-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Tom Jamieson for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07quixote-veterans-promo/merlin_152467806_01484a2f-ed31-48ca-a2e8-b0bb785e0b1d-articleInline.jpg',
#     'format': 'Normal',
#     'height': 136,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Tom Jamieson for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07quixote-veterans-promo/07QUIXOTE-promo-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Tom Jamieson for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07quixote-veterans-promo/merlin_152467806_01484a2f-ed31-48ca-a2e8-b0bb785e0b1d-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1463,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Tom Jamieson for The New York Times'}],
#   'short_url': 'https://nyti.ms/2K6qNLz'},
#  {'section': 'Style',
#   'subsection': '',
#   'title': 'Hot Topic Is Still Hot',
#   'abstract': 'How has an enclave for emo kids and mall goths resisted the retail apocalypse? With merch.',
#   'url': 'https://www.nytimes.com/2019/04/06/style/hot-topic-stores.html',
#   'byline': 'By PAULA MEJÍA',
#   'item_type': 'Article',
#   'updated_date': '2019-04-06T06:00:02-04:00',
#   'created_date': '2019-04-06T06:00:01-04:00',
#   'published_date': '2019-04-06T06:00:01-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Shopping and Retail'],
#   'org_facet': ['Hot Topic'],
#   'per_facet': [],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/04/fashion/04HOTTOPIC1/04HOTTOPIC1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'T-shirts on display at the Westfield Garden State Plaza shopping center’s Hot Topic. The store, now in its 30th year, has become a haven for merchandise tied to a wide range of fandoms.',
#     'copyright': "Pat O'Malley for The New York Times"},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/04HOTTOPIC1/04HOTTOPIC1-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'T-shirts on display at the Westfield Garden State Plaza shopping center’s Hot Topic. The store, now in its 30th year, has become a haven for merchandise tied to a wide range of fandoms.',
#     'copyright': "Pat O'Malley for The New York Times"},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/04HOTTOPIC1/merlin_152972241_37cb430e-8686-4ce9-b113-688e9019ef16-articleInline.jpg',
#     'format': 'Normal',
#     'height': 136,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'T-shirts on display at the Westfield Garden State Plaza shopping center’s Hot Topic. The store, now in its 30th year, has become a haven for merchandise tied to a wide range of fandoms.',
#     'copyright': "Pat O'Malley for The New York Times"},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/04HOTTOPIC1/04HOTTOPIC1-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'T-shirts on display at the Westfield Garden State Plaza shopping center’s Hot Topic. The store, now in its 30th year, has become a haven for merchandise tied to a wide range of fandoms.',
#     'copyright': "Pat O'Malley for The New York Times"},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/04HOTTOPIC1/merlin_152972241_37cb430e-8686-4ce9-b113-688e9019ef16-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1463,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'T-shirts on display at the Westfield Garden State Plaza shopping center’s Hot Topic. The store, now in its 30th year, has become a haven for merchandise tied to a wide range of fandoms.',
#     'copyright': "Pat O'Malley for The New York Times"}],
#   'short_url': 'https://nyti.ms/2IfXdQZ'},
#  {'section': 'Arts',
#   'subsection': '',
#   'title': 'The Week in Arts: The Criterion Channel, Charlotte Gainsbourg and ‘Queens of Mystery’',
#   'abstract': 'A classic movie streaming service arrives; a singer tours in Brooklyn; and Acorn TV debuts a new series.',
#   'url': 'https://www.nytimes.com/2019/04/06/arts/the-week-in-arts-the-criterion-channel-charlotte-gainsbourg-and-queens-of-mystery.html',
#   'byline': 'By THE NEW YORK TIMES',
#   'item_type': 'Article',
#   'updated_date': '2019-04-06T02:00:06-04:00',
#   'created_date': '2019-04-06T02:00:06-04:00',
#   'published_date': '2019-04-06T02:00:06-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Culture (Arts)',
#    'Rest (Album)',
#    'Queens of Mystery (TV Program)'],
#   'org_facet': ['Acorn TV',
#    'American Composers Orchestra',
#    'Brooklyn Steel (Brooklyn, NY, Music Venue)',
#    'Carnegie Hall',
#    'Criterion Collection',
#    'Performance Space New York (Manhattan, NY)',
#    'Public Theater'],
#   'per_facet': ['Gainsbourg, Charlotte', 'Jorn, Asger (1914-73)'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/arts/07week-film/07week-film-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Gloria Grahame and Glenn Ford in &ldquo;The Big Heat.&rdquo;',
#     'copyright': 'Columbia Pictures, via The Criterion Channel'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07week-film/07week-film-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Gloria Grahame and Glenn Ford in &ldquo;The Big Heat.&rdquo;',
#     'copyright': 'Columbia Pictures, via The Criterion Channel'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07week-film/merlin_152602617_27833eb4-1fb5-4a50-945a-4a7af022ee65-articleInline.jpg',
#     'format': 'Normal',
#     'height': 138,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Gloria Grahame and Glenn Ford in &ldquo;The Big Heat.&rdquo;',
#     'copyright': 'Columbia Pictures, via The Criterion Channel'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07week-film/07week-film-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Gloria Grahame and Glenn Ford in &ldquo;The Big Heat.&rdquo;',
#     'copyright': 'Columbia Pictures, via The Criterion Channel'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07week-film/merlin_152602617_27833eb4-1fb5-4a50-945a-4a7af022ee65-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1160,
#     'width': 1600,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Gloria Grahame and Glenn Ford in &ldquo;The Big Heat.&rdquo;',
#     'copyright': 'Columbia Pictures, via The Criterion Channel'}],
#   'short_url': 'https://nyti.ms/2G2NXhw'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': 'Issa Rae Is Learning to Make Her Big Voice Heard',
#   'abstract': 'She talks about “Little,” her new film with Regina Hall and Marsai Martin; the future of “Insecure” — including a drinks- and pool-fueled discussion of its end — and a golden moment for black women.',
#   'url': 'https://www.nytimes.com/2019/04/05/movies/issa-rae-insecure-future.html',
#   'byline': 'By KATHRYN SHATTUCK',
#   'item_type': 'Article',
#   'updated_date': '2019-04-05T18:26:51-04:00',
#   'created_date': '2019-04-05T10:00:01-04:00',
#   'published_date': '2019-04-05T10:00:01-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Television',
#    'Movies',
#    'Actors and Actresses',
#    'Blacks',
#    'Insecure (TV Program)',
#    'Little (Movie)',
#    'The Hate U Give (Movie)'],
#   'org_facet': [],
#   'per_facet': ['Rae, Issa'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/arts/07snapshot/07snapshot-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Rozette Rago for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07snapshot/07snapshot-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Rozette Rago for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07snapshot/07snapshot-articleInline.jpg',
#     'format': 'Normal',
#     'height': 253,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Rozette Rago for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07snapshot/07snapshot-mediumThreeByTwo210-v2.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Rozette Rago for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/arts/07snapshot/07snapshot-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 2048,
#     'width': 1537,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Rozette Rago for The New York Times'}],
#   'short_url': 'https://nyti.ms/2VqOqPZ'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': '‘Unicorn Store’ Review: When It’s Never Time to Put Away Childish Things',
#   'abstract': 'The message of the movie, directed by and starring Brie Larson, is that there’s no one-size-fits-all formula for adulthood.',
#   'url': 'https://www.nytimes.com/2019/04/05/movies/unicorn-store-review.html',
#   'byline': 'By SCOTT TOBIAS',
#   'item_type': 'Article',
#   'updated_date': '2019-04-05T09:54:55-04:00',
#   'created_date': '2019-04-05T09:54:55-04:00',
#   'published_date': '2019-04-05T09:54:55-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies'],
#   'org_facet': ['Netflix Inc'],
#   'per_facet': ['Larson, Brie', 'Jackson, Samuel L'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/05unicornstore/05unicornstore-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Samuel L. Jackson and Brie Larson in “Unicorn Store,” on Netflix. Larson also directed the film.',
#     'copyright': 'Logan White/Netflix'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05unicornstore/05unicornstore-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Samuel L. Jackson and Brie Larson in “Unicorn Store,” on Netflix. Larson also directed the film.',
#     'copyright': 'Logan White/Netflix'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05unicornstore/merlin_152975937_cec78afc-47a9-49fa-8856-f17796c7c222-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Samuel L. Jackson and Brie Larson in “Unicorn Store,” on Netflix. Larson also directed the film.',
#     'copyright': 'Logan White/Netflix'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05unicornstore/merlin_152975937_cec78afc-47a9-49fa-8856-f17796c7c222-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Samuel L. Jackson and Brie Larson in “Unicorn Store,” on Netflix. Larson also directed the film.',
#     'copyright': 'Logan White/Netflix'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05unicornstore/merlin_152975937_cec78afc-47a9-49fa-8856-f17796c7c222-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Samuel L. Jackson and Brie Larson in “Unicorn Store,” on Netflix. Larson also directed the film.',
#     'copyright': 'Logan White/Netflix'}],
#   'short_url': 'https://nyti.ms/2CVJ9ss'},
#  {'section': 'Arts',
#   'subsection': 'Art & Design',
#   'title': '‘Hamilton’ Set Designer Goes Whimsical, Using Sotheby’s Galleries as a Stage',
#   'abstract': 'David Korins is bringing some of Chatsworth House, the stately home from the movie “Pride and Prejudice,” to New York — for a show at Sotheby’s.',
#   'url': 'https://www.nytimes.com/2019/04/05/arts/design/sothebys-hamilton-chatsworth-house.html',
#   'byline': 'By SOPHIE HAIGNEY',
#   'item_type': 'Article',
#   'updated_date': '2019-04-05T00:01:06-04:00',
#   'created_date': '2019-04-05T00:01:06-04:00',
#   'published_date': '2019-04-05T00:01:06-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Art',
#    'Historic Buildings and Sites',
#    'Theater',
#    'Movies',
#    'Pride and Prejudice (Movie)',
#    'Treasures From Chatsworth (Exhibit)',
#    'the Devonshire Collection'],
#   'org_facet': ["Sotheby's", 'Chatsworth House (Derbyshire, England)'],
#   'per_facet': ['Korins, David'],
#   'geo_facet': ['New York City'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/04/arts/04chatsworth-item-3-rendering/04chatsworth-item-3-rendering-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A rendering of the galleries for “Treasures From Chatsworth,” for which David Korins magnified details — like table legs, moldings, chair feet — for vitrines and set pieces for the display.',
#     'copyright': 'Rendering courtesy of David Korins'},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/arts/04chatsworth-item-3-rendering/04chatsworth-item-3-rendering-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A rendering of the galleries for “Treasures From Chatsworth,” for which David Korins magnified details — like table legs, moldings, chair feet — for vitrines and set pieces for the display.',
#     'copyright': 'Rendering courtesy of David Korins'},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/arts/04chatsworth-item-3-rendering/04chatsworth-item-3-rendering-articleInline.jpg',
#     'format': 'Normal',
#     'height': 88,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A rendering of the galleries for “Treasures From Chatsworth,” for which David Korins magnified details — like table legs, moldings, chair feet — for vitrines and set pieces for the display.',
#     'copyright': 'Rendering courtesy of David Korins'},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/arts/04chatsworth-item-3-rendering/04chatsworth-item-3-rendering-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A rendering of the galleries for “Treasures From Chatsworth,” for which David Korins magnified details — like table legs, moldings, chair feet — for vitrines and set pieces for the display.',
#     'copyright': 'Rendering courtesy of David Korins'},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/arts/04chatsworth-item-3-rendering/04chatsworth-item-3-rendering-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 631,
#     'width': 1365,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A rendering of the galleries for “Treasures From Chatsworth,” for which David Korins magnified details — like table legs, moldings, chair feet — for vitrines and set pieces for the display.',
#     'copyright': 'Rendering courtesy of David Korins'}],
#   'short_url': 'https://nyti.ms/2Ia67zo'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': '4 Film Series to Catch in N.Y.C. This Weekend',
#   'abstract': 'Our guide to film series and special screenings.',
#   'url': 'https://www.nytimes.com/2019/04/04/movies/nyc-this-weekend-film-series.html',
#   'byline': 'By BEN KENIGSBERG',
#   'item_type': 'Article',
#   'updated_date': '2019-04-04T17:00:08-04:00',
#   'created_date': '2019-04-04T17:00:08-04:00',
#   'published_date': '2019-04-04T17:00:08-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies'],
#   'org_facet': [],
#   'per_facet': [],
#   'geo_facet': ['New York City'],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/05LISTINGS-FILM/05LISTINGS-FILM-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Kurt Russell in “Breakdown,” one of several big-rig-themed films screening for Jammin’ Gears: Truckers on Film, at Anthology Film Archives until April 21.',
#     'copyright': 'Paramount Pictures'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05LISTINGS-FILM/05LISTINGS-FILM-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Kurt Russell in “Breakdown,” one of several big-rig-themed films screening for Jammin’ Gears: Truckers on Film, at Anthology Film Archives until April 21.',
#     'copyright': 'Paramount Pictures'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05LISTINGS-FILM/merlin_152968686_46b9249e-61ce-4e70-b254-891f223d8527-articleInline.jpg',
#     'format': 'Normal',
#     'height': 107,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Kurt Russell in “Breakdown,” one of several big-rig-themed films screening for Jammin’ Gears: Truckers on Film, at Anthology Film Archives until April 21.',
#     'copyright': 'Paramount Pictures'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05LISTINGS-FILM/05LISTINGS-FILM-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Kurt Russell in “Breakdown,” one of several big-rig-themed films screening for Jammin’ Gears: Truckers on Film, at Anthology Film Archives until April 21.',
#     'copyright': 'Paramount Pictures'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05LISTINGS-FILM/merlin_152968686_46b9249e-61ce-4e70-b254-891f223d8527-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1152,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Kurt Russell in “Breakdown,” one of several big-rig-themed films screening for Jammin’ Gears: Truckers on Film, at Anthology Film Archives until April 21.',
#     'copyright': 'Paramount Pictures'}],
#   'short_url': 'https://nyti.ms/2uIZnAI'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': '‘Peterloo’ Review: Political Violence of the Past Mirrors the Present',
#   'abstract': 'Mike Leigh’s historical drama has the sweep of Tolstoy and the bustling energy of Dickens.',
#   'url': 'https://www.nytimes.com/2019/04/04/movies/peterloo-review.html',
#   'byline': 'By A.O. SCOTT',
#   'item_type': 'Article',
#   'updated_date': '2019-04-04T12:47:37-04:00',
#   'created_date': '2019-04-04T11:58:33-04:00',
#   'published_date': '2019-04-04T11:58:33-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies', 'Peterloo (Movie)'],
#   'org_facet': [],
#   'per_facet': ['Leigh, Mike', 'Kinnear, Rory'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/05peterloo/05peterloo-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mike Leigh&rsquo;s new movie, &ldquo;Peterloo,&rdquo; is filled with images of oppression and fiery exhortations to revolt.',
#     'copyright': 'Simon Mein/Amazon Studios'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05peterloo/05peterloo-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mike Leigh&rsquo;s new movie, &ldquo;Peterloo,&rdquo; is filled with images of oppression and fiery exhortations to revolt.',
#     'copyright': 'Simon Mein/Amazon Studios'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05peterloo/merlin_152838888_fc67ae89-4a23-40a8-9e17-4bdc9556f099-articleInline.jpg',
#     'format': 'Normal',
#     'height': 107,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mike Leigh&rsquo;s new movie, &ldquo;Peterloo,&rdquo; is filled with images of oppression and fiery exhortations to revolt.',
#     'copyright': 'Simon Mein/Amazon Studios'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05peterloo/05peterloo-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mike Leigh&rsquo;s new movie, &ldquo;Peterloo,&rdquo; is filled with images of oppression and fiery exhortations to revolt.',
#     'copyright': 'Simon Mein/Amazon Studios'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/05peterloo/merlin_152838888_fc67ae89-4a23-40a8-9e17-4bdc9556f099-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1152,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Mike Leigh&rsquo;s new movie, &ldquo;Peterloo,&rdquo; is filled with images of oppression and fiery exhortations to revolt.',
#     'copyright': 'Simon Mein/Amazon Studios'}],
#   'short_url': 'https://nyti.ms/2UtIXLa'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': '‘The Fate of Lee Khan’ Review: King Hu Directs Angela Mao',
#   'abstract': 'Lady Kung Fu and a renowned wuxia director in their only feature together, this restored 1973 film.',
#   'url': 'https://www.nytimes.com/2019/04/04/movies/the-fate-of-lee-khan-review.html',
#   'byline': 'By GLENN KENNY',
#   'item_type': 'Article',
#   'updated_date': '2019-04-04T22:11:13-04:00',
#   'created_date': '2019-04-04T07:00:05-04:00',
#   'published_date': '2019-04-04T07:00:05-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies', 'The Fate of Lee Khan (Movie)'],
#   'org_facet': [],
#   'per_facet': ['Hu, King', 'Mao, Angela (1950- )'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/04fateofleepix/04fateofleepix-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Left to right, Angela Mao, Chin Hu and Helen Ma in the restored film "The Fate of Lee Khan."',
#     'copyright': 'Film Movement Classics'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04fateofleepix/04fateofleepix-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Left to right, Angela Mao, Chin Hu and Helen Ma in the restored film "The Fate of Lee Khan."',
#     'copyright': 'Film Movement Classics'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04fateofleepix/merlin_152838666_3bd38ad0-8dab-4e67-9e58-8f452ba09566-articleInline.jpg',
#     'format': 'Normal',
#     'height': 119,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Left to right, Angela Mao, Chin Hu and Helen Ma in the restored film "The Fate of Lee Khan."',
#     'copyright': 'Film Movement Classics'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04fateofleepix/04fateofleepix-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Left to right, Angela Mao, Chin Hu and Helen Ma in the restored film "The Fate of Lee Khan."',
#     'copyright': 'Film Movement Classics'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/04fateofleepix/merlin_152838666_3bd38ad0-8dab-4e67-9e58-8f452ba09566-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1200,
#     'width': 1920,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Left to right, Angela Mao, Chin Hu and Helen Ma in the restored film "The Fate of Lee Khan."',
#     'copyright': 'Film Movement Classics'}],
#   'short_url': 'https://nyti.ms/2K61CJ3'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': '‘Storm Boy’ Review: Raising Pelicans in a Film That Never Fully Takes Flight',
#   'abstract': 'The film tries to present itself as a modern fable, but the themes come across as didactic rather than moving.',
#   'url': 'https://www.nytimes.com/2019/04/04/movies/storm-boy-review.html',
#   'byline': 'By TEO BUGBEE',
#   'item_type': 'Article',
#   'updated_date': '2019-04-04T07:00:05-04:00',
#   'created_date': '2019-04-04T07:00:05-04:00',
#   'published_date': '2019-04-04T07:00:05-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies', 'Storm Boy (Movie)'],
#   'org_facet': [],
#   'per_facet': ['Rush, Geoffrey', 'Seet, Shawn'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/04/arts/04stormboy/04stormboy-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Finn Little in “Storm Boy.”',
#     'copyright': 'Matt Nettheim/Good Deed Entertainment'},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/arts/04stormboy/04stormboy-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Finn Little in “Storm Boy.”',
#     'copyright': 'Matt Nettheim/Good Deed Entertainment'},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/arts/04stormboy/merlin_152839785_79db8663-673e-4665-a7a4-75c324a1a3a1-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
# ...
#     'copyright': 'Matt Rourke/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/02/arts/02neh-item/merlin_152733675_2df331a7-be96-4ebf-9ec4-24ff2a73e011-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The steeple lantern of Christ Church in Philadelphia. The church was awarded a grant by the National Endowment for the Humanities to restore its steeple and church tower.',
#     'copyright': 'Matt Rourke/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/02/arts/02neh-item/merlin_152733675_2df331a7-be96-4ebf-9ec4-24ff2a73e011-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The steeple lantern of Christ Church in Philadelphia. The church was awarded a grant by the National Endowment for the Humanities to restore its steeple and church tower.',
#     'copyright': 'Matt Rourke/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/02/arts/02neh-item/merlin_152733675_2df331a7-be96-4ebf-9ec4-24ff2a73e011-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The steeple lantern of Christ Church in Philadelphia. The church was awarded a grant by the National Endowment for the Humanities to restore its steeple and church tower.',
#     'copyright': 'Matt Rourke/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/02/arts/02neh-item/merlin_152733675_2df331a7-be96-4ebf-9ec4-24ff2a73e011-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1365,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The steeple lantern of Christ Church in Philadelphia. The church was awarded a grant by the National Endowment for the Humanities to restore its steeple and church tower.',
#     'copyright': 'Matt Rourke/Associated Press'}],
#   'short_url': 'https://nyti.ms/2UkDrdG'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': 'From the Boxing Ring to ‘Dumbo’: Michael Buffer Is Still Ready to Rumble',
#   'abstract': 'You might not recognize his name, but you definitely recognize his voice. Michael Buffer came up with one of the most recognizable catchphrases in history and has continued cashing in since.',
#   'url': 'https://www.nytimes.com/2019/04/02/movies/dumbo-michael-buffer-lets-get-ready-to-rumble.html',
#   'byline': 'By SOPAN DEB',
#   'item_type': 'Article',
#   'updated_date': '2019-04-02T11:18:40-04:00',
#   'created_date': '2019-04-02T11:18:40-04:00',
#   'published_date': '2019-04-02T11:18:40-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies', 'Dumbo (Movie)'],
#   'org_facet': ['Walt Disney Company'],
#   'per_facet': ['Burton, Tim'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/03/arts/02dumbo-buffer-2/02dumbo-buffer-2-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Michael Buffer in &ldquo;Dumbo.&rdquo;',
#     'copyright': 'Jay Maidment/Disney'},
#    {'url': 'https://static01.nyt.com/images/2019/04/03/arts/02dumbo-buffer-2/02dumbo-buffer-2-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Michael Buffer in &ldquo;Dumbo.&rdquo;',
#     'copyright': 'Jay Maidment/Disney'},
#    {'url': 'https://static01.nyt.com/images/2019/04/03/arts/02dumbo-buffer-2/merlin_152940573_f57757a2-0f19-475d-a557-84d96892aee0-articleInline.jpg',
#     'format': 'Normal',
#     'height': 132,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Michael Buffer in &ldquo;Dumbo.&rdquo;',
#     'copyright': 'Jay Maidment/Disney'},
#    {'url': 'https://static01.nyt.com/images/2019/04/03/arts/02dumbo-buffer-2/02dumbo-buffer-2-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Michael Buffer in &ldquo;Dumbo.&rdquo;',
#     'copyright': 'Jay Maidment/Disney'},
#    {'url': 'https://static01.nyt.com/images/2019/04/03/arts/02dumbo-buffer-2/merlin_152940573_f57757a2-0f19-475d-a557-84d96892aee0-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1419,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Michael Buffer in &ldquo;Dumbo.&rdquo;',
#     'copyright': 'Jay Maidment/Disney'}],
#   'short_url': 'https://nyti.ms/2uGqNHm'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': '‘Christ Stopped at Eboli’: An Italian Saga Returns in Full',
#   'abstract': 'Francesco Rosi’s adaptation of Carlo Levi’s best-selling memoir, “Christ Stopped at Eboli,” is an absorbing immersion in peasant poverty under Fascism.',
#   'url': 'https://www.nytimes.com/2019/04/02/movies/christ-stopped-at-eboli-levi-rosi.html',
#   'byline': 'By J. HOBERMAN',
#   'item_type': 'Article',
#   'updated_date': '2019-04-02T10:00:04-04:00',
#   'created_date': '2019-04-02T10:00:04-04:00',
#   'published_date': '2019-04-02T10:00:04-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies',
#    'Christ Stopped at Eboli (Movie)',
#    'Italian Language'],
#   'org_facet': ['Film Forum'],
#   'per_facet': ['Rosi, Francesco', 'Levi, Carlo'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/arts/02rewind/03rewind-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Paolo Bonacelli, left, as a pro-Fascist mayor, and Gian Maria Volont&egrave; as the exiled writer Carlo Levi in &ldquo;Christ Stopped at Eboli,&rdquo; a film adaptation of Levi&rsquo;s memoir directed by Francesco Rosi.',
#     'copyright': 'Rialto Pictures'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/02rewind/03rewind-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Paolo Bonacelli, left, as a pro-Fascist mayor, and Gian Maria Volont&egrave; as the exiled writer Carlo Levi in &ldquo;Christ Stopped at Eboli,&rdquo; a film adaptation of Levi&rsquo;s memoir directed by Francesco Rosi.',
#     'copyright': 'Rialto Pictures'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/02rewind/merlin_152789544_fcbc5015-a424-4122-8ce3-eff6e889e2af-articleInline.jpg',
#     'format': 'Normal',
#     'height': 152,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Paolo Bonacelli, left, as a pro-Fascist mayor, and Gian Maria Volont&egrave; as the exiled writer Carlo Levi in &ldquo;Christ Stopped at Eboli,&rdquo; a film adaptation of Levi&rsquo;s memoir directed by Francesco Rosi.',
#     'copyright': 'Rialto Pictures'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/02rewind/03rewind-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Paolo Bonacelli, left, as a pro-Fascist mayor, and Gian Maria Volont&egrave; as the exiled writer Carlo Levi in &ldquo;Christ Stopped at Eboli,&rdquo; a film adaptation of Levi&rsquo;s memoir directed by Francesco Rosi.',
#     'copyright': 'Rialto Pictures'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/arts/02rewind/merlin_152789544_fcbc5015-a424-4122-8ce3-eff6e889e2af-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1643,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Paolo Bonacelli, left, as a pro-Fascist mayor, and Gian Maria Volont&egrave; as the exiled writer Carlo Levi in &ldquo;Christ Stopped at Eboli,&rdquo; a film adaptation of Levi&rsquo;s memoir directed by Francesco Rosi.',
#     'copyright': 'Rialto Pictures'}],
#   'short_url': 'https://nyti.ms/2UolAmc'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': '‘Wall’ Review: A Writer Reflects on Borders',
#   'abstract': 'In the animated feature “Wall,” David Hare meditates on the partition that divides Israel and the West Bank.',
#   'url': 'https://www.nytimes.com/2019/04/02/movies/the-wall-review.html',
#   'byline': 'By BEN KENIGSBERG',
#   'item_type': 'Article',
#   'updated_date': '2019-04-02T07:00:01-04:00',
#   'created_date': '2019-04-02T07:00:01-04:00',
#   'published_date': '2019-04-02T07:00:01-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies', 'Wall (Movie)'],
#   'org_facet': [],
#   'per_facet': ['Hare, David'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/03/arts/wall1/wall1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The writer David Hare in the animated film &ldquo;Wall.&rdquo;',
#     'copyright': 'The National Film Board of Canada'},
#    {'url': 'https://static01.nyt.com/images/2019/04/03/arts/wall1/wall1-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The writer David Hare in the animated film &ldquo;Wall.&rdquo;',
#     'copyright': 'The National Film Board of Canada'},
#    {'url': 'https://static01.nyt.com/images/2019/04/03/arts/wall1/wall1-articleInline.jpg',
#     'format': 'Normal',
#     'height': 107,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The writer David Hare in the animated film &ldquo;Wall.&rdquo;',
#     'copyright': 'The National Film Board of Canada'},
#    {'url': 'https://static01.nyt.com/images/2019/04/03/arts/wall1/wall1-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The writer David Hare in the animated film &ldquo;Wall.&rdquo;',
#     'copyright': 'The National Film Board of Canada'},
#    {'url': 'https://static01.nyt.com/images/2019/04/03/arts/wall1/wall1-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1152,
#     'width': 2048,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The writer David Hare in the animated film &ldquo;Wall.&rdquo;',
#     'copyright': 'The National Film Board of Canada'}],
#   'short_url': 'https://nyti.ms/2uCk4OO'},
#  {'section': 'Style',
#   'subsection': '',
#   'title': 'Confirm or Deny: Sam Rockwell',
#   'abstract': 'More on the actor’s friends and influences.',
#   'url': 'https://www.nytimes.com/2019/04/01/style/confirm-or-deny-sam-rockwell.html',
#   'byline': 'By MAUREEN DOWD',
#   'item_type': 'Article',
#   'updated_date': '2019-04-04T00:52:01-04:00',
#   'created_date': '2019-04-01T11:38:18-04:00',
#   'published_date': '2019-04-01T11:38:18-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies', 'Television', 'Actors and Actresses'],
#   'org_facet': [],
#   'per_facet': ['Rockwell, Sam'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/04/fashion/01CONFIRMORDENY2/01CONFIRMORDENY2-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Sam Rockwell',
#     'copyright': 'Daniel Dorsa for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/01CONFIRMORDENY2/01CONFIRMORDENY2-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Sam Rockwell',
#     'copyright': 'Daniel Dorsa for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/01CONFIRMORDENY2/merlin_152280909_1f3ecfe4-006c-4d19-a117-e64380a4e58f-articleInline.jpg',
#     'format': 'Normal',
#     'height': 238,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Sam Rockwell',
#     'copyright': 'Daniel Dorsa for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/01CONFIRMORDENY2/merlin_152280909_1f3ecfe4-006c-4d19-a117-e64380a4e58f-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Sam Rockwell',
#     'copyright': 'Daniel Dorsa for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/04/fashion/01CONFIRMORDENY2/merlin_152280909_1f3ecfe4-006c-4d19-a117-e64380a4e58f-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 2048,
#     'width': 1639,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Sam Rockwell',
#     'copyright': 'Daniel Dorsa for The New York Times'}],
#   'short_url': 'https://nyti.ms/2FTUvy3'},
#  {'section': 'Movies',
#   'subsection': '',
#   'title': '‘Dumbo’ Falls Short of Box-Office Expectations but Still Comes in First',
#   'abstract': 'Tim Burton’s moody Disney remake sold $45 million in tickets in its first weekend. And Jordan Peele’s “Us” has crossed well over the $100 million mark.',
#   'url': 'https://www.nytimes.com/2019/03/31/movies/dumbo-box-office-us.html',
#   'byline': 'By GABE COHN',
#   'item_type': 'Article',
#   'updated_date': '2019-03-31T15:12:31-04:00',
#   'created_date': '2019-03-31T15:12:31-04:00',
#   'published_date': '2019-03-31T15:12:31-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Movies', 'Dumbo (Movie)', 'Us (Movie)'],
#   'org_facet': ['Walt Disney Company'],
#   'per_facet': ['Burton, Tim', 'Peele, Jordan'],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/03/31/arts/31boxoffice-item/merlin_152482068_a6ae7443-f57a-4c35-b4f0-c296cea46a4a-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'From left, Danny DeVito, Nico Parker and Colin Farrell in “Dumbo,” the latest live-action remake of an animated Disney classic.',
#     'copyright': 'Jay Maidment/Disney'},
#    {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31boxoffice-item/merlin_152482068_a6ae7443-f57a-4c35-b4f0-c296cea46a4a-thumbLarge.jpg',
#     'format': 'thumbLarge',
#     'height': 150,
#     'width': 150,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'From left, Danny DeVito, Nico Parker and Colin Farrell in “Dumbo,” the latest live-action remake of an animated Disney classic.',
#     'copyright': 'Jay Maidment/Disney'},
#    {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31boxoffice-item/merlin_152482068_a6ae7443-f57a-4c35-b4f0-c296cea46a4a-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'From left, Danny DeVito, Nico Parker and Colin Farrell in “Dumbo,” the latest live-action remake of an animated Disney classic.',
#     'copyright': 'Jay Maidment/Disney'},
#    {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31boxoffice-item/merlin_152482068_a6ae7443-f57a-4c35-b4f0-c296cea46a4a-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'From left, Danny DeVito, Nico Parker and Colin Farrell in “Dumbo,” the latest live-action remake of an animated Disney classic.',
#     'copyright': 'Jay Maidment/Disney'},
#    {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31boxoffice-item/merlin_152482068_a6ae7443-f57a-4c35-b4f0-c296cea46a4a-superJumbo.jpg',
#     'format': 'superJumbo',
#     'height': 1200,
#     'width': 1800,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'From left, Danny DeVito, Nico Parker and Colin Farrell in “Dumbo,” the latest live-action remake of an animated Disney classic.',
#     'copyright': 'Jay Maidment/Disney'}],
#   'short_url': 'https://nyti.ms/2WBRyc8'}]

# %%
#translates json data into a Pandas dataframe
m_reviews = pd.DataFrame(movie_res, columns=['section','subsection','title','abstract','url','byline','item_type',
                                             'updated_date','created_date','published_date','material_type_facet',
                                             'kicker'])
m_reviews
# Out:
#        section    subsection  \
# 0       Movies
# 1       Movies
# 2       Movies
# 3       Movies
# 4       Movies
# 5       Movies
# 6       Movies
# 7       Movies
# 8       Movies
# 9        Style
# 10        Arts
# 11      Movies
# 12      Movies
# 13        Arts  Art & Design
# 14      Movies
# 15      Movies
# 16      Movies
# 17      Movies
# 18      Movies
# 19      Movies
# 20      Movies
# 21      Movies
# 22      Movies
# 23       Style
# 24      Movies
# 25  Obituaries
# 26        Arts
# 27      Movies
# 28      Movies
# 29      Movies
# 30       Style
# 31      Movies
#
#                                                 title  \
# 0   ‘Shazam!’ Review: A Boy’s Supersized Alter Ego...
# 1   ‘Pet Sematary’ Review: An Unsettling New Take ...
# 2   The Agnès Varda I Knew: Showing Women Their Re...
# 3   ‘The Best of Enemies’ Review: A Klansman and a...
# 4   Watch a Boy Discover His Superpowers in ‘Shazam!’
# 5   ‘High Life’ Review: Robert Pattinson Is Lost i...
# 6   ‘Amazing Grace’ Review: Aretha Franklin Is Glo...
# 7              Shazam Is Back. Wait, Who Is He Again?
# 8   It May Be the Most Cursed Film Ever. These 5 C...
# 9                              Hot Topic Is Still Hot
# 10  The Week in Arts: The Criterion Channel, Charl...
# 11   Issa Rae Is Learning to Make Her Big Voice Heard
# 12  ‘Unicorn Store’ Review: When It’s Never Time t...
# 13  ‘Hamilton’ Set Designer Goes Whimsical, Using ...
# 14      4 Film Series to Catch in N.Y.C. This Weekend
# 15  ‘Peterloo’ Review: Political Violence of the P...
# 16  ‘The Fate of Lee Khan’ Review: King Hu Directs...
# 17  ‘Storm Boy’ Review: Raising Pelicans in a Film...
# 18  ‘The Public’ Review: Emilio Estevez Takes Us t...
# 19  ‘Blowin’ Up’ Review: In a Queens Courtroom, Hu...
# 20  ‘The Wind’ Review: Who’s That Knocking at My L...
# 21  ‘Reinventing Rosalee’ Review: A Centenarian Wh...
# 22  ‘Suburban Birds’ Review: A Spectacular Directi...
# 23  Stefania LaVie Owen, Snoop Dogg Co-Star and Vo...
# 24  Watch the ‘Joker’ Trailer: Joaquin Phoenix in ...
# 25  What They Left Behind: Creative Works by the R...
# 26  Humanities Endowment Announces New Grants Amid...
# 27  From the Boxing Ring to ‘Dumbo’: Michael Buffe...
# 28  ‘Christ Stopped at Eboli’: An Italian Saga Ret...
# 29        ‘Wall’ Review: A Writer Reflects on Borders
# 30                      Confirm or Deny: Sam Rockwell
# 31  ‘Dumbo’ Falls Short of Box-Office Expectations...
#
#                                              abstract  \
# 0   A nicely matched Asher Angel and Zachary Levi ...
# 1   This one has a smoother feel than the 1989 mov...
# 2   In encounters over the years, our critic met a...
# 3   Taraji P. Henson and Sam Rockwell star in a cl...
# 4   The director David F. Sandberg discusses a sce...
# 5   The director Claire Denis fills her science-fi...
# 6   The film Aretha Franklin didn’t want you to se...
# 7   Although many viewers may be unfamiliar with t...
# 8   Terry Gilliam’s “The Man Who Killed Don Quixot...
# 9   How has an enclave for emo kids and mall goths...
# 10  A classic movie streaming service arrives; a s...
# 11  She talks about “Little,” her new film with Re...
# 12  The message of the movie, directed by and star...
# 13  David Korins is bringing some of Chatsworth Ho...
# 14   Our guide to film series and special screenings.
# 15  Mike Leigh’s historical drama has the sweep of...
# 16  Lady Kung Fu and a renowned wuxia director in ...
# 17  The film tries to present itself as a modern f...
# 18  The movie’s literary virtues are up for debate...
# 19  Stephanie Wang-Breal’s fascinating documentary...
# 20  Emma Tammi’s atmospheric horror-Western shines...
# 21  The documentary focuses on a feisty woman who ...
# 22  In Qiu Sheng’s film, a team of engineers and a...
# 23  The young actress from New Zealand stars in “T...
# 24  The first clip for the movie, directed by “The...
# 25  Movies, a poem, a photograph, a sandwich: Some...
# 26  The National Endowment for the Humanities anno...
# 27  You might not recognize his name, but you defi...
# 28  Francesco Rosi’s adaptation of Carlo Levi’s be...
# 29  In the animated feature “Wall,” David Hare med...
# 30        More on the actor’s friends and influences.
# 31  Tim Burton’s moody Disney remake sold $45 mill...
#
#                                                   url                  byline  \
# 0   https://www.nytimes.com/2019/04/03/movies/shaz...       By MANOHLA DARGIS
# 1   https://www.nytimes.com/2019/04/04/movies/pet-...          By GLENN KENNY
# 2   https://www.nytimes.com/2019/04/02/movies/agne...       By MANOHLA DARGIS
# 3   https://www.nytimes.com/2019/04/03/movies/the-...           By A.O. SCOTT
# 4   https://www.nytimes.com/2019/04/05/movies/shaz...        By MEKADO MURPHY
# 5   https://www.nytimes.com/2019/04/04/movies/high...       By MANOHLA DARGIS
# 6   https://www.nytimes.com/2018/12/05/movies/amaz...        By WESLEY MORRIS
# 7   https://www.nytimes.com/2019/04/05/movies/shaz...         By DEVIN FULLER
# 8   https://www.nytimes.com/2019/04/04/movies/terr...            By SOPAN DEB
# 9   https://www.nytimes.com/2019/04/06/style/hot-t...          By PAULA MEJÍA
# 10  https://www.nytimes.com/2019/04/06/arts/the-we...   By THE NEW YORK TIMES
# 11  https://www.nytimes.com/2019/04/05/movies/issa...     By KATHRYN SHATTUCK
# 12  https://www.nytimes.com/2019/04/05/movies/unic...         By SCOTT TOBIAS
# 13  https://www.nytimes.com/2019/04/05/arts/design...       By SOPHIE HAIGNEY
# 14  https://www.nytimes.com/2019/04/04/movies/nyc-...       By BEN KENIGSBERG
# 15  https://www.nytimes.com/2019/04/04/movies/pete...           By A.O. SCOTT
# 16  https://www.nytimes.com/2019/04/04/movies/the-...          By GLENN KENNY
# 17  https://www.nytimes.com/2019/04/04/movies/stor...           By TEO BUGBEE
# 18  https://www.nytimes.com/2019/04/04/movies/the-...       By BEN KENIGSBERG
# 19  https://www.nytimes.com/2019/04/04/movies/blow...  By JEANNETTE CATSOULIS
# 20  https://www.nytimes.com/2019/04/04/movies/the-...  By JEANNETTE CATSOULIS
# 21  https://www.nytimes.com/2019/04/04/movies/rein...       By KEN JAWOROWSKI
# 22  https://www.nytimes.com/2019/04/04/movies/subu...          By GLENN KENNY
# 23  https://www.nytimes.com/2019/04/03/style/stefa...         By ALEX HAWGOOD
# 24  https://www.nytimes.com/2019/04/03/movies/joke...         By BRUCE FRETTS
# 25  https://www.nytimes.com/2019/04/02/obituaries/...      By DANIEL J. WAKIN
# 26  https://www.nytimes.com/2019/04/02/arts/nation...  By JENNIFER SCHUESSLER
# 27  https://www.nytimes.com/2019/04/02/movies/dumb...            By SOPAN DEB
# 28  https://www.nytimes.com/2019/04/02/movies/chri...          By J. HOBERMAN
# 29  https://www.nytimes.com/2019/04/02/movies/the-...       By BEN KENIGSBERG
# 30  https://www.nytimes.com/2019/04/01/style/confi...         By MAUREEN DOWD
# 31  https://www.nytimes.com/2019/03/31/movies/dumb...            By GABE COHN
#
#    item_type               updated_date               created_date  \
# 0    Article  2019-04-05T10:32:45-04:00  2019-04-03T17:47:11-04:00
# 1    Article  2019-04-04T13:17:17-04:00  2019-04-04T10:11:31-04:00
# 2    Article  2019-04-03T10:14:35-04:00  2019-04-02T14:51:25-04:00
# 3    Article  2019-04-04T09:43:05-04:00  2019-04-03T15:01:59-04:00
# 4    Article  2019-04-05T17:38:34-04:00  2019-04-05T07:02:01-04:00
# 5    Article  2019-04-04T12:27:22-04:00  2019-04-04T12:27:22-04:00
# 6    Article  2018-12-05T20:17:11-05:00  2018-12-05T20:17:11-05:00
# 7    Article  2019-04-05T11:00:01-04:00  2019-04-05T11:00:01-04:00
# 8    Article  2019-04-04T10:00:09-04:00  2019-04-04T10:00:09-04:00
# 9    Article  2019-04-06T06:00:02-04:00  2019-04-06T06:00:01-04:00
# 10   Article  2019-04-06T02:00:06-04:00  2019-04-06T02:00:06-04:00
# 11   Article  2019-04-05T18:26:51-04:00  2019-04-05T10:00:01-04:00
# 12   Article  2019-04-05T09:54:55-04:00  2019-04-05T09:54:55-04:00
# 13   Article  2019-04-05T00:01:06-04:00  2019-04-05T00:01:06-04:00
# 14   Article  2019-04-04T17:00:08-04:00  2019-04-04T17:00:08-04:00
# 15   Article  2019-04-04T12:47:37-04:00  2019-04-04T11:58:33-04:00
# 16   Article  2019-04-04T22:11:13-04:00  2019-04-04T07:00:05-04:00
# 17   Article  2019-04-04T07:00:05-04:00  2019-04-04T07:00:05-04:00
# 18   Article  2019-04-04T07:00:04-04:00  2019-04-04T07:00:04-04:00
# 19   Article  2019-04-04T07:00:01-04:00  2019-04-04T07:00:01-04:00
# 20   Article  2019-04-04T23:55:52-04:00  2019-04-04T07:00:01-04:00
# 21   Article  2019-04-04T07:00:01-04:00  2019-04-04T07:00:01-04:00
# 22   Article  2019-04-04T04:00:01-04:00  2019-04-04T04:00:01-04:00
# 23   Article  2019-04-04T00:50:54-04:00  2019-04-03T12:58:47-04:00
# 24   Article  2019-04-03T10:45:57-04:00  2019-04-03T10:45:57-04:00
# 25   Article  2019-04-02T14:35:08-04:00  2019-04-02T14:35:08-04:00
# 26   Article  2019-04-02T14:16:10-04:00  2019-04-02T14:16:10-04:00
# 27   Article  2019-04-02T11:18:40-04:00  2019-04-02T11:18:40-04:00
# 28   Article  2019-04-02T10:00:04-04:00  2019-04-02T10:00:04-04:00
# 29   Article  2019-04-02T07:00:01-04:00  2019-04-02T07:00:01-04:00
# 30   Article  2019-04-04T00:52:01-04:00  2019-04-01T11:38:18-04:00
# 31   Article  2019-03-31T15:12:31-04:00  2019-03-31T15:12:31-04:00
#
#                published_date material_type_facet kicker
# 0   2019-04-03T17:47:11-04:00
# 1   2019-04-04T10:11:31-04:00
# 2   2019-04-02T14:51:25-04:00
# 3   2019-04-03T15:01:59-04:00
# 4   2019-04-05T07:02:01-04:00
# 5   2019-04-04T12:27:22-04:00
# 6   2018-12-05T20:17:11-05:00
# 7   2019-04-05T11:00:01-04:00
# 8   2019-04-04T10:00:09-04:00
# 9   2019-04-06T06:00:01-04:00
# 10  2019-04-06T02:00:06-04:00
# 11  2019-04-05T10:00:01-04:00
# 12  2019-04-05T09:54:55-04:00
# 13  2019-04-05T00:01:06-04:00
# 14  2019-04-04T17:00:08-04:00
# 15  2019-04-04T11:58:33-04:00
# 16  2019-04-04T07:00:05-04:00
# 17  2019-04-04T07:00:05-04:00
# 18  2019-04-04T07:00:04-04:00
# 19  2019-04-04T07:00:01-04:00
# 20  2019-04-04T07:00:01-04:00
# 21  2019-04-04T07:00:01-04:00
# 22  2019-04-04T04:00:01-04:00
# 23  2019-04-03T12:58:47-04:00
# 24  2019-04-03T10:45:57-04:00
# 25  2019-04-02T14:35:08-04:00
# 26  2019-04-02T14:16:10-04:00
# 27  2019-04-02T11:18:40-04:00
# 28  2019-04-02T10:00:04-04:00
# 29  2019-04-02T07:00:01-04:00
# 30  2019-04-01T11:38:18-04:00
# 31  2019-03-31T15:12:31-04:00

# %% [markdown]
# #### Dataset 2: ####
# This dataset came from the NYT and lists out all the names or categories of the books that is then used for searching or filtering dataset by category.

# %%
#use requests library and call get method to access URL and open the API
books_cat = requests.get('https://api.nytimes.com/svc/books/v3/lists/names.json?api-key=GsQu4h8IDfExzCiiJWehGDgRPEQ9Ajka')
print(books_cat.text)
# Out:
# {"status":"OK","copyright":"Copyright (c) 2019 The New York Times Company.  All Rights Reserved.","num_results":55,"results":[{"list_name":"Combined Print and E-Book Fiction","display_name":"Combined Print & E-Book Fiction","list_name_encoded":"combined-print-and-e-book-fiction","oldest_published_date":"2011-02-13","newest_published_date":"2019-04-14","updated":"WEEKLY"},{"list_name":"Combined Print and E-Book Nonfiction","display_name":"Combined Print & E-Book Nonfiction","list_name_encoded":"combined-print-and-e-book-nonfiction","oldest_published_date":"2011-02-13","newest_published_date":"2019-04-14","updated":"WEEKLY"},{"list_name":"Hardcover Fiction","display_name":"Hardcover Fiction","list_name_encoded":"hardcover-fiction","oldest_published_date":"2008-06-08","newest_published_date":"2019-04-14","updated":"WEEKLY"},{"list_name":"Hardcover Nonfiction","display_name":"Hardcover Nonfiction","list_name_encoded":"hardcover-nonfiction","oldest_published_date":"2008-06-08","newest_published_date":"2019-04-14","updated":"WEEKLY"},{"list_name":"Trade Fiction Paperback","display_name":"Paperback Trade Fiction","list_name_encoded":"trade-fiction-paperback","oldest_published_date":"2008-06-08","newest_published_date":"2019-04-14","updated":"WEEKLY"},{"list_name":"Mass Market Paperback","display_name":"Paperback Mass-Market Fiction","list_name_encoded":"mass-market-paperback","oldest_published_date":"2008-06-08","newest_published_date":"2017-01-29","updated":"WEEKLY"},{"list_name":"Paperback Nonfiction","display_name":"Paperback Nonfiction","list_name_encoded":"paperback-nonfiction","oldest_published_date":"2008-06-08","newest_published_date":"2019-04-14","updated":"WEEKLY"},{"list_name":"E-Book Fiction","display_name":"E-Book Fiction","list_name_encoded":"e-book-fiction","oldest_published_date":"2011-02-13","newest_published_date":"2017-01-29","updated":"WEEKLY"},{"list_name":"E-Book Nonfiction","display_name":"E-Book Nonfiction","list_name_encoded":"e-book-nonfiction","oldest_published_date":"2011-02-13","newest_published_date":"2017-01-29","updated":"WEEKLY"},{"list_name":"Hardcover Advice","display_name":"Hardcover Advice & Misc.","list_name_encoded":"hardcover-advice","oldest_published_date":"2008-06-08","newest_published_date":"2013-04-21","updated":"WEEKLY"},{"list_name":"Paperback Advice","display_name":"Paperback Advice & Misc.","list_name_encoded":"paperback-advice","oldest_published_date":"2008-06-08","newest_published_date":"2013-04-21","updated":"WEEKLY"},{"list_name":"Advice How-To and Miscellaneous","display_name":"Advice, How-To & Miscellaneous","list_name_encoded":"advice-how-to-and-miscellaneous","oldest_published_date":"2013-04-28","newest_published_date":"2019-04-14","updated":"WEEKLY"},{"list_name":"Chapter Books","display_name":"Children\u2019s Chapter Books","list_name_encoded":"chapter-books","oldest_published_date":"2008-06-08","newest_published_date":"2012-12-09","updated":"WEEKLY"},{"list_name":"Childrens Middle Grade","display_name":"Children\u2019s Middle Grade","list_name_encoded":"childrens-middle-grade","oldest_published_date":"2012-12-16","newest_published_date":"2015-08-23","updated":"WEEKLY"},{"list_name":"Childrens Middle Grade E-Book","display_name":"Children\u2019s Middle Grade E-Book","list_name_encoded":"childrens-middle-grade-e-book","oldest_published_date":"2015-08-30","newest_published_date":"2017-01-29","updated":"WEEKLY"},{"list_name":"Childrens Middle Grade Hardcover","display_name":"Children\u2019s Middle Grade Hardcover","list_name_encoded":"childrens-middle-grade-hardcover","oldest_published_date":"2015-08-30","newest_published_date":"2019-04-14","updated":"WEEKLY"},{"list_name":"Childrens Middle Grade Paperback","display_name":"Children\u2019s Middle Grade Paperback","list_name_encoded":"childrens-middle-grade-paperback","oldest_published_date":"2015-08-30","newest_published_date":"2017-01-29","updated":"WEEKLY"},{"list_name":"Paperback Books","display_name":"Children\u2019s Paperback ...

# %%
#translates data into a readable json file
books = books_cat.json()
books
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company.  All Rights Reserved.',
#  'num_results': 55,
#  'results': [{'list_name': 'Combined Print and E-Book Fiction',
#    'display_name': 'Combined Print & E-Book Fiction',
#    'list_name_encoded': 'combined-print-and-e-book-fiction',
#    'oldest_published_date': '2011-02-13',
#    'newest_published_date': '2019-04-14',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Combined Print and E-Book Nonfiction',
#    'display_name': 'Combined Print & E-Book Nonfiction',
#    'list_name_encoded': 'combined-print-and-e-book-nonfiction',
#    'oldest_published_date': '2011-02-13',
#    'newest_published_date': '2019-04-14',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'list_name_encoded': 'hardcover-fiction',
#    'oldest_published_date': '2008-06-08',
#    'newest_published_date': '2019-04-14',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Hardcover Nonfiction',
#    'display_name': 'Hardcover Nonfiction',
#    'list_name_encoded': 'hardcover-nonfiction',
#    'oldest_published_date': '2008-06-08',
#    'newest_published_date': '2019-04-14',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Trade Fiction Paperback',
#    'display_name': 'Paperback Trade Fiction',
#    'list_name_encoded': 'trade-fiction-paperback',
#    'oldest_published_date': '2008-06-08',
#    'newest_published_date': '2019-04-14',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Mass Market Paperback',
#    'display_name': 'Paperback Mass-Market Fiction',
#    'list_name_encoded': 'mass-market-paperback',
#    'oldest_published_date': '2008-06-08',
#    'newest_published_date': '2017-01-29',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Paperback Nonfiction',
#    'display_name': 'Paperback Nonfiction',
#    'list_name_encoded': 'paperback-nonfiction',
#    'oldest_published_date': '2008-06-08',
#    'newest_published_date': '2019-04-14',
#    'updated': 'WEEKLY'},
#   {'list_name': 'E-Book Fiction',
#    'display_name': 'E-Book Fiction',
#    'list_name_encoded': 'e-book-fiction',
#    'oldest_published_date': '2011-02-13',
#    'newest_published_date': '2017-01-29',
#    'updated': 'WEEKLY'},
#   {'list_name': 'E-Book Nonfiction',
#    'display_name': 'E-Book Nonfiction',
#    'list_name_encoded': 'e-book-nonfiction',
#    'oldest_published_date': '2011-02-13',
#    'newest_published_date': '2017-01-29',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Hardcover Advice',
#    'display_name': 'Hardcover Advice & Misc.',
#    'list_name_encoded': 'hardcover-advice',
#    'oldest_published_date': '2008-06-08',
#    'newest_published_date': '2013-04-21',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Paperback Advice',
#    'display_name': 'Paperback Advice & Misc.',
#    'list_name_encoded': 'paperback-advice',
#    'oldest_published_date': '2008-06-08',
#    'newest_published_date': '2013-04-21',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Advice How-To and Miscellaneous',
#    'display_name': 'Advice, How-To & Miscellaneous',
#    'list_name_encoded': 'advice-how-to-and-miscellaneous',
#    'oldest_published_date': '2013-04-28',
#    'newest_published_date': '2019-04-14',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Chapter Books',
#    'display_name': 'Children’s Chapter Books',
#    'list_name_encoded': 'chapter-books',
#    'oldest_published_date': '2008-06-08',
#    'newest_published_date': '2012-12-09',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Childrens Middle Grade',
#    'display_name': 'Children’s Middle Grade',
#    'list_name_encoded': 'childrens-middle-grade',
#    'oldest_published_date': '2012-12-16',
#    'newest_published_date': '2015-08-23',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Childrens Middle Grade E-Book',
#    'display_name': 'Children’s Middle Grade E-Book',
#    'list_name_encoded': 'childrens-middle-grade-e-book',
#    'oldest_published_date': '2015-08-30',
#    'newest_published_date': '2017-01-29',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Childrens Middle Grade Hardcover',
#    'display_name': 'Children’s Middle Grade Hardcover',
#    'list_name_encoded': 'childrens-middle-grade-hardcover',
#    'oldest_published_date': '2015-08-30',
#    'newest_published_date': '2019-04-14',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Childrens Middle Grade Paperback',
#    'display_name': 'Children’s Middle Grade Paperback',
#    'list_name_encoded': 'childrens-middle-grade-paperback',
#    'oldest_published_date': '2015-08-30',
#    'newest_published_date': '2017-01-29',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Paperback Books',
#    'display_name': 'Children’s Paperback Books',
#    'list_name_encoded': 'paperback-books',
#    'oldest_published_date': '2008-06-08',
#    'newest_published_date': '2012-12-09',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Picture Books',
#    'display_name': 'Children’s Picture Books',
#    'list_name_encoded': 'picture-books',
#    'oldest_published_date': '2008-06-08',
#    'newest_published_date': '2019-04-14',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Series Books',
#    'display_name': 'Children’s Series',
#    'list_name_encoded': 'series-books',
#    'oldest_published_date': '2008-06-08',
#    'newest_published_date': '2019-04-14',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Young Adult',
#    'display_name': 'Young Adult',
#    'list_name_encoded': 'young-adult',
#    'oldest_published_date': '2012-12-16',
#    'newest_published_date': '2015-08-23',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Young Adult E-Book',
#    'display_name': 'Young Adult E-Book',
#    'list_name_encoded': 'young-adult-e-book',
#    'oldest_published_date': '2015-08-30',
#    'newest_published_date': '2017-01-29',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Young Adult Hardcover',
#    'display_name': 'Young Adult Hardcover',
#    'list_name_encoded': 'young-adult-hardcover',
#    'oldest_published_date': '2015-08-30',
#    'newest_published_date': '2019-04-14',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Young Adult Paperback',
#    'display_name': 'Young Adult Paperback',
#    'list_name_encoded': 'young-adult-paperback',
#    'oldest_published_date': '2015-08-30',
#    'newest_published_date': '2017-01-29',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Hardcover Graphic Books',
#    'display_name': 'Hardcover Graphic Books',
#    'list_name_encoded': 'hardcover-graphic-books',
#    'oldest_published_date': '2009-03-15',
#    'newest_published_date': '2017-01-29',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Paperback Graphic Books',
#    'display_name': 'Paperback Graphic Books',
#    'list_name_encoded': 'paperback-graphic-books',
#    'oldest_published_date': '2009-03-15',
#    'newest_published_date': '2017-01-29',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Manga',
#    'display_name': 'Manga',
#    'list_name_encoded': 'manga',
#    'oldest_published_date': '2009-03-15',
#    'newest_published_date': '2017-01-29',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Combined Print Fiction',
#    'display_name': 'Combined Hardcover & Paperback Fiction',
#    'list_name_encoded': 'combined-print-fiction',
#    'oldest_published_date': '2011-02-13',
#    'newest_published_date': '2013-05-12',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Combined Print Nonfiction',
#    'display_name': 'Combined Hardcover & Paperback Nonfiction',
#    'list_name_encoded': 'combined-print-nonfiction',
#    'oldest_published_date': '2011-02-13',
#    'newest_published_date': '2013-05-12',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Animals',
#    'display_name': 'Animals',
#    'list_name_encoded': 'animals',
#    'oldest_published_date': '2014-09-07',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Audio Fiction',
#    'display_name': 'Audio Fiction',
#    'list_name_encoded': 'audio-fiction',
#    'oldest_published_date': '2018-03-11',
#    'newest_published_date': '2019-04-14',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Audio Nonfiction',
#    'display_name': 'Audio Nonfiction',
#    'list_name_encoded': 'audio-nonfiction',
#    'oldest_published_date': '2018-03-11',
#    'newest_published_date': '2019-04-14',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Business Books',
#    'display_name': 'Business',
#    'list_name_encoded': 'business-books',
#    'oldest_published_date': '2013-11-03',
#    'newest_published_date': '2019-04-14',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Celebrities',
#    'display_name': 'Celebrities',
#    'list_name_encoded': 'celebrities',
#    'oldest_published_date': '2014-09-07',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Crime and Punishment',
#    'display_name': 'Crime and Punishment',
#    'list_name_encoded': 'crime-and-punishment',
#    'oldest_published_date': '2014-10-12',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Culture',
#    'display_name': 'Culture',
#    'list_name_encoded': 'culture',
#    'oldest_published_date': '2014-10-12',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Education',
#    'display_name': 'Education',
#    'list_name_encoded': 'education',
#    'oldest_published_date': '2014-10-12',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Espionage',
#    'display_name': 'Espionage',
#    'list_name_encoded': 'espionage',
#    'oldest_published_date': '2014-12-14',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Expeditions Disasters and Adventures',
#    'display_name': 'Expeditions',
#    'list_name_encoded': 'expeditions-disasters-and-adventures',
#    'oldest_published_date': '2014-12-14',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Fashion Manners and Customs',
#    'display_name': 'Fashion, Manners and Customs',
#    'list_name_encoded': 'fashion-manners-and-customs',
#    'oldest_published_date': '2014-10-12',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Food and Fitness',
#    'display_name': 'Food and Diet',
#    'list_name_encoded': 'food-and-fitness',
#    'oldest_published_date': '2013-09-01',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Games and Activities',
#    'display_name': 'Games and Activities',
#    'list_name_encoded': 'games-and-activities',
#    'oldest_published_date': '2014-10-12',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Hardcover Business Books',
#    'display_name': 'Hardcover Business Books',
#    'list_name_encoded': 'hardcover-business-books',
#    'oldest_published_date': '2011-07-03',
#    'newest_published_date': '2013-10-13',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Health',
#    'display_name': 'Health',
#    'list_name_encoded': 'health',
#    'oldest_published_date': '2014-10-12',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Humor',
#    'display_name': 'Humor',
#    'list_name_encoded': 'humor',
#    'oldest_published_date': '2014-09-07',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Indigenous Americans',
#    'display_name': 'Indigenous Americans',
#    'list_name_encoded': 'indigenous-americans',
#    'oldest_published_date': '2014-12-14',
#    'newest_published_date': '2016-01-10',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Relationships',
#    'display_name': 'Love and Relationships',
#    'list_name_encoded': 'relationships',
#    'oldest_published_date': '2014-09-07',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Paperback Business Books',
#    'display_name': 'Paperback Business Books',
#    'list_name_encoded': 'paperback-business-books',
#    'oldest_published_date': '2011-07-03',
#    'newest_published_date': '2013-10-13',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Family',
#    'display_name': 'Parenthood and Family',
#    'list_name_encoded': 'family',
#    'oldest_published_date': '2014-09-07',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Hardcover Political Books',
#    'display_name': 'Politics and American History',
#    'list_name_encoded': 'hardcover-political-books',
#    'oldest_published_date': '2011-07-03',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Race and Civil Rights',
#    'display_name': 'Race and Civil Rights',
#    'list_name_encoded': 'race-and-civil-rights',
#    'oldest_published_date': '2014-12-14',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Religion Spirituality and Faith',
#    'display_name': 'Religion, Spirituality and Faith',
#    'list_name_encoded': 'religion-spirituality-and-faith',
#    'oldest_published_date': '2014-09-07',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Science',
#    'display_name': 'Science',
#    'list_name_encoded': 'science',
#    'oldest_published_date': '2013-04-14',
#    'newest_published_date': '2019-04-14',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Sports',
#    'display_name': 'Sports and Fitness',
#    'list_name_encoded': 'sports',
#    'oldest_published_date': '2014-03-02',
#    'newest_published_date': '2019-04-14',
#    'updated': 'MONTHLY'},
#   {'list_name': 'Travel',
#    'display_name': 'Travel',
#    'list_name_encoded': 'travel',
#    'oldest_published_date': '2014-09-07',
#    'newest_published_date': '2017-01-15',
#    'updated': 'MONTHLY'}]}

# %%
#extract actual data from the json file
cat_res = books['results']
cat_res
# Out:
# [{'list_name': 'Combined Print and E-Book Fiction',
#   'display_name': 'Combined Print & E-Book Fiction',
#   'list_name_encoded': 'combined-print-and-e-book-fiction',
#   'oldest_published_date': '2011-02-13',
#   'newest_published_date': '2019-04-14',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Combined Print and E-Book Nonfiction',
#   'display_name': 'Combined Print & E-Book Nonfiction',
#   'list_name_encoded': 'combined-print-and-e-book-nonfiction',
#   'oldest_published_date': '2011-02-13',
#   'newest_published_date': '2019-04-14',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Hardcover Fiction',
#   'display_name': 'Hardcover Fiction',
#   'list_name_encoded': 'hardcover-fiction',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2019-04-14',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Hardcover Nonfiction',
#   'display_name': 'Hardcover Nonfiction',
#   'list_name_encoded': 'hardcover-nonfiction',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2019-04-14',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Trade Fiction Paperback',
#   'display_name': 'Paperback Trade Fiction',
#   'list_name_encoded': 'trade-fiction-paperback',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2019-04-14',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Mass Market Paperback',
#   'display_name': 'Paperback Mass-Market Fiction',
#   'list_name_encoded': 'mass-market-paperback',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Paperback Nonfiction',
#   'display_name': 'Paperback Nonfiction',
#   'list_name_encoded': 'paperback-nonfiction',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2019-04-14',
#   'updated': 'WEEKLY'},
#  {'list_name': 'E-Book Fiction',
#   'display_name': 'E-Book Fiction',
#   'list_name_encoded': 'e-book-fiction',
#   'oldest_published_date': '2011-02-13',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'E-Book Nonfiction',
#   'display_name': 'E-Book Nonfiction',
#   'list_name_encoded': 'e-book-nonfiction',
#   'oldest_published_date': '2011-02-13',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Hardcover Advice',
#   'display_name': 'Hardcover Advice & Misc.',
#   'list_name_encoded': 'hardcover-advice',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2013-04-21',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Paperback Advice',
#   'display_name': 'Paperback Advice & Misc.',
#   'list_name_encoded': 'paperback-advice',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2013-04-21',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Advice How-To and Miscellaneous',
#   'display_name': 'Advice, How-To & Miscellaneous',
#   'list_name_encoded': 'advice-how-to-and-miscellaneous',
#   'oldest_published_date': '2013-04-28',
#   'newest_published_date': '2019-04-14',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Chapter Books',
#   'display_name': 'Children’s Chapter Books',
#   'list_name_encoded': 'chapter-books',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2012-12-09',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Childrens Middle Grade',
#   'display_name': 'Children’s Middle Grade',
#   'list_name_encoded': 'childrens-middle-grade',
#   'oldest_published_date': '2012-12-16',
#   'newest_published_date': '2015-08-23',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Childrens Middle Grade E-Book',
#   'display_name': 'Children’s Middle Grade E-Book',
#   'list_name_encoded': 'childrens-middle-grade-e-book',
#   'oldest_published_date': '2015-08-30',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Childrens Middle Grade Hardcover',
#   'display_name': 'Children’s Middle Grade Hardcover',
#   'list_name_encoded': 'childrens-middle-grade-hardcover',
#   'oldest_published_date': '2015-08-30',
#   'newest_published_date': '2019-04-14',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Childrens Middle Grade Paperback',
#   'display_name': 'Children’s Middle Grade Paperback',
#   'list_name_encoded': 'childrens-middle-grade-paperback',
#   'oldest_published_date': '2015-08-30',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Paperback Books',
#   'display_name': 'Children’s Paperback Books',
#   'list_name_encoded': 'paperback-books',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2012-12-09',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Picture Books',
#   'display_name': 'Children’s Picture Books',
#   'list_name_encoded': 'picture-books',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2019-04-14',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Series Books',
#   'display_name': 'Children’s Series',
#   'list_name_encoded': 'series-books',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2019-04-14',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Young Adult',
#   'display_name': 'Young Adult',
#   'list_name_encoded': 'young-adult',
#   'oldest_published_date': '2012-12-16',
#   'newest_published_date': '2015-08-23',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Young Adult E-Book',
#   'display_name': 'Young Adult E-Book',
#   'list_name_encoded': 'young-adult-e-book',
#   'oldest_published_date': '2015-08-30',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Young Adult Hardcover',
#   'display_name': 'Young Adult Hardcover',
#   'list_name_encoded': 'young-adult-hardcover',
#   'oldest_published_date': '2015-08-30',
#   'newest_published_date': '2019-04-14',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Young Adult Paperback',
#   'display_name': 'Young Adult Paperback',
#   'list_name_encoded': 'young-adult-paperback',
#   'oldest_published_date': '2015-08-30',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Hardcover Graphic Books',
#   'display_name': 'Hardcover Graphic Books',
#   'list_name_encoded': 'hardcover-graphic-books',
#   'oldest_published_date': '2009-03-15',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Paperback Graphic Books',
#   'display_name': 'Paperback Graphic Books',
#   'list_name_encoded': 'paperback-graphic-books',
#   'oldest_published_date': '2009-03-15',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Manga',
#   'display_name': 'Manga',
#   'list_name_encoded': 'manga',
#   'oldest_published_date': '2009-03-15',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Combined Print Fiction',
#   'display_name': 'Combined Hardcover & Paperback Fiction',
#   'list_name_encoded': 'combined-print-fiction',
#   'oldest_published_date': '2011-02-13',
#   'newest_published_date': '2013-05-12',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Combined Print Nonfiction',
#   'display_name': 'Combined Hardcover & Paperback Nonfiction',
#   'list_name_encoded': 'combined-print-nonfiction',
#   'oldest_published_date': '2011-02-13',
#   'newest_published_date': '2013-05-12',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Animals',
#   'display_name': 'Animals',
#   'list_name_encoded': 'animals',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Audio Fiction',
#   'display_name': 'Audio Fiction',
#   'list_name_encoded': 'audio-fiction',
#   'oldest_published_date': '2018-03-11',
#   'newest_published_date': '2019-04-14',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Audio Nonfiction',
#   'display_name': 'Audio Nonfiction',
#   'list_name_encoded': 'audio-nonfiction',
#   'oldest_published_date': '2018-03-11',
#   'newest_published_date': '2019-04-14',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Business Books',
#   'display_name': 'Business',
#   'list_name_encoded': 'business-books',
#   'oldest_published_date': '2013-11-03',
#   'newest_published_date': '2019-04-14',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Celebrities',
#   'display_name': 'Celebrities',
#   'list_name_encoded': 'celebrities',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Crime and Punishment',
#   'display_name': 'Crime and Punishment',
#   'list_name_encoded': 'crime-and-punishment',
#   'oldest_published_date': '2014-10-12',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Culture',
#   'display_name': 'Culture',
#   'list_name_encoded': 'culture',
#   'oldest_published_date': '2014-10-12',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Education',
#   'display_name': 'Education',
#   'list_name_encoded': 'education',
#   'oldest_published_date': '2014-10-12',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Espionage',
#   'display_name': 'Espionage',
#   'list_name_encoded': 'espionage',
#   'oldest_published_date': '2014-12-14',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Expeditions Disasters and Adventures',
#   'display_name': 'Expeditions',
#   'list_name_encoded': 'expeditions-disasters-and-adventures',
#   'oldest_published_date': '2014-12-14',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Fashion Manners and Customs',
#   'display_name': 'Fashion, Manners and Customs',
#   'list_name_encoded': 'fashion-manners-and-customs',
#   'oldest_published_date': '2014-10-12',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Food and Fitness',
#   'display_name': 'Food and Diet',
#   'list_name_encoded': 'food-and-fitness',
#   'oldest_published_date': '2013-09-01',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Games and Activities',
#   'display_name': 'Games and Activities',
#   'list_name_encoded': 'games-and-activities',
#   'oldest_published_date': '2014-10-12',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Hardcover Business Books',
#   'display_name': 'Hardcover Business Books',
#   'list_name_encoded': 'hardcover-business-books',
#   'oldest_published_date': '2011-07-03',
#   'newest_published_date': '2013-10-13',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Health',
#   'display_name': 'Health',
#   'list_name_encoded': 'health',
#   'oldest_published_date': '2014-10-12',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Humor',
#   'display_name': 'Humor',
#   'list_name_encoded': 'humor',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Indigenous Americans',
#   'display_name': 'Indigenous Americans',
#   'list_name_encoded': 'indigenous-americans',
#   'oldest_published_date': '2014-12-14',
#   'newest_published_date': '2016-01-10',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Relationships',
#   'display_name': 'Love and Relationships',
#   'list_name_encoded': 'relationships',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Paperback Business Books',
#   'display_name': 'Paperback Business Books',
#   'list_name_encoded': 'paperback-business-books',
#   'oldest_published_date': '2011-07-03',
#   'newest_published_date': '2013-10-13',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Family',
#   'display_name': 'Parenthood and Family',
#   'list_name_encoded': 'family',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Hardcover Political Books',
#   'display_name': 'Politics and American History',
#   'list_name_encoded': 'hardcover-political-books',
#   'oldest_published_date': '2011-07-03',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Race and Civil Rights',
#   'display_name': 'Race and Civil Rights',
#   'list_name_encoded': 'race-and-civil-rights',
#   'oldest_published_date': '2014-12-14',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Religion Spirituality and Faith',
#   'display_name': 'Religion, Spirituality and Faith',
#   'list_name_encoded': 'religion-spirituality-and-faith',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Science',
#   'display_name': 'Science',
#   'list_name_encoded': 'science',
#   'oldest_published_date': '2013-04-14',
#   'newest_published_date': '2019-04-14',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Sports',
#   'display_name': 'Sports and Fitness',
#   'list_name_encoded': 'sports',
#   'oldest_published_date': '2014-03-02',
#   'newest_published_date': '2019-04-14',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Travel',
#   'display_name': 'Travel',
#   'list_name_encoded': 'travel',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'}]

# %%
#translates json data into a Pandas dataframe
books_catlist = pd.DataFrame(cat_res, columns=['list_name','display_name','list_name_encoded','oldest_published_date',
                                              'newest_published_date','updated'])
books_catlist
# Out:
#                                list_name  \
# 0      Combined Print and E-Book Fiction
# 1   Combined Print and E-Book Nonfiction
# 2                      Hardcover Fiction
# 3                   Hardcover Nonfiction
# 4                Trade Fiction Paperback
# 5                  Mass Market Paperback
# 6                   Paperback Nonfiction
# 7                         E-Book Fiction
# 8                      E-Book Nonfiction
# 9                       Hardcover Advice
# 10                      Paperback Advice
# 11       Advice How-To and Miscellaneous
# 12                         Chapter Books
# 13                Childrens Middle Grade
# 14         Childrens Middle Grade E-Book
# 15      Childrens Middle Grade Hardcover
# 16      Childrens Middle Grade Paperback
# 17                       Paperback Books
# 18                         Picture Books
# 19                          Series Books
# 20                           Young Adult
# 21                    Young Adult E-Book
# 22                 Young Adult Hardcover
# 23                 Young Adult Paperback
# 24               Hardcover Graphic Books
# 25               Paperback Graphic Books
# 26                                 Manga
# 27                Combined Print Fiction
# 28             Combined Print Nonfiction
# 29                               Animals
# 30                         Audio Fiction
# 31                      Audio Nonfiction
# 32                        Business Books
# 33                           Celebrities
# 34                  Crime and Punishment
# 35                               Culture
# 36                             Education
# 37                             Espionage
# 38  Expeditions Disasters and Adventures
# 39           Fashion Manners and Customs
# 40                      Food and Fitness
# 41                  Games and Activities
# 42              Hardcover Business Books
# 43                                Health
# 44                                 Humor
# 45                  Indigenous Americans
# 46                         Relationships
# 47              Paperback Business Books
# 48                                Family
# 49             Hardcover Political Books
# 50                 Race and Civil Rights
# 51       Religion Spirituality and Faith
# 52                               Science
# 53                                Sports
# 54                                Travel
#
#                                  display_name  \
# 0             Combined Print & E-Book Fiction
# 1          Combined Print & E-Book Nonfiction
# 2                           Hardcover Fiction
# 3                        Hardcover Nonfiction
# 4                     Paperback Trade Fiction
# 5               Paperback Mass-Market Fiction
# 6                        Paperback Nonfiction
# 7                              E-Book Fiction
# 8                           E-Book Nonfiction
# 9                    Hardcover Advice & Misc.
# 10                   Paperback Advice & Misc.
# 11             Advice, How-To & Miscellaneous
# 12                   Children’s Chapter Books
# 13                    Children’s Middle Grade
# 14             Children’s Middle Grade E-Book
# 15          Children’s Middle Grade Hardcover
# 16          Children’s Middle Grade Paperback
# 17                 Children’s Paperback Books
# 18                   Children’s Picture Books
# 19                          Children’s Series
# 20                                Young Adult
# 21                         Young Adult E-Book
# 22                      Young Adult Hardcover
# 23                      Young Adult Paperback
# 24                    Hardcover Graphic Books
# 25                    Paperback Graphic Books
# 26                                      Manga
# 27     Combined Hardcover & Paperback Fiction
# 28  Combined Hardcover & Paperback Nonfiction
# 29                                    Animals
# 30                              Audio Fiction
# 31                           Audio Nonfiction
# 32                                   Business
# 33                                Celebrities
# 34                       Crime and Punishment
# 35                                    Culture
# 36                                  Education
# 37                                  Espionage
# 38                                Expeditions
# 39               Fashion, Manners and Customs
# 40                              Food and Diet
# 41                       Games and Activities
# 42                   Hardcover Business Books
# 43                                     Health
# 44                                      Humor
# 45                       Indigenous Americans
# 46                     Love and Relationships
# 47                   Paperback Business Books
# 48                      Parenthood and Family
# 49              Politics and American History
# 50                      Race and Civil Rights
# 51           Religion, Spirituality and Faith
# 52                                    Science
# 53                         Sports and Fitness
# 54                                     Travel
#
#                        list_name_encoded oldest_published_date  \
# 0      combined-print-and-e-book-fiction            2011-02-13
# 1   combined-print-and-e-book-nonfiction            2011-02-13
# 2                      hardcover-fiction            2008-06-08
# 3                   hardcover-nonfiction            2008-06-08
# 4                trade-fiction-paperback            2008-06-08
# 5                  mass-market-paperback            2008-06-08
# 6                   paperback-nonfiction            2008-06-08
# 7                         e-book-fiction            2011-02-13
# 8                      e-book-nonfiction            2011-02-13
# 9                       hardcover-advice            2008-06-08
# 10                      paperback-advice            2008-06-08
# 11       advice-how-to-and-miscellaneous            2013-04-28
# 12                         chapter-books            2008-06-08
# 13                childrens-middle-grade            2012-12-16
# 14         childrens-middle-grade-e-book            2015-08-30
# 15      childrens-middle-grade-hardcover            2015-08-30
# 16      childrens-middle-grade-paperback            2015-08-30
# 17                       paperback-books            2008-06-08
# 18                         picture-books            2008-06-08
# 19                          series-books            2008-06-08
# 20                           young-adult            2012-12-16
# 21                    young-adult-e-book            2015-08-30
# 22                 young-adult-hardcover            2015-08-30
# 23                 young-adult-paperback            2015-08-30
# 24               hardcover-graphic-books            2009-03-15
# 25               paperback-graphic-books            2009-03-15
# 26                                 manga            2009-03-15
# 27                combined-print-fiction            2011-02-13
# 28             combined-print-nonfiction            2011-02-13
# 29                               animals            2014-09-07
# 30                         audio-fiction            2018-03-11
# 31                      audio-nonfiction            2018-03-11
# 32                        business-books            2013-11-03
# 33                           celebrities            2014-09-07
# 34                  crime-and-punishment            2014-10-12
# 35                               culture            2014-10-12
# 36                             education            2014-10-12
# 37                             espionage            2014-12-14
# 38  expeditions-disasters-and-adventures            2014-12-14
# 39           fashion-manners-and-customs            2014-10-12
# 40                      food-and-fitness            2013-09-01
# 41                  games-and-activities            2014-10-12
# 42              hardcover-business-books            2011-07-03
# 43                                health            2014-10-12
# 44                                 humor            2014-09-07
# 45                  indigenous-americans            2014-12-14
# 46                         relationships            2014-09-07
# 47              paperback-business-books            2011-07-03
# 48                                family            2014-09-07
# 49             hardcover-political-books            2011-07-03
# 50                 race-and-civil-rights            2014-12-14
# 51       religion-spirituality-and-faith            2014-09-07
# 52                               science            2013-04-14
# 53                                sports            2014-03-02
# 54                                travel            2014-09-07
#
#    newest_published_date  updated
# 0             2019-04-14   WEEKLY
# 1             2019-04-14   WEEKLY
# 2             2019-04-14   WEEKLY
# 3             2019-04-14   WEEKLY
# 4             2019-04-14   WEEKLY
# 5             2017-01-29   WEEKLY
# 6             2019-04-14   WEEKLY
# 7             2017-01-29   WEEKLY
# 8             2017-01-29   WEEKLY
# 9             2013-04-21   WEEKLY
# 10            2013-04-21   WEEKLY
# 11            2019-04-14   WEEKLY
# 12            2012-12-09   WEEKLY
# 13            2015-08-23   WEEKLY
# 14            2017-01-29   WEEKLY
# 15            2019-04-14   WEEKLY
# 16            2017-01-29   WEEKLY
# 17            2012-12-09   WEEKLY
# 18            2019-04-14   WEEKLY
# 19            2019-04-14   WEEKLY
# 20            2015-08-23   WEEKLY
# 21            2017-01-29   WEEKLY
# 22            2019-04-14   WEEKLY
# 23            2017-01-29   WEEKLY
# 24            2017-01-29   WEEKLY
# 25            2017-01-29   WEEKLY
# 26            2017-01-29   WEEKLY
# 27            2013-05-12   WEEKLY
# 28            2013-05-12   WEEKLY
# 29            2017-01-15  MONTHLY
# 30            2019-04-14  MONTHLY
# 31            2019-04-14  MONTHLY
# 32            2019-04-14  MONTHLY
# 33            2017-01-15  MONTHLY
# 34            2017-01-15  MONTHLY
# 35            2017-01-15  MONTHLY
# 36            2017-01-15  MONTHLY
# 37            2017-01-15  MONTHLY
# 38            2017-01-15  MONTHLY
# 39            2017-01-15  MONTHLY
# 40            2017-01-15  MONTHLY
# 41            2017-01-15  MONTHLY
# 42            2013-10-13  MONTHLY
# 43            2017-01-15  MONTHLY
# 44            2017-01-15  MONTHLY
# 45            2016-01-10  MONTHLY
# 46            2017-01-15  MONTHLY
# 47            2013-10-13  MONTHLY
# 48            2017-01-15  MONTHLY
# 49            2017-01-15  MONTHLY
# 50            2017-01-15  MONTHLY
# 51            2017-01-15  MONTHLY
# 52            2019-04-14  MONTHLY
# 53            2019-04-14  MONTHLY
# 54            2017-01-15  MONTHLY

# %% [markdown]
# #### Dataset 3: ####
# This dataset came from the NYT and lists out the most popular stories from the last 30 days based on number of views.

# %%
#use requests library and call get method to access URL and open the API
most_pop = requests.get('https://api.nytimes.com/svc/mostpopular/v2/viewed/30.json?api-key=GsQu4h8IDfExzCiiJWehGDgRPEQ9Ajka')
print(most_pop.text)
# Out:
# {"status":"OK","copyright":"Copyright (c) 2019 The New York Times Company.  All Rights Reserved.","num_results":1899,"results":[{"url":"https:\/\/www.nytimes.com\/2019\/03\/28\/health\/woman-pain-anxiety.html","adx_keywords":"Pain;Anxiety and Stress;Cameron, Jo;Srivastava, Devjit;British Journal of Anaesthesia;Genetics and Heredity;Opioids and Opiates;Pain-Relieving Drugs;University College London;Scotland","column":null,"section":"Health","byline":"By HEATHER MURPHY","type":"Article","title":"At 71, She\u2019s Never Felt Pain or Anxiety. Now Scientists Know Why.","abstract":"Scientists discovered a previously unidentified genetic mutation in a Scottish woman. They hope it could lead to the development of new pain treatment.","published_date":"2019-03-28","source":"The New York Times","id":100000006432324,"asset_id":100000006432324,"views":1,"des_facet":["ANXIETY AND STRESS","GENETICS AND HEREDITY","OPIOIDS AND OPIATES","PAIN-RELIEVING DRUGS"],"org_facet":["PAIN","BRITISH JOURNAL OF ANAESTHESIA","UNIVERSITY COLLEGE LONDON"],"per_facet":["CAMERON, JO","SRIVASTAVA, DEVJIT"],"geo_facet":["SCOTLAND"],"media":[{"type":"image","subtype":"photo","caption":"Jo Cameron, 71, has a rare gene mutation that scientists believe inhibits her from feeling pain or anxiety.","copyright":"Mary Turner for The New York Times","approved_for_syndication":1,"media-metadata":[{"url":"https:\/\/static01.nyt.com\/images\/2019\/03\/27\/science\/27xp-nopain\/27xp-nopain-thumbStandard.jpg","format":"Standard Thumbnail","height":75,"width":75},{"url":"https:\/\/static01.nyt.com\/images\/2019\/03\/27\/science\/27xp-nopain\/27xp-nopain-mediumThreeByTwo210.jpg","format":"mediumThreeByTwo210","height":140,"width":210},{"url":"https:\/\/static01.nyt.com\/images\/2019\/03\/27\/science\/27xp-nopain\/27xp-nopain-mediumThreeByTwo440.jpg","format":"mediumThreeByTwo440","height":293,"width":440}]}],"uri":"nyt:\/\/article\/02e0395b-1496-540a-8e5f-6687a52a6fca"},{"url":"https:\/\/www.nytimes.com\/2019\/03\/12\/us\/felicity-huffman-lori-loughlin-massimo-giannulli.html","adx_keywords":"College Admissions Scandal (2019);Admissions Standards;Colleges and Universities;Bribery and Kickbacks;Cheating;Frauds and Swindling;Huffman, Felicity;Loughlin, Lori;Giannulli, Mossimo","column":null,"section":"U.S.","byline":"By REBECCA HALLECK","type":"Article","title":"Who\u2019s Been Charged in the College Admissions Cheating Scandal? Here\u2019s the Full List","abstract":"The actresses Felicity Huffman and Lori Loughlin and the fashion designer Mossimo Giannulli are among the 50 people charged in a bribery scheme to secure places for students in elite colleges.","published_date":"2019-03-12","source":"The New York Times","id":100000006406229,"asset_id":100000006406229,"views":2,"des_facet":["ADMISSIONS STANDARDS","COLLEGES AND UNIVERSITIES","BRIBERY AND KICKBACKS","FRAUDS AND SWINDLING"],"org_facet":["COLLEGE ADMISSIONS SCANDAL (2019)","CHEATING"],"per_facet":["HUFFMAN, FELICITY","LOUGHLIN, LORI","GIANNULLI, MOSSIMO"],"geo_facet":"","media":[{"type":"image","subtype":"photo","caption":"From left: Lori Loughlin, Mossimo Giannulli and Felicity Huffman.","copyright":"From left: AFP -- Getty Images; Reuters and AP","approved_for_syndication":1,"media-metadata":[{"url":"https:\/\/static01.nyt.com\/images\/2019\/03\/12\/us\/12college-whois-hp\/12college-whois-alt-thumbStandard.jpg","format":"Standard Thumbnail","height":75,"width":75},{"url":"https:\/\/static01.nyt.com\/images\/2019\/03\/12\/us\/12college-whois-hp\/12college-whois-alt-mediumThreeByTwo210.jpg","format":"mediumThreeByTwo210","height":140,"width":210},{"url":"https:\/\/static01.nyt.com\/images\/2019\/03\/12\/us\/12college-whois-hp\/12college-whois-alt-mediumThreeByTwo440.jpg","format":"mediumThreeByTwo440","height":293,"width":440}]}],"uri":"nyt:\/\/article\/50b479fd-7f67-54d5-91ec-b60178e83d83"},{"url":"https:\/\/www.nytimes.com\/2019\/03\/12\/us\/college-admissions-cheating-scandal.html","adx_keywords":"College Admissions Scan ...

# %%
#translates data into a readable json file
pop = most_pop.json()
pop
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company.  All Rights Reserved.',
#  'num_results': 1899,
#  'results': [{'url': 'https://www.nytimes.com/2019/03/28/health/woman-pain-anxiety.html',
#    'adx_keywords': 'Pain;Anxiety and Stress;Cameron, Jo;Srivastava, Devjit;British Journal of Anaesthesia;Genetics and Heredity;Opioids and Opiates;Pain-Relieving Drugs;University College London;Scotland',
#    'column': None,
#    'section': 'Health',
#    'byline': 'By HEATHER MURPHY',
#    'type': 'Article',
#    'title': 'At 71, She’s Never Felt Pain or Anxiety. Now Scientists Know Why.',
#    'abstract': 'Scientists discovered a previously unidentified genetic mutation in a Scottish woman. They hope it could lead to the development of new pain treatment.',
#    'published_date': '2019-03-28',
#    'source': 'The New York Times',
#    'id': 100000006432324,
#    'asset_id': 100000006432324,
#    'views': 1,
#    'des_facet': ['ANXIETY AND STRESS',
#     'GENETICS AND HEREDITY',
#     'OPIOIDS AND OPIATES',
#     'PAIN-RELIEVING DRUGS'],
#    'org_facet': ['PAIN',
#     'BRITISH JOURNAL OF ANAESTHESIA',
#     'UNIVERSITY COLLEGE LONDON'],
#    'per_facet': ['CAMERON, JO', 'SRIVASTAVA, DEVJIT'],
#    'geo_facet': ['SCOTLAND'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jo Cameron, 71, has a rare gene mutation that scientists believe inhibits her from feeling pain or anxiety.',
#      'copyright': 'Mary Turner for The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/27/science/27xp-nopain/27xp-nopain-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/27/science/27xp-nopain/27xp-nopain-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/27/science/27xp-nopain/27xp-nopain-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/02e0395b-1496-540a-8e5f-6687a52a6fca'},
#   {'url': 'https://www.nytimes.com/2019/03/12/us/felicity-huffman-lori-loughlin-massimo-giannulli.html',
#    'adx_keywords': 'College Admissions Scandal (2019);Admissions Standards;Colleges and Universities;Bribery and Kickbacks;Cheating;Frauds and Swindling;Huffman, Felicity;Loughlin, Lori;Giannulli, Mossimo',
#    'column': None,
#    'section': 'U.S.',
#    'byline': 'By REBECCA HALLECK',
#    'type': 'Article',
#    'title': 'Who’s Been Charged in the College Admissions Cheating Scandal? Here’s the Full List',
#    'abstract': 'The actresses Felicity Huffman and Lori Loughlin and the fashion designer Mossimo Giannulli are among the 50 people charged in a bribery scheme to secure places for students in elite colleges.',
#    'published_date': '2019-03-12',
#    'source': 'The New York Times',
#    'id': 100000006406229,
#    'asset_id': 100000006406229,
#    'views': 2,
#    'des_facet': ['ADMISSIONS STANDARDS',
#     'COLLEGES AND UNIVERSITIES',
#     'BRIBERY AND KICKBACKS',
#     'FRAUDS AND SWINDLING'],
#    'org_facet': ['COLLEGE ADMISSIONS SCANDAL (2019)', 'CHEATING'],
#    'per_facet': ['HUFFMAN, FELICITY', 'LOUGHLIN, LORI', 'GIANNULLI, MOSSIMO'],
#    'geo_facet': '',
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'From left: Lori Loughlin, Mossimo Giannulli and Felicity Huffman.',
#      'copyright': 'From left: AFP -- Getty Images; Reuters and AP',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/12/us/12college-whois-hp/12college-whois-alt-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/12/us/12college-whois-hp/12college-whois-alt-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/12/us/12college-whois-hp/12college-whois-alt-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/50b479fd-7f67-54d5-91ec-b60178e83d83'},
#   {'url': 'https://www.nytimes.com/2019/03/12/us/college-admissions-cheating-scandal.html',
#    'adx_keywords': 'College Admissions Scandal (2019);Colleges and Universities;Admissions Standards;Cheating;Bribery and Kickbacks;Frauds and Swindling;Singer, William Rick;Edge College and Career Network;Huffman, Felicity;Loughlin, Lori;McGlashan, William E Jr;Yale University;Wake Forest University;Stanford University;University of Southern California',
#    'column': None,
#    'section': 'U.S.',
#    'byline': 'By JENNIFER MEDINA, KATIE BENNER and KATE TAYLOR',
#    'type': 'Article',
#    'title': 'Actresses, Business Leaders and Other Wealthy Parents Charged in U.S. College Entry Fraud',
#    'abstract': 'A sprawling federal investigation accuses 50 people of involvement in a scheme to get undeserving students into major American universities.',
#    'published_date': '2019-03-12',
#    'source': 'The New York Times',
#    'id': 100000006406075,
#    'asset_id': 100000006406075,
#    'views': 3,
#    'des_facet': ['COLLEGES AND UNIVERSITIES',
#     'ADMISSIONS STANDARDS',
#     'CHEATING'],
#    'org_facet': ['COLLEGE ADMISSIONS SCANDAL (2019)',
#     'BRIBERY AND KICKBACKS',
#     'FRAUDS AND SWINDLING',
#     'EDGE COLLEGE AND CAREER NETWORK',
#     'YALE UNIVERSITY',
#     'WAKE FOREST UNIVERSITY',
#     'STANFORD UNIVERSITY',
#     'UNIVERSITY OF SOUTHERN CALIFORNIA'],
#    'per_facet': ['SINGER, WILLIAM RICK',
#     'HUFFMAN, FELICITY',
#     'LOUGHLIN, LORI',
#     'MCGLASHAN, WILLIAM E JR'],
#    'geo_facet': '',
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Steven Senne/Associated Press',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/12/us/12college-raid-sub/12college-raid-sub-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/12/us/12college-raid-sub/12college-raid-sub-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/12/us/12college-raid-sub/12college-raid-sub-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/bac76e87-b5fc-54fa-8c0f-46a0688effba'},
#   {'url': 'https://www.nytimes.com/interactive/2019/arts/television/best-movies-on-netflix.html',
#    'adx_keywords': 'Netflix Inc;Movies;Video Recordings, Downloads and Streaming',
#    'column': '',
#    'section': 'Arts',
#    'byline': 'By JASON BAILEY',
#    'type': 'Interactive',
#    'title': 'The 50 Best Movies on Netflix Right Now',
#    'abstract': 'We’ve plucked out the 50 best films currently streaming on Netflix in the United States. Take a look.',
#    'published_date': '2019-03-06',
#    'source': 'The New York Times',
#    'id': 100000006330108,
#    'asset_id': 100000006330108,
#    'views': 4,
#    'des_facet': ['MOVIES', 'VIDEO RECORDINGS, DOWNLOADS AND STREAMING'],
#    'org_facet': ['NETFLIX INC'],
#    'per_facet': '',
#    'geo_facet': '',
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Uma Thurman in “Pulp Fiction.”',
#      'copyright': 'Linda R. Chen/Miramax Films',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2016/06/19/watching/pulp-fiction-watching-recommendation/pulp-fiction-watching-recommendation-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2016/06/19/watching/pulp-fiction-watching-recommendation/pulp-fiction-watching-recommendation-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2016/06/19/watching/pulp-fiction-watching-recommendation/pulp-fiction-watching-recommendation-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://interactive/3769fe44-d294-5a71-8281-5220a39673bf'},
#   {'url': 'https://www.nytimes.com/2019/03/16/style/snowplow-parenting-scandal.html',
#    'adx_keywords': 'Admissions Standards;Colleges and Universities;College Admissions Scandal (2019);Parenting;Tests and Examinations;SAT (College Admission Test);Education (K-12)',
#    'column': None,
#    'section': 'Style',
#    'byline': 'By CLAIRE CAIN MILLER and JONAH ENGEL BROMWICH',
#    'type': 'Article',
#    'title': 'How Parents Are Robbing Their Children of Adulthood',
#    'abstract': 'Today’s “snowplow parents” keep their children’s futures obstacle-free — even when it means crossing ethical and legal boundaries.',
#    'published_date': '2019-03-16',
#    'source': 'The New York Times',
#    'id': 100000006411881,
#    'asset_id': 100000006411881,
#    'views': 5,
#    'des_facet': ['ADMISSIONS STANDARDS',
#     'COLLEGES AND UNIVERSITIES',
#     'PARENTING',
#     'TESTS AND EXAMINATIONS'],
#    'org_facet': ['COLLEGE ADMISSIONS SCANDAL (2019)',
#     'SAT (COLLEGE ADMISSION TEST)',
#     'EDUCATION (K-12)'],
#    'per_facet': '',
#    'geo_facet': '',
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Illustration by The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/17/style/17snowplow-1/17snowplow-1-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/17/style/17snowplow-1/17snowplow-1-mediumThreeByTwo210-v2.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/17/style/17snowplow-1/17snowplow-1-mediumThreeByTwo440-v2.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/08baa5d4-b67b-5e29-8212-7c64d8978670'},
#   {'url': 'https://www.nytimes.com/2019/03/25/smarter-living/why-you-procrastinate-it-has-nothing-to-do-with-self-control.html',
#    'adx_keywords': 'Procrastination;Emotions;Psychology and Psychologists;Anxiety and Stress;Boredom',
#    'column': None,
#    'section': 'Smarter Living',
#    'byline': 'By CHARLOTTE LIEBERMAN',
#    'type': 'Article',
#    'title': 'Why You Procrastinate (It Has Nothing to Do With Self-Control)',
#    'abstract': 'If procrastination isn’t about laziness, then what is it about?',
#    'published_date': '2019-03-25',
#    'source': 'The New York Times',
#    'id': 100000006416140,
#    'asset_id': 100000006416140,
#    'views': 6,
#    'des_facet': ['PROCRASTINATION',
#     'PSYCHOLOGY AND PSYCHOLOGISTS',
#     'ANXIETY AND STRESS'],
#    'org_facet': ['EMOTIONS', 'BOREDOM'],
#    'per_facet': '',
#    'geo_facet': '',
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Erik Winkowski',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/25/smarter-living/25sl_procrastination_promo/25sl_procrastination_promo-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/25/smarter-living/25sl_procrastination_promo/25sl_procrastination_promo-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/25/smarter-living/25sl_procrastination_promo/25sl_procrastination_promo-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/166a9d7f-8edd-5ae8-88e5-30a6e80e646e'},
#   {'url': 'https://www.nytimes.com/2019/04/03/us/politics/william-barr-mueller-report.html',
#    'adx_keywords': 'Trump, Donald J;Mueller, Robert S III;Barr, William P;Russian Interference in 2016 US Elections and Ties to Trump Associates;Special Prosecutors (Independent Counsel);Justice Department;Attorneys General;United States Politics and Government',
#    'column': None,
#    'section': 'U.S.',
#    'byline': 'By NICHOLAS FANDOS, MICHAEL S. SCHMIDT and MARK MAZZETTI',
#    'type': 'Article',
#    'title': 'Some on Mueller’s Team Say Report Was More Damaging Than Barr Revealed',
#    'abstract': 'Members of the special counsel’s team have told associates that their findings are more troubling for President Trump than the attorney general indicated.',
#    'published_date': '2019-04-03',
#    'source': 'The New York Times',
#    'id': 100000006441465,
#    'asset_id': 100000006441465,
#    'views': 7,
#    'des_facet': ['RUSSIAN INTERFERENCE IN 2016 US ELECTIONS AND TIES TO TRUMP ASSOCIATES',
#     'UNITED STATES POLITICS AND GOVERNMENT'],
#    'org_facet': ['SPECIAL PROSECUTORS (INDEPENDENT COUNSEL)',
#     'JUSTICE DEPARTMENT',
#     'ATTORNEYS GENERAL'],
#    'per_facet': ['TRUMP, DONALD J',
#     'MUELLER, ROBERT S III',
#     'BARR, WILLIAM P'],
#    'geo_facet': '',
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Attorney General William P. Barr has shown hints of frustration with how the rollout of the special counsel’s chief findings has unfolded.<br /><br />',
#      'copyright': 'Sarah Silbiger/The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/05/03/us/03dc-mueller-promo/merlin_152946042_2d0da3b4-7ed5-47a4-bc93-0b1234b85a54-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/05/03/us/03dc-mueller-promo/merlin_152946042_2d0da3b4-7ed5-47a4-bc93-0b1234b85a54-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/05/03/us/03dc-mueller-promo/merlin_152946042_2d0da3b4-7ed5-47a4-bc93-0b1234b85a54-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/6d5ac849-af3f-5a1b-90f7-88f56c37dabd'},
#   {'url': 'https://www.nytimes.com/2019/03/21/business/boeing-safety-features-charge.html',
#    'adx_keywords': 'Boeing 737 Max Groundings and Safety Concerns (2019);Aviation Accidents, Safety and Disasters;Airlines and Airplanes;Boeing Company;Ethiopian Airlines;Lion Air;Regulation and Deregulation of Industry',
#    'column': None,
#    'section': 'Business',
#    'byline': 'By HIROKO TABUCHI and DAVID GELLES',
#    'type': 'Article',
#    'title': 'Doomed Boeing Jets Lacked 2 Safety Features That Company Sold Only as Extras',
#    'abstract': 'Airlines had to pay more for two optional upgrades that could warn pilots about sensor malfunctions. Boeing now plans to make one of the features standard.',
#    'published_date': '2019-03-21',
#    'source': 'The New York Times',
#    'id': 100000006421007,
#    'asset_id': 100000006421007,
#    'views': 8,
#    'des_facet': ['BOEING 737 MAX GROUNDINGS AND SAFETY CONCERNS (2019)',
#     'AVIATION ACCIDENTS, SAFETY AND DISASTERS',
#     'AIRLINES AND AIRPLANES'],
#    'org_facet': ['BOEING COMPANY',
#     'ETHIOPIAN AIRLINES',
#     'LION AIR',
#     'REGULATION AND DEREGULATION OF INDUSTRY'],
#    'per_facet': '',
#    'geo_facet': '',
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Standard 737 Max planes are not equipped with a so-called angle of attack indicator or an angle of attack disagree light. The indicator will continue to cost airlines extra, but the light won’t.',
#      'copyright': 'Ruth Fremson/The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/23/business/23boeing1/20boeing1-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/23/business/23boeing1/20boeing1-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/23/business/23boeing1/20boeing1-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/b8a29461-75dc-56ee-8f4b-e076749b6a6d'},
#   {'url': 'https://www.nytimes.com/2019/03/14/world/boeing-737-max-ethiopian-airlines.html',
#    'adx_keywords': 'Boeing 737 Max Groundings and Safety Concerns (2019);Aviation Accidents, Safety and Disasters;Getachew, Yared;Boeing Company;Federal Aviation Administration;Ethiopian Airlines',
#    'column': None,
#    'section': 'World',
#    'byline': 'By SELAM GEBREKIDAN and JAMES GLANZ',
#    'type': 'Article',
#    'title': 'Boeing 737 Max Hit Trouble Right Away, Pilot’s Tense Radio Messages Show',
#    'abstract': '“Break break, request back to home,” the captain of the ill-fated Ethiopian Airlines flight radioed air traffic controllers minutes after taking off.',
#    'published_date': '2019-03-14',
#    'source': 'The New York Times',
#    'id': 100000006410242,
#    'asset_id': 100000006410242,
#    'views': 9,
#    'des_facet': ['BOEING 737 MAX GROUNDINGS AND SAFETY CONCERNS (2019)',
#     'AVIATION ACCIDENTS, SAFETY AND DISASTERS'],
#    'org_facet': ['BOEING COMPANY',
#     'FEDERAL AVIATION ADMINISTRATION',
#     'ETHIOPIAN AIRLINES'],
#    'per_facet': ['GETACHEW, YARED'],
#    'geo_facet': '',
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A memorial arch on Thursday at the site of the jet crash in Ethiopia.',
#      'copyright': 'Jemal Countess/Getty Images',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/14/business/14boeing3/14boeing3-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/14/business/14boeing3/14boeing3-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/14/business/14boeing3/14boeing3-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/63411a1f-beed-55ff-99b5-7c382acf1d83'},
#   {'url': 'https://www.nytimes.com/2019/03/15/world/asia/new-zealand-shooting.html',
#    'adx_keywords': 'Murders, Attempted Murders and Homicides;Christchurch, New Zealand, Attack (March 2019);Mosques;Terrorism;Muslims and Islam;New Zealand;Social Media;Christchurch (New Zealand)',
#    'column': None,
#    'section': 'World',
#    'byline': 'By THE NEW YORK TIMES',
#    'type': 'Article',
#    'title': 'Jacinda Ardern Consoles Families After New Zealand Shooting',
#    'abstract': 'The attack on two mosques, which appeared to have been carried out by a white extremist, left 49 dead in the city of Christchurch.',
#    'published_date': '2019-03-15',
#    'source': 'The New York Times',
#    'id': 100000006412038,
#    'asset_id': 100000006412038,
#    'views': 10,
#    'des_facet': ['MURDERS, ATTEMPTED MURDERS AND HOMICIDES',
#     'CHRISTCHURCH, NEW ZEALAND, ATTACK (MARCH 2019)',
#     'MOSQUES'],
#    'org_facet': ['TERRORISM', 'MUSLIMS AND ISLAM', 'SOCIAL MEDIA'],
#    'per_facet': '',
#    'geo_facet': ['NEW ZEALAND', 'CHRISTCHURCH (NEW ZEALAND)'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A makeshift memorial in Christchurch, New Zealand, on Saturday.',
#      'copyright': 'Matthew Abbott for The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/16/world/16nz-shooting-2/16nz-shooting-2-thumbStandard-v2.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/16/world/16nz-shooting-2/16nz-shooting-2-mediumThreeByTwo210-v2.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/16/world/16nz-shooting-2/16nz-shooting-2-mediumThreeByTwo440-v2.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/54ac784c-9e89-5526-8fa3-4e7734eb5888'},
#   {'url': 'https://www.nytimes.com/2019/03/24/us/politics/mueller-report-summary.html',
#    'adx_keywords': 'Russian Interference in 2016 US Elections and Ties to Trump Associates;Mueller, Robert S III;Trump, Donald J;United States Politics and Government;Special Prosecutors (Independent Counsel);Justice Department;Russia;Barr, William P;Presidential Election of 2016',
#    'column': None,
#    'section': 'U.S.',
#    'byline': 'By MARK MAZZETTI and KATIE BENNER',
#    'type': 'Article',
#    'title': 'Mueller Finds No Trump-Russia Conspiracy, but Stops Short of Exonerating President on Obstruction',
#    'abstract': 'The attorney general released the main findings of the closely watched investigation into Russia’s election interference and whether Trump associates conspired.',
#    'published_date': '2019-03-24',
#    'source': 'The New York Times',
#    'id': 100000006425832,
#    'asset_id': 100000006425832,
#    'views': 11,
#    'des_facet': ['RUSSIAN INTERFERENCE IN 2016 US ELECTIONS AND TIES TO TRUMP ASSOCIATES',
#     'UNITED STATES POLITICS AND GOVERNMENT',
#     'PRESIDENTIAL ELECTION OF 2016'],
#    'org_facet': ['SPECIAL PROSECUTORS (INDEPENDENT COUNSEL)',
#     'JUSTICE DEPARTMENT'],
#    'per_facet': ['MUELLER, ROBERT S III',
#     'TRUMP, DONALD J',
#     'BARR, WILLIAM P'],
#    'geo_facet': ['RUSSIA'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The special counsel, Robert S. Mueller III, and his wife, Ann Standish, near the White House after attending church on Sunday.',
#      'copyright': 'Cliff Owen/Associated Press',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/26/us/politics/26dc-cong-promo/24dc-cong-promo-thumbStandard-v2.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/26/us/politics/26dc-cong-promo/24dc-cong-promo-mediumThreeByTwo210-v2.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/26/us/politics/26dc-cong-promo/24dc-cong-promo-mediumThreeByTwo440-v2.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/0e82d026-fa9b-5802-9df6-b65dfc662b70'},
#   {'url': 'https://www.nytimes.com/interactive/2019/03/11/world/boeing-737-max-which-airlines.html',
#    'adx_keywords': 'Airlines and Airplanes;Boeing Company;Aviation Accidents, Safety and Disasters;Lion Air;Ethiopian Airlines;Addis Ababa (Ethiopia);Southwest Airlines Company;American Airlines;Air Canada;China Southern Airlines;Norwegian Air Shuttle ASA;Air China;SpiceJet;Turkish Airlines;Flydubai',
#    'column': '',
#    'section': 'World',
#    'byline': 'By DENISE LU, ALLISON McCANN, JIN WU and K.K. REBECCA LAI',
#    'type': 'Interactive',
#    'title': 'From 8,600 Flights to Zero: Grounding the Boeing 737 Max 8',
#    'abstract': 'China was the first major country to ground the jets. The U.S. was last.',
#    'published_date': '2019-03-11',
#    'source': 'The New York Times',
#    'id': 100000006404643,
#    'asset_id': 100000006404643,
#    'views': 12,
#    'des_facet': ['AIRLINES AND AIRPLANES',
#     'AVIATION ACCIDENTS, SAFETY AND DISASTERS'],
#    'org_facet': ['BOEING COMPANY',
#     'LION AIR',
#     'ETHIOPIAN AIRLINES',
#     'SOUTHWEST AIRLINES COMPANY',
#     'AMERICAN AIRLINES',
#     'AIR CANADA',
#     'CHINA SOUTHERN AIRLINES',
#     'NORWEGIAN AIR SHUTTLE ASA',
#     'AIR CHINA',
#     'SPICEJET',
#     'TURKISH AIRLINES',
#     'FLYDUBAI'],
#    'per_facet': '',
#    'geo_facet': ['ADDIS ABABA (ETHIOPIA)'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': '',
#      'approved_for_syndication': 0,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/11/world/where-boeing-737-max-flies-1552329118347/where-boeing-737-max-flies-1552329118347-thumbStandard-v15.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/11/world/where-boeing-737-max-flies-1552329118347/where-boeing-737-max-flies-1552329118347-mediumThreeByTwo210-v15.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/11/world/where-boeing-737-max-flies-1552329118347/where-boeing-737-max-flies-1552329118347-mediumThreeByTwo440-v15.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://interactive/7fcc105c-d025-5f27-841e-e00292eeb4ab'},
#   {'url': 'https://www.nytimes.com/interactive/2019/arts/television/best-drama-series.html',
#    'adx_keywords': "Television;The Sopranos (TV Program);The Americans (TV Program);Adventure Time (TV Program);The Leftovers (TV Program);Lost (TV Program);The West Wing (TV Program);Game of Thrones (TV Program);Deadwood (TV Program);Jane the Virgin (TV Program);Halt and Catch Fire (TV Program);Breaking Bad (TV Program);The Wire (TV Program);Justified (TV Program);The Good Wife (TV Program);Queen Sugar (TV Program);Grey's Anatomy (TV Program);Mad Men (TV Program);Friday Night Lights (TV Program);Gunn, Anna;Beetz, Zazie;Weiner, Matthew (1965- );Lindelof, Damon;Wright, Alison (1976- )",
#    'column': '',
#    'section': 'Arts',
#    'byline': 'By THE NEW YORK TIMES',
#    'type': 'Interactive',
#    'title': 'The 20 Best TV Dramas Since ‘The Sopranos’',
#    'abstract': 'It’s been 20 years since those ducks landed in Tony’s pool. A flock of extraordinary shows followed. These are the best dramas since 1999.',
#    'published_date': '2019-01-10',
#    'source': 'The New York Times',
#    'id': 100000006297737,
#    'asset_id': 100000006297737,
#    'views': 13,
#    'des_facet': ['TELEVISION'],
#    'org_facet': '',
#    'per_facet': ['GUNN, ANNA',
#     'BEETZ, ZAZIE',
#     'WEINER, MATTHEW (1965- )',
#     'LINDELOF, DAMON',
#     'WRIGHT, ALISON (1976- )'],
#    'geo_facet': '',
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Illustration by Pedro Piccinini. “Breaking Bad,” AMC.',
#      'approved_for_syndication': 0,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/01/09/arts/television/besttv-breakingbad/besttv-breakingbad-thumbStandard.png',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/01/09/arts/television/besttv-breakingbad/besttv-breakingbad-mediumThreeByTwo210.png',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/01/09/arts/television/besttv-breakingbad/besttv-breakingbad-mediumThreeByTwo440.png',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://interactive/ecdf0eeb-8049-53a9-abf6-f430eb3f4104'},
#   {'url': 'https://www.nytimes.com/interactive/2019/04/03/magazine/rupert-murdoch-fox-news-trump.html',
#    'adx_keywords': 'News and News Media;Presidential Election of 2016;United States Politics and Government;Cable Television;Regulation and Deregulation of Industry;Conservatism (US Politics);Antitrust Laws and Competition Issues;Family Business;21st Century Fox;Fox Broadcasting Co;Fox Entertainment Group Inc;Fox News Channel;New York Post;News Corporation;News of the World;Sky PLC;Sky Television;Sun, The (British Newspaper);Times of London;Twentieth Century Fox;Wall Street Journal;Hall, Jerry;Ailes, Roger E;Hannity, Sean;Murdoch, James R;Murdoch, Lachlan;Murdoch, Rupert;Trump, Donald J;Trump, Ivanka;Kushner, Jared;Australia;Great Britain;Great Britain Withdrawal from EU (Brexit)',
#    'column': '',
#    'section': 'Magazine',
#    'byline': 'By JONATHAN MAHLER and JIM RUTENBERG',
#    'type': 'Interactive',
#    'title': 'How Rupert Murdoch’s Empire of Influence Remade the World',
#    'abstract': 'Murdoch and his children have toppled governments on two continents and destabilized the most important democracy on Earth. What do they want?',
#    'published_date': '2019-04-03',
#    'source': 'The New York Times',
#    'id': 100000006439740,
#    'asset_id': 100000006439740,
#    'views': 14,
#    'des_facet': ['NEWS AND NEWS MEDIA',
#     'PRESIDENTIAL ELECTION OF 2016',
#     'GREAT BRITAIN WITHDRAWAL FROM EU (BREXIT)'],
#    'org_facet': ['UNITED STATES POLITICS AND GOVERNMENT',
#     'CABLE TELEVISION',
#     'REGULATION AND DEREGULATION OF INDUSTRY',
#     'CONSERVATISM (US POLITICS)',
#     'ANTITRUST LAWS AND COMPETITION ISSUES',
#     'FAMILY BUSINESS',
#     '21ST CENTURY FOX',
#     'FOX BROADCASTING CO',
#     'FOX ENTERTAINMENT GROUP INC',
#     'FOX NEWS CHANNEL',
#     'NEW YORK POST',
#     'NEWS CORPORATION',
#     'NEWS OF THE WORLD',
#     'SKY PLC',
#     'SKY TELEVISION',
#     'SUN, THE (BRITISH NEWSPAPER)',
#     'TIMES OF LONDON',
#     'TWENTIETH CENTURY FOX',
#     'WALL STREET JOURNAL'],
#    'per_facet': ['HALL, JERRY',
#     'AILES, ROGER E',
#     'HANNITY, SEAN',
#     'MURDOCH, JAMES R',
#     'MURDOCH, LACHLAN',
#     'MURDOCH, RUPERT',
#     'TRUMP, DONALD J',
#     'TRUMP, IVANKA',
#     'KUSHNER, JARED'],
#    'geo_facet': ['AUSTRALIA', 'GREAT BRITAIN'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Photo illustration by Joan Wong',
#      'approved_for_syndication': 0,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/04/07/magazine/07mag-murdoch-promo-image-1/07mag-murdoch-promo-image-1-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/04/07/magazine/07mag-murdoch-promo-image-1/07mag-murdoch-promo-image-1-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/04/07/magazine/07mag-murdoch-promo-image-1/07mag-murdoch-promo-image-1-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://interactive/1401f501-2f5c-5a0c-bee7-1a5b28dfc4e4'},
#   {'url': 'https://www.nytimes.com/2019/03/18/business/trump-deutsche-bank.html',
#    'adx_keywords': 'Trump, Donald J;Deutsche Bank AG;Banking and Financial Institutions;Real Estate (Commercial);United States Politics and Government;Presidential Election of 2016;Credit and Debt;Trump Organization;Jain, Anshu;Vrablic, Rosemary T;Kushner, Jared;Offit, Mike;Manhattan (NYC);Kennedy, Justin A;Trump International Hotel and Tower (Chicago, Ill)',
#    'column': None,
#    'section': 'Business',
#    'byline': 'By DAVID ENRICH',
#    'type': 'Article',
#    'title': 'A Mar-a-Lago Weekend and an Act of God: Trump’s History With Deutsche Bank',
#    'abstract': 'Deutsche Bank’s hunger for profits and risk led it to lend Donald Trump more than $2 billion. Once he was elected president, employees were told not to utter his name.',
#    'published_date': '2019-03-18',
#    'source': 'The New York Times',
#    'id': 100000006408304,
#    'asset_id': 100000006408304,
#    'views': 15,
#    'des_facet': ['BANKING AND FINANCIAL INSTITUTIONS',
#     'UNITED STATES POLITICS AND GOVERNMENT',
#     'PRESIDENTIAL ELECTION OF 2016'],
#    'org_facet': ['DEUTSCHE BANK AG',
#     'REAL ESTATE (COMMERCIAL)',
#     'CREDIT AND DEBT',
#     'TRUMP ORGANIZATION',
#     'TRUMP INTERNATIONAL HOTEL AND TOWER (CHICAGO, ILL)'],
#    'per_facet': ['TRUMP, DONALD J',
#     'JAIN, ANSHU',
#     'VRABLIC, ROSEMARY T',
#     'KUSHNER, JARED',
#     'OFFIT, MIKE',
#     'KENNEDY, JUSTIN A'],
#    'geo_facet': ['MANHATTAN (NYC)'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A Chicago skyscraper was the focus of a court battle between Mr. Trump and Deutsche Bank that equated the 2008 financial crisis with an act of God.',
#      'copyright': 'Nathan Weber for The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/19/business/19deutsche-4/19deutsche-4-thumbStandard-v2.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/19/business/19deutsche-4/merlin_105779095_a31267d5-ed98-4dac-83ee-a4944e284f21-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/19/business/19deutsche-4/merlin_105779095_a31267d5-ed98-4dac-83ee-a4944e284f21-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/1154d6c4-5dc2-505d-8c61-1f14581b78ab'},
#   {'url': 'https://www.nytimes.com/interactive/2019/03/07/magazine/top-songs.html',
#    'adx_keywords': 'Pop and Rock Music;Rhythm and Blues (Music);Rap and Hip-Hop;Springsteen, Bruce;Grande, Ariana;Carey, Mariah;Meek Mill (Rapper);Lady Gaga;A Star Is Born (Movie);Scott, Travis (1992- );Baby Shark (Song);Knowles, Beyonce;Jay-Z;Juice WRLD (Rapper);Musgraves, Kacey;Post, Austin (Post Malone) (1995- );Whack, Tierra;Parquet Courts (Music Group);Grimes (1988- );Holter, Julia (1984- );Maroon 5 (Music Group);Robyn (1979- );6ix9ine (Rapper);Vila Tobella, Rosalia;1975, The (Music Group);Blake, James (1988- );Weezer (Music Group);Van Etten, Sharon;Sons of Kemet (Music Group);Davidson, Marie (1987- )',
#    'column': '',
#    'section': 'Magazine',
#    'byline': 'By THE NEW YORK TIMES MAGAZINE',
#    'type': 'Interactive',
#    'title': 'The Top 25 Songs That Matter Right Now',
#    'abstract': 'Listen to music — from the blockbuster hits, critical darlings and conversation pieces of the moment — few of which take a direct route to the usual joys of pop.',
#    'published_date': '2019-03-07',
#    'source': 'The New York Times',
#    'id': 100000006397390,
#    'asset_id': 100000006397390,
#    'views': 16,
#    'des_facet': ['POP AND ROCK MUSIC', 'RHYTHM AND BLUES (MUSIC)'],
#    'org_facet': ['RAP AND HIP-HOP',
#     'PARQUET COURTS (MUSIC GROUP)',
#     'MAROON 5 (MUSIC GROUP)',
#     '1975, THE (MUSIC GROUP)',
#     'WEEZER (MUSIC GROUP)',
#     'SONS OF KEMET (MUSIC GROUP)'],
#    'per_facet': ['SPRINGSTEEN, BRUCE',
#     'GRANDE, ARIANA',
#     'CAREY, MARIAH',
#     'MEEK MILL (RAPPER)',
#     'LADY GAGA',
#     'SCOTT, TRAVIS (1992- )',
#     'KNOWLES, BEYONCE',
#     'JAY-Z',
#     'JUICE WRLD (RAPPER)',
#     'MUSGRAVES, KACEY',
#     'POST, AUSTIN (POST MALONE) (1995- )',
#     'WHACK, TIERRA',
#     'GRIMES (1988- )',
#     'HOLTER, JULIA (1984- )',
#     'ROBYN (1979- )',
#     '6IX9INE (RAPPER)',
#     'VILA TOBELLA, ROSALIA',
#     'BLAKE, JAMES (1988- )',
#     'VAN ETTEN, SHARON',
#     'DAVIDSON, MARIE (1987- )'],
#    'geo_facet': '',
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': '',
#      'approved_for_syndication': 0,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/10/magazine/10mag-cover-vertical/10mag-cover-vertical-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/10/magazine/10mag-cover-vertical/10mag-cover-vertical-mediumThreeByTwo210-v2.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/10/magazine/10mag-cover-vertical/10mag-cover-vertical-mediumThreeByTwo440-v2.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://interactive/ca81636d-4df7-5f04-9660-148c7ca65d35'},
#   {'url': 'https://www.nytimes.com/2019/03/10/world/americas/venezuela-aid-fire-video.html',
#    'adx_keywords': 'Humanitarian Aid;Guaido, Juan;Maduro, Nicolas;Venezuela;Demonstrations, Protests and Riots;Politics and Government;United States Agency for International Development;Video Recordings, Downloads and Streaming;Rumors and Misinformation',
#    'column': None,
#    'section': 'World',
#    'byline': 'By NICHOLAS CASEY, CHRISTOPH KOETTL and DEBORAH ACOSTA',
#    'type': 'Article',
#    'title': 'Footage Contradicts U.S. Claim That Nicolás Maduro Burned Aid Convoy',
#    'abstract': 'A reconstruction of the moment when a truck bearing humanitarian supplies was set on fire shows the likely cause was a Molotov cocktail thrown by a protester.',
#    'published_date': '2019-03-10',
#    'source': 'The New York Times',
#    'id': 100000006400090,
#    'asset_id': 100000006400090,
#    'views': 17,
#    'des_facet': ['POLITICS AND GOVERNMENT', 'RUMORS AND MISINFORMATION'],
#    'org_facet': ['HUMANITARIAN AID',
#     'DEMONSTRATIONS, PROTESTS AND RIOTS',
#     'UNITED STATES AGENCY FOR INTERNATIONAL DEVELOPMENT',
#     'VIDEO RECORDINGS, DOWNLOADS AND STREAMING'],
#    'per_facet': ['GUAIDO, JUAN', 'MADURO, NICOLAS'],
#    'geo_facet': ['VENEZUELA'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Natasha Vásquez/Afp',
#      'approved_for_syndication': 0,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/11/world/americas/11a2-truck/AIDTRUCK-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/11/world/americas/11a2-truck/AIDTRUCK-mediumThreeByTwo210-v2.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/11/world/americas/11a2-truck/AIDTRUCK-mediumThreeByTwo440-v2.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/b8b9ab4e-90c7-57d1-b65f-8fe3b8328674'},
#   {'url': 'https://www.nytimes.com/2019/03/07/opinion/ilhan-omar-anti-semitism.html',
#    'adx_keywords': 'Omar, Ilhan;Anti-Semitism;Israel;Jews and Judaism;Pelosi, Nancy;Democratic Party;House of Representatives;United States Politics and Government',
#    'column': None,
#    'section': 'Opinion',
#    'byline': 'By BRET STEPHENS',
#    'type': 'Article',
#    'title': 'Ilhan Omar Knows Exactly What She Is Doing',
#    'abstract': 'The Minnesota Democrat is bringing Corbynism to the Democratic Party.',
#    'published_date': '2019-03-07',
#    'source': 'The New York Times',
#    'id': 100000006397212,
#    'asset_id': 100000006397212,
#    'views': 18,
#    'des_facet': ['ANTI-SEMITISM',
#     'JEWS AND JUDAISM',
#     'UNITED STATES POLITICS AND GOVERNMENT'],
#    'org_facet': ['DEMOCRATIC PARTY', 'HOUSE OF REPRESENTATIVES'],
#    'per_facet': ['OMAR, ILHAN', 'PELOSI, NANCY'],
#    'geo_facet': ['ISRAEL'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Representative Ilhan Omar in Washington on Wednesday.',
#      'copyright': 'Mark Wilson/Getty Images',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/06/opinion/06stephensWeb/06stephensWeb-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/06/opinion/06stephensWeb/06stephensWeb-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/06/opinion/06stephensWeb/06stephensWeb-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/9eaf1564-54c0-551c-9180-9a3f07880c81'},
#   {'url': 'https://www.nytimes.com/interactive/2019/03/24/us/politics/barr-letter-mueller-report.html',
#    'adx_keywords': 'Mueller, Robert S III;Russian Interference in 2016 US Elections and Ties to Trump Associates;Trump, Donald J;Justice Department;Barr, William P',
#    'column': '',
#    'section': 'U.S.',
#    'byline': 'By THE NEW YORK TIMES',
#    'type': 'Interactive',
#    'title': 'Read Attorney General William Barr’s Summary of the Mueller Report',
#    'abstract': 'The letter, by Attorney General William P. Barr, details the main findings of the special counsel’s two-year investigation into Russian interference in the 2016 presidential election.',
#    'published_date': '2019-03-24',
#    'source': 'The New York Times',
#    'id': 100000006374989,
#    'asset_id': 100000006374989,
#    'views': 19,
#    'des_facet': ['RUSSIAN INTERFERENCE IN 2016 US ELECTIONS AND TIES TO TRUMP ASSOCIATES'],
#    'org_facet': ['JUSTICE DEPARTMENT'],
#    'per_facet': ['MUELLER, ROBERT S III',
#     'TRUMP, DONALD J',
#     'BARR, WILLIAM P'],
#    'geo_facet': '',
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': None,
#      'copyright': None,
#      'approved_for_syndication': 0,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/24/us/politics/barr-letter-mueller-report-1553456906394/barr-letter-mueller-report-1553456906394-thumbStandard-v3.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/24/us/politics/barr-letter-mueller-report-1553456906394/barr-letter-mueller-report-1553456906394-mediumThreeByTwo210-v3.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/24/us/politics/barr-letter-mueller-report-1553456906394/barr-letter-mueller-report-1553456906394-mediumThreeByTwo440-v3.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://interactive/c3d65284-19ac-57fb-a9a8-56cac730abb0'},
#   {'url': 'https://www.nytimes.com/2019/03/22/us/politics/mueller-report.html',
#    'adx_keywords': 'United States Politics and Government;Russian Interference in 2016 US Elections and Ties to Trump Associates;Presidential Election of 2016;Special Prosecutors (Independent Counsel);Justice Department;Mueller, Robert S III;Trump, Donald J;Barr, William P',
#    'column': None,
#    'section': 'U.S.',
#    'byline': 'By SHARON LaFRANIERE and KATIE BENNER',
#    'type': 'Article',
#    'title': 'Mueller Delivers Report on Trump-Russia Investigation to Attorney General',
#    'abstract': 'Now the attorney general must decide how much of the report — one of the most highly anticipated documents in Washington in a generation — to make public.',
#    'published_date': '2019-03-22',
#    'source': 'The New York Times',
#    'id': 100000006422774,
#    'asset_id': 100000006422774,
#    'views': 20,
#    'des_facet': ['UNITED STATES POLITICS AND GOVERNMENT',
#     'RUSSIAN INTERFERENCE IN 2016 US ELECTIONS AND TIES TO TRUMP ASSOCIATES',
#     'PRESIDENTIAL ELECTION OF 2016'],
#    'org_facet': ['SPECIAL PROSECUTORS (INDEPENDENT COUNSEL)',
#     'JUSTICE DEPARTMENT'],
#    'per_facet': ['MUELLER, ROBERT S III',
#     'TRUMP, DONALD J',
#     'BARR, WILLIAM P'],
#    'geo_facet': '',
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The Justice Department is preparing to receive a report from the special counsel, Robert S. Mueller III, and will decide how much of it to make public.',
#      'copyright': 'Doug Mills/The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/25/us/politics/25a2_railphoto/22dc-mueller-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2019/03/25/us/politics/25a2_railphoto/22dc-mueller-1-print-mediumThreeByTwo210-v3.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2019/03/25/us/politics/25a2_railphoto/22dc-mueller-1-print-mediumThreeByTwo440-v3.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'uri': 'nyt://article/05d46ff2-3cf7-54e4-bb53-630487c90781'}]}

# %%
#extract actual data from the json file
most_pop_res = pop['results']
most_pop_res
# Out:
# [{'url': 'https://www.nytimes.com/2019/03/28/health/woman-pain-anxiety.html',
#   'adx_keywords': 'Pain;Anxiety and Stress;Cameron, Jo;Srivastava, Devjit;British Journal of Anaesthesia;Genetics and Heredity;Opioids and Opiates;Pain-Relieving Drugs;University College London;Scotland',
#   'column': None,
#   'section': 'Health',
#   'byline': 'By HEATHER MURPHY',
#   'type': 'Article',
#   'title': 'At 71, She’s Never Felt Pain or Anxiety. Now Scientists Know Why.',
#   'abstract': 'Scientists discovered a previously unidentified genetic mutation in a Scottish woman. They hope it could lead to the development of new pain treatment.',
#   'published_date': '2019-03-28',
#   'source': 'The New York Times',
#   'id': 100000006432324,
#   'asset_id': 100000006432324,
#   'views': 1,
#   'des_facet': ['ANXIETY AND STRESS',
#    'GENETICS AND HEREDITY',
#    'OPIOIDS AND OPIATES',
#    'PAIN-RELIEVING DRUGS'],
#   'org_facet': ['PAIN',
#    'BRITISH JOURNAL OF ANAESTHESIA',
#    'UNIVERSITY COLLEGE LONDON'],
#   'per_facet': ['CAMERON, JO', 'SRIVASTAVA, DEVJIT'],
#   'geo_facet': ['SCOTLAND'],
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Jo Cameron, 71, has a rare gene mutation that scientists believe inhibits her from feeling pain or anxiety.',
#     'copyright': 'Mary Turner for The New York Times',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/27/science/27xp-nopain/27xp-nopain-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/27/science/27xp-nopain/27xp-nopain-mediumThreeByTwo210.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/27/science/27xp-nopain/27xp-nopain-mediumThreeByTwo440.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/02e0395b-1496-540a-8e5f-6687a52a6fca'},
#  {'url': 'https://www.nytimes.com/2019/03/12/us/felicity-huffman-lori-loughlin-massimo-giannulli.html',
#   'adx_keywords': 'College Admissions Scandal (2019);Admissions Standards;Colleges and Universities;Bribery and Kickbacks;Cheating;Frauds and Swindling;Huffman, Felicity;Loughlin, Lori;Giannulli, Mossimo',
#   'column': None,
#   'section': 'U.S.',
#   'byline': 'By REBECCA HALLECK',
#   'type': 'Article',
#   'title': 'Who’s Been Charged in the College Admissions Cheating Scandal? Here’s the Full List',
#   'abstract': 'The actresses Felicity Huffman and Lori Loughlin and the fashion designer Mossimo Giannulli are among the 50 people charged in a bribery scheme to secure places for students in elite colleges.',
#   'published_date': '2019-03-12',
#   'source': 'The New York Times',
#   'id': 100000006406229,
#   'asset_id': 100000006406229,
#   'views': 2,
#   'des_facet': ['ADMISSIONS STANDARDS',
#    'COLLEGES AND UNIVERSITIES',
#    'BRIBERY AND KICKBACKS',
#    'FRAUDS AND SWINDLING'],
#   'org_facet': ['COLLEGE ADMISSIONS SCANDAL (2019)', 'CHEATING'],
#   'per_facet': ['HUFFMAN, FELICITY', 'LOUGHLIN, LORI', 'GIANNULLI, MOSSIMO'],
#   'geo_facet': '',
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': 'From left: Lori Loughlin, Mossimo Giannulli and Felicity Huffman.',
#     'copyright': 'From left: AFP -- Getty Images; Reuters and AP',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/12/us/12college-whois-hp/12college-whois-alt-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/12/us/12college-whois-hp/12college-whois-alt-mediumThreeByTwo210.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/12/us/12college-whois-hp/12college-whois-alt-mediumThreeByTwo440.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/50b479fd-7f67-54d5-91ec-b60178e83d83'},
#  {'url': 'https://www.nytimes.com/2019/03/12/us/college-admissions-cheating-scandal.html',
#   'adx_keywords': 'College Admissions Scandal (2019);Colleges and Universities;Admissions Standards;Cheating;Bribery and Kickbacks;Frauds and Swindling;Singer, William Rick;Edge College and Career Network;Huffman, Felicity;Loughlin, Lori;McGlashan, William E Jr;Yale University;Wake Forest University;Stanford University;University of Southern California',
#   'column': None,
#   'section': 'U.S.',
#   'byline': 'By JENNIFER MEDINA, KATIE BENNER and KATE TAYLOR',
#   'type': 'Article',
#   'title': 'Actresses, Business Leaders and Other Wealthy Parents Charged in U.S. College Entry Fraud',
#   'abstract': 'A sprawling federal investigation accuses 50 people of involvement in a scheme to get undeserving students into major American universities.',
#   'published_date': '2019-03-12',
#   'source': 'The New York Times',
#   'id': 100000006406075,
#   'asset_id': 100000006406075,
#   'views': 3,
#   'des_facet': ['COLLEGES AND UNIVERSITIES',
#    'ADMISSIONS STANDARDS',
#    'CHEATING'],
#   'org_facet': ['COLLEGE ADMISSIONS SCANDAL (2019)',
#    'BRIBERY AND KICKBACKS',
#    'FRAUDS AND SWINDLING',
#    'EDGE COLLEGE AND CAREER NETWORK',
#    'YALE UNIVERSITY',
#    'WAKE FOREST UNIVERSITY',
#    'STANFORD UNIVERSITY',
#    'UNIVERSITY OF SOUTHERN CALIFORNIA'],
#   'per_facet': ['SINGER, WILLIAM RICK',
#    'HUFFMAN, FELICITY',
#    'LOUGHLIN, LORI',
#    'MCGLASHAN, WILLIAM E JR'],
#   'geo_facet': '',
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Steven Senne/Associated Press',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/12/us/12college-raid-sub/12college-raid-sub-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/12/us/12college-raid-sub/12college-raid-sub-mediumThreeByTwo210.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/12/us/12college-raid-sub/12college-raid-sub-mediumThreeByTwo440.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/bac76e87-b5fc-54fa-8c0f-46a0688effba'},
#  {'url': 'https://www.nytimes.com/interactive/2019/arts/television/best-movies-on-netflix.html',
#   'adx_keywords': 'Netflix Inc;Movies;Video Recordings, Downloads and Streaming',
#   'column': '',
#   'section': 'Arts',
#   'byline': 'By JASON BAILEY',
#   'type': 'Interactive',
#   'title': 'The 50 Best Movies on Netflix Right Now',
#   'abstract': 'We’ve plucked out the 50 best films currently streaming on Netflix in the United States. Take a look.',
#   'published_date': '2019-03-06',
#   'source': 'The New York Times',
#   'id': 100000006330108,
#   'asset_id': 100000006330108,
#   'views': 4,
#   'des_facet': ['MOVIES', 'VIDEO RECORDINGS, DOWNLOADS AND STREAMING'],
#   'org_facet': ['NETFLIX INC'],
#   'per_facet': '',
#   'geo_facet': '',
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Uma Thurman in “Pulp Fiction.”',
#     'copyright': 'Linda R. Chen/Miramax Films',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2016/06/19/watching/pulp-fiction-watching-recommendation/pulp-fiction-watching-recommendation-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2016/06/19/watching/pulp-fiction-watching-recommendation/pulp-fiction-watching-recommendation-mediumThreeByTwo210.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2016/06/19/watching/pulp-fiction-watching-recommendation/pulp-fiction-watching-recommendation-mediumThreeByTwo440.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://interactive/3769fe44-d294-5a71-8281-5220a39673bf'},
#  {'url': 'https://www.nytimes.com/2019/03/16/style/snowplow-parenting-scandal.html',
#   'adx_keywords': 'Admissions Standards;Colleges and Universities;College Admissions Scandal (2019);Parenting;Tests and Examinations;SAT (College Admission Test);Education (K-12)',
#   'column': None,
#   'section': 'Style',
#   'byline': 'By CLAIRE CAIN MILLER and JONAH ENGEL BROMWICH',
#   'type': 'Article',
#   'title': 'How Parents Are Robbing Their Children of Adulthood',
#   'abstract': 'Today’s “snowplow parents” keep their children’s futures obstacle-free — even when it means crossing ethical and legal boundaries.',
#   'published_date': '2019-03-16',
#   'source': 'The New York Times',
#   'id': 100000006411881,
#   'asset_id': 100000006411881,
#   'views': 5,
#   'des_facet': ['ADMISSIONS STANDARDS',
#    'COLLEGES AND UNIVERSITIES',
#    'PARENTING',
#    'TESTS AND EXAMINATIONS'],
#   'org_facet': ['COLLEGE ADMISSIONS SCANDAL (2019)',
#    'SAT (COLLEGE ADMISSION TEST)',
#    'EDUCATION (K-12)'],
#   'per_facet': '',
#   'geo_facet': '',
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Illustration by The New York Times',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/17/style/17snowplow-1/17snowplow-1-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/17/style/17snowplow-1/17snowplow-1-mediumThreeByTwo210-v2.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/17/style/17snowplow-1/17snowplow-1-mediumThreeByTwo440-v2.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/08baa5d4-b67b-5e29-8212-7c64d8978670'},
#  {'url': 'https://www.nytimes.com/2019/03/25/smarter-living/why-you-procrastinate-it-has-nothing-to-do-with-self-control.html',
#   'adx_keywords': 'Procrastination;Emotions;Psychology and Psychologists;Anxiety and Stress;Boredom',
#   'column': None,
#   'section': 'Smarter Living',
#   'byline': 'By CHARLOTTE LIEBERMAN',
#   'type': 'Article',
#   'title': 'Why You Procrastinate (It Has Nothing to Do With Self-Control)',
#   'abstract': 'If procrastination isn’t about laziness, then what is it about?',
#   'published_date': '2019-03-25',
#   'source': 'The New York Times',
#   'id': 100000006416140,
#   'asset_id': 100000006416140,
#   'views': 6,
#   'des_facet': ['PROCRASTINATION',
#    'PSYCHOLOGY AND PSYCHOLOGISTS',
#    'ANXIETY AND STRESS'],
#   'org_facet': ['EMOTIONS', 'BOREDOM'],
#   'per_facet': '',
#   'geo_facet': '',
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Erik Winkowski',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/25/smarter-living/25sl_procrastination_promo/25sl_procrastination_promo-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/25/smarter-living/25sl_procrastination_promo/25sl_procrastination_promo-mediumThreeByTwo210.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/25/smarter-living/25sl_procrastination_promo/25sl_procrastination_promo-mediumThreeByTwo440.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/166a9d7f-8edd-5ae8-88e5-30a6e80e646e'},
#  {'url': 'https://www.nytimes.com/2019/04/03/us/politics/william-barr-mueller-report.html',
#   'adx_keywords': 'Trump, Donald J;Mueller, Robert S III;Barr, William P;Russian Interference in 2016 US Elections and Ties to Trump Associates;Special Prosecutors (Independent Counsel);Justice Department;Attorneys General;United States Politics and Government',
#   'column': None,
#   'section': 'U.S.',
#   'byline': 'By NICHOLAS FANDOS, MICHAEL S. SCHMIDT and MARK MAZZETTI',
#   'type': 'Article',
#   'title': 'Some on Mueller’s Team Say Report Was More Damaging Than Barr Revealed',
#   'abstract': 'Members of the special counsel’s team have told associates that their findings are more troubling for President Trump than the attorney general indicated.',
#   'published_date': '2019-04-03',
#   'source': 'The New York Times',
#   'id': 100000006441465,
#   'asset_id': 100000006441465,
#   'views': 7,
#   'des_facet': ['RUSSIAN INTERFERENCE IN 2016 US ELECTIONS AND TIES TO TRUMP ASSOCIATES',
#    'UNITED STATES POLITICS AND GOVERNMENT'],
#   'org_facet': ['SPECIAL PROSECUTORS (INDEPENDENT COUNSEL)',
#    'JUSTICE DEPARTMENT',
#    'ATTORNEYS GENERAL'],
#   'per_facet': ['TRUMP, DONALD J', 'MUELLER, ROBERT S III', 'BARR, WILLIAM P'],
#   'geo_facet': '',
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Attorney General William P. Barr has shown hints of frustration with how the rollout of the special counsel’s chief findings has unfolded.<br /><br />',
#     'copyright': 'Sarah Silbiger/The New York Times',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/05/03/us/03dc-mueller-promo/merlin_152946042_2d0da3b4-7ed5-47a4-bc93-0b1234b85a54-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/05/03/us/03dc-mueller-promo/merlin_152946042_2d0da3b4-7ed5-47a4-bc93-0b1234b85a54-mediumThreeByTwo210.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/05/03/us/03dc-mueller-promo/merlin_152946042_2d0da3b4-7ed5-47a4-bc93-0b1234b85a54-mediumThreeByTwo440.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/6d5ac849-af3f-5a1b-90f7-88f56c37dabd'},
#  {'url': 'https://www.nytimes.com/2019/03/21/business/boeing-safety-features-charge.html',
#   'adx_keywords': 'Boeing 737 Max Groundings and Safety Concerns (2019);Aviation Accidents, Safety and Disasters;Airlines and Airplanes;Boeing Company;Ethiopian Airlines;Lion Air;Regulation and Deregulation of Industry',
#   'column': None,
#   'section': 'Business',
#   'byline': 'By HIROKO TABUCHI and DAVID GELLES',
#   'type': 'Article',
#   'title': 'Doomed Boeing Jets Lacked 2 Safety Features That Company Sold Only as Extras',
#   'abstract': 'Airlines had to pay more for two optional upgrades that could warn pilots about sensor malfunctions. Boeing now plans to make one of the features standard.',
#   'published_date': '2019-03-21',
#   'source': 'The New York Times',
#   'id': 100000006421007,
#   'asset_id': 100000006421007,
#   'views': 8,
#   'des_facet': ['BOEING 737 MAX GROUNDINGS AND SAFETY CONCERNS (2019)',
#    'AVIATION ACCIDENTS, SAFETY AND DISASTERS',
#    'AIRLINES AND AIRPLANES'],
#   'org_facet': ['BOEING COMPANY',
#    'ETHIOPIAN AIRLINES',
#    'LION AIR',
#    'REGULATION AND DEREGULATION OF INDUSTRY'],
#   'per_facet': '',
#   'geo_facet': '',
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Standard 737 Max planes are not equipped with a so-called angle of attack indicator or an angle of attack disagree light. The indicator will continue to cost airlines extra, but the light won’t.',
#     'copyright': 'Ruth Fremson/The New York Times',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/23/business/23boeing1/20boeing1-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/23/business/23boeing1/20boeing1-mediumThreeByTwo210.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/23/business/23boeing1/20boeing1-mediumThreeByTwo440.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/b8a29461-75dc-56ee-8f4b-e076749b6a6d'},
#  {'url': 'https://www.nytimes.com/2019/03/14/world/boeing-737-max-ethiopian-airlines.html',
#   'adx_keywords': 'Boeing 737 Max Groundings and Safety Concerns (2019);Aviation Accidents, Safety and Disasters;Getachew, Yared;Boeing Company;Federal Aviation Administration;Ethiopian Airlines',
#   'column': None,
#   'section': 'World',
#   'byline': 'By SELAM GEBREKIDAN and JAMES GLANZ',
#   'type': 'Article',
#   'title': 'Boeing 737 Max Hit Trouble Right Away, Pilot’s Tense Radio Messages Show',
#   'abstract': '“Break break, request back to home,” the captain of the ill-fated Ethiopian Airlines flight radioed air traffic controllers minutes after taking off.',
#   'published_date': '2019-03-14',
#   'source': 'The New York Times',
#   'id': 100000006410242,
#   'asset_id': 100000006410242,
#   'views': 9,
#   'des_facet': ['BOEING 737 MAX GROUNDINGS AND SAFETY CONCERNS (2019)',
#    'AVIATION ACCIDENTS, SAFETY AND DISASTERS'],
#   'org_facet': ['BOEING COMPANY',
#    'FEDERAL AVIATION ADMINISTRATION',
#    'ETHIOPIAN AIRLINES'],
#   'per_facet': ['GETACHEW, YARED'],
#   'geo_facet': '',
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A memorial arch on Thursday at the site of the jet crash in Ethiopia.',
#     'copyright': 'Jemal Countess/Getty Images',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/14/business/14boeing3/14boeing3-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/14/business/14boeing3/14boeing3-mediumThreeByTwo210.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/14/business/14boeing3/14boeing3-mediumThreeByTwo440.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/63411a1f-beed-55ff-99b5-7c382acf1d83'},
#  {'url': 'https://www.nytimes.com/2019/03/15/world/asia/new-zealand-shooting.html',
#   'adx_keywords': 'Murders, Attempted Murders and Homicides;Christchurch, New Zealand, Attack (March 2019);Mosques;Terrorism;Muslims and Islam;New Zealand;Social Media;Christchurch (New Zealand)',
#   'column': None,
#   'section': 'World',
#   'byline': 'By THE NEW YORK TIMES',
#   'type': 'Article',
#   'title': 'Jacinda Ardern Consoles Families After New Zealand Shooting',
#   'abstract': 'The attack on two mosques, which appeared to have been carried out by a white extremist, left 49 dead in the city of Christchurch.',
#   'published_date': '2019-03-15',
#   'source': 'The New York Times',
#   'id': 100000006412038,
#   'asset_id': 100000006412038,
#   'views': 10,
#   'des_facet': ['MURDERS, ATTEMPTED MURDERS AND HOMICIDES',
#    'CHRISTCHURCH, NEW ZEALAND, ATTACK (MARCH 2019)',
#    'MOSQUES'],
#   'org_facet': ['TERRORISM', 'MUSLIMS AND ISLAM', 'SOCIAL MEDIA'],
#   'per_facet': '',
#   'geo_facet': ['NEW ZEALAND', 'CHRISTCHURCH (NEW ZEALAND)'],
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A makeshift memorial in Christchurch, New Zealand, on Saturday.',
#     'copyright': 'Matthew Abbott for The New York Times',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/16/world/16nz-shooting-2/16nz-shooting-2-thumbStandard-v2.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/16/world/16nz-shooting-2/16nz-shooting-2-mediumThreeByTwo210-v2.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/16/world/16nz-shooting-2/16nz-shooting-2-mediumThreeByTwo440-v2.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/54ac784c-9e89-5526-8fa3-4e7734eb5888'},
#  {'url': 'https://www.nytimes.com/2019/03/24/us/politics/mueller-report-summary.html',
#   'adx_keywords': 'Russian Interference in 2016 US Elections and Ties to Trump Associates;Mueller, Robert S III;Trump, Donald J;United States Politics and Government;Special Prosecutors (Independent Counsel);Justice Department;Russia;Barr, William P;Presidential Election of 2016',
#   'column': None,
#   'section': 'U.S.',
#   'byline': 'By MARK MAZZETTI and KATIE BENNER',
#   'type': 'Article',
#   'title': 'Mueller Finds No Trump-Russia Conspiracy, but Stops Short of Exonerating President on Obstruction',
#   'abstract': 'The attorney general released the main findings of the closely watched investigation into Russia’s election interference and whether Trump associates conspired.',
#   'published_date': '2019-03-24',
#   'source': 'The New York Times',
#   'id': 100000006425832,
#   'asset_id': 100000006425832,
#   'views': 11,
#   'des_facet': ['RUSSIAN INTERFERENCE IN 2016 US ELECTIONS AND TIES TO TRUMP ASSOCIATES',
#    'UNITED STATES POLITICS AND GOVERNMENT',
#    'PRESIDENTIAL ELECTION OF 2016'],
#   'org_facet': ['SPECIAL PROSECUTORS (INDEPENDENT COUNSEL)',
#    'JUSTICE DEPARTMENT'],
#   'per_facet': ['MUELLER, ROBERT S III', 'TRUMP, DONALD J', 'BARR, WILLIAM P'],
#   'geo_facet': ['RUSSIA'],
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The special counsel, Robert S. Mueller III, and his wife, Ann Standish, near the White House after attending church on Sunday.',
#     'copyright': 'Cliff Owen/Associated Press',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/26/us/politics/26dc-cong-promo/24dc-cong-promo-thumbStandard-v2.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/26/us/politics/26dc-cong-promo/24dc-cong-promo-mediumThreeByTwo210-v2.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/26/us/politics/26dc-cong-promo/24dc-cong-promo-mediumThreeByTwo440-v2.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/0e82d026-fa9b-5802-9df6-b65dfc662b70'},
#  {'url': 'https://www.nytimes.com/interactive/2019/03/11/world/boeing-737-max-which-airlines.html',
#   'adx_keywords': 'Airlines and Airplanes;Boeing Company;Aviation Accidents, Safety and Disasters;Lion Air;Ethiopian Airlines;Addis Ababa (Ethiopia);Southwest Airlines Company;American Airlines;Air Canada;China Southern Airlines;Norwegian Air Shuttle ASA;Air China;SpiceJet;Turkish Airlines;Flydubai',
#   'column': '',
#   'section': 'World',
#   'byline': 'By DENISE LU, ALLISON McCANN, JIN WU and K.K. REBECCA LAI',
#   'type': 'Interactive',
#   'title': 'From 8,600 Flights to Zero: Grounding the Boeing 737 Max 8',
#   'abstract': 'China was the first major country to ground the jets. The U.S. was last.',
#   'published_date': '2019-03-11',
#   'source': 'The New York Times',
#   'id': 100000006404643,
#   'asset_id': 100000006404643,
#   'views': 12,
#   'des_facet': ['AIRLINES AND AIRPLANES',
#    'AVIATION ACCIDENTS, SAFETY AND DISASTERS'],
#   'org_facet': ['BOEING COMPANY',
#    'LION AIR',
#    'ETHIOPIAN AIRLINES',
#    'SOUTHWEST AIRLINES COMPANY',
#    'AMERICAN AIRLINES',
#    'AIR CANADA',
#    'CHINA SOUTHERN AIRLINES',
#    'NORWEGIAN AIR SHUTTLE ASA',
#    'AIR CHINA',
#    'SPICEJET',
#    'TURKISH AIRLINES',
#    'FLYDUBAI'],
#   'per_facet': '',
#   'geo_facet': ['ADDIS ABABA (ETHIOPIA)'],
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': '',
#     'approved_for_syndication': 0,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/11/world/where-boeing-737-max-flies-1552329118347/where-boeing-737-max-flies-1552329118347-thumbStandard-v15.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/11/world/where-boeing-737-max-flies-1552329118347/where-boeing-737-max-flies-1552329118347-mediumThreeByTwo210-v15.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/11/world/where-boeing-737-max-flies-1552329118347/where-boeing-737-max-flies-1552329118347-mediumThreeByTwo440-v15.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://interactive/7fcc105c-d025-5f27-841e-e00292eeb4ab'},
#  {'url': 'https://www.nytimes.com/interactive/2019/arts/television/best-drama-series.html',
#   'adx_keywords': "Television;The Sopranos (TV Program);The Americans (TV Program);Adventure Time (TV Program);The Leftovers (TV Program);Lost (TV Program);The West Wing (TV Program);Game of Thrones (TV Program);Deadwood (TV Program);Jane the Virgin (TV Program);Halt and Catch Fire (TV Program);Breaking Bad (TV Program);The Wire (TV Program);Justified (TV Program);The Good Wife (TV Program);Queen Sugar (TV Program);Grey's Anatomy (TV Program);Mad Men (TV Program);Friday Night Lights (TV Program);Gunn, Anna;Beetz, Zazie;Weiner, Matthew (1965- );Lindelof, Damon;Wright, Alison (1976- )",
#   'column': '',
#   'section': 'Arts',
#   'byline': 'By THE NEW YORK TIMES',
#   'type': 'Interactive',
#   'title': 'The 20 Best TV Dramas Since ‘The Sopranos’',
#   'abstract': 'It’s been 20 years since those ducks landed in Tony’s pool. A flock of extraordinary shows followed. These are the best dramas since 1999.',
#   'published_date': '2019-01-10',
#   'source': 'The New York Times',
#   'id': 100000006297737,
#   'asset_id': 100000006297737,
#   'views': 13,
#   'des_facet': ['TELEVISION'],
#   'org_facet': '',
#   'per_facet': ['GUNN, ANNA',
#    'BEETZ, ZAZIE',
#    'WEINER, MATTHEW (1965- )',
#    'LINDELOF, DAMON',
#    'WRIGHT, ALISON (1976- )'],
#   'geo_facet': '',
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Illustration by Pedro Piccinini. “Breaking Bad,” AMC.',
#     'approved_for_syndication': 0,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/01/09/arts/television/besttv-breakingbad/besttv-breakingbad-thumbStandard.png',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/01/09/arts/television/besttv-breakingbad/besttv-breakingbad-mediumThreeByTwo210.png',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/01/09/arts/television/besttv-breakingbad/besttv-breakingbad-mediumThreeByTwo440.png',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://interactive/ecdf0eeb-8049-53a9-abf6-f430eb3f4104'},
#  {'url': 'https://www.nytimes.com/interactive/2019/04/03/magazine/rupert-murdoch-fox-news-trump.html',
#   'adx_keywords': 'News and News Media;Presidential Election of 2016;United States Politics and Government;Cable Television;Regulation and Deregulation of Industry;Conservatism (US Politics);Antitrust Laws and Competition Issues;Family Business;21st Century Fox;Fox Broadcasting Co;Fox Entertainment Group Inc;Fox News Channel;New York Post;News Corporation;News of the World;Sky PLC;Sky Television;Sun, The (British Newspaper);Times of London;Twentieth Century Fox;Wall Street Journal;Hall, Jerry;Ailes, Roger E;Hannity, Sean;Murdoch, James R;Murdoch, Lachlan;Murdoch, Rupert;Trump, Donald J;Trump, Ivanka;Kushner, Jared;Australia;Great Britain;Great Britain Withdrawal from EU (Brexit)',
#   'column': '',
#   'section': 'Magazine',
#   'byline': 'By JONATHAN MAHLER and JIM RUTENBERG',
#   'type': 'Interactive',
#   'title': 'How Rupert Murdoch’s Empire of Influence Remade the World',
#   'abstract': 'Murdoch and his children have toppled governments on two continents and destabilized the most important democracy on Earth. What do they want?',
#   'published_date': '2019-04-03',
#   'source': 'The New York Times',
#   'id': 100000006439740,
#   'asset_id': 100000006439740,
#   'views': 14,
#   'des_facet': ['NEWS AND NEWS MEDIA',
#    'PRESIDENTIAL ELECTION OF 2016',
#    'GREAT BRITAIN WITHDRAWAL FROM EU (BREXIT)'],
#   'org_facet': ['UNITED STATES POLITICS AND GOVERNMENT',
#    'CABLE TELEVISION',
#    'REGULATION AND DEREGULATION OF INDUSTRY',
#    'CONSERVATISM (US POLITICS)',
#    'ANTITRUST LAWS AND COMPETITION ISSUES',
#    'FAMILY BUSINESS',
#    '21ST CENTURY FOX',
#    'FOX BROADCASTING CO',
#    'FOX ENTERTAINMENT GROUP INC',
#    'FOX NEWS CHANNEL',
#    'NEW YORK POST',
#    'NEWS CORPORATION',
#    'NEWS OF THE WORLD',
#    'SKY PLC',
#    'SKY TELEVISION',
#    'SUN, THE (BRITISH NEWSPAPER)',
#    'TIMES OF LONDON',
#    'TWENTIETH CENTURY FOX',
#    'WALL STREET JOURNAL'],
#   'per_facet': ['HALL, JERRY',
#    'AILES, ROGER E',
#    'HANNITY, SEAN',
#    'MURDOCH, JAMES R',
#    'MURDOCH, LACHLAN',
#    'MURDOCH, RUPERT',
#    'TRUMP, DONALD J',
#    'TRUMP, IVANKA',
#    'KUSHNER, JARED'],
#   'geo_facet': ['AUSTRALIA', 'GREAT BRITAIN'],
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Photo illustration by Joan Wong',
#     'approved_for_syndication': 0,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/04/07/magazine/07mag-murdoch-promo-image-1/07mag-murdoch-promo-image-1-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/04/07/magazine/07mag-murdoch-promo-image-1/07mag-murdoch-promo-image-1-mediumThreeByTwo210.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/04/07/magazine/07mag-murdoch-promo-image-1/07mag-murdoch-promo-image-1-mediumThreeByTwo440.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://interactive/1401f501-2f5c-5a0c-bee7-1a5b28dfc4e4'},
#  {'url': 'https://www.nytimes.com/2019/03/18/business/trump-deutsche-bank.html',
#   'adx_keywords': 'Trump, Donald J;Deutsche Bank AG;Banking and Financial Institutions;Real Estate (Commercial);United States Politics and Government;Presidential Election of 2016;Credit and Debt;Trump Organization;Jain, Anshu;Vrablic, Rosemary T;Kushner, Jared;Offit, Mike;Manhattan (NYC);Kennedy, Justin A;Trump International Hotel and Tower (Chicago, Ill)',
#   'column': None,
#   'section': 'Business',
#   'byline': 'By DAVID ENRICH',
#   'type': 'Article',
#   'title': 'A Mar-a-Lago Weekend and an Act of God: Trump’s History With Deutsche Bank',
#   'abstract': 'Deutsche Bank’s hunger for profits and risk led it to lend Donald Trump more than $2 billion. Once he was elected president, employees were told not to utter his name.',
#   'published_date': '2019-03-18',
#   'source': 'The New York Times',
#   'id': 100000006408304,
#   'asset_id': 100000006408304,
#   'views': 15,
#   'des_facet': ['BANKING AND FINANCIAL INSTITUTIONS',
#    'UNITED STATES POLITICS AND GOVERNMENT',
#    'PRESIDENTIAL ELECTION OF 2016'],
#   'org_facet': ['DEUTSCHE BANK AG',
#    'REAL ESTATE (COMMERCIAL)',
#    'CREDIT AND DEBT',
#    'TRUMP ORGANIZATION',
#    'TRUMP INTERNATIONAL HOTEL AND TOWER (CHICAGO, ILL)'],
#   'per_facet': ['TRUMP, DONALD J',
#    'JAIN, ANSHU',
#    'VRABLIC, ROSEMARY T',
#    'KUSHNER, JARED',
#    'OFFIT, MIKE',
#    'KENNEDY, JUSTIN A'],
#   'geo_facet': ['MANHATTAN (NYC)'],
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': 'A Chicago skyscraper was the focus of a court battle between Mr. Trump and Deutsche Bank that equated the 2008 financial crisis with an act of God.',
#     'copyright': 'Nathan Weber for The New York Times',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/19/business/19deutsche-4/19deutsche-4-thumbStandard-v2.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/19/business/19deutsche-4/merlin_105779095_a31267d5-ed98-4dac-83ee-a4944e284f21-mediumThreeByTwo210.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/19/business/19deutsche-4/merlin_105779095_a31267d5-ed98-4dac-83ee-a4944e284f21-mediumThreeByTwo440.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/1154d6c4-5dc2-505d-8c61-1f14581b78ab'},
#  {'url': 'https://www.nytimes.com/interactive/2019/03/07/magazine/top-songs.html',
#   'adx_keywords': 'Pop and Rock Music;Rhythm and Blues (Music);Rap and Hip-Hop;Springsteen, Bruce;Grande, Ariana;Carey, Mariah;Meek Mill (Rapper);Lady Gaga;A Star Is Born (Movie);Scott, Travis (1992- );Baby Shark (Song);Knowles, Beyonce;Jay-Z;Juice WRLD (Rapper);Musgraves, Kacey;Post, Austin (Post Malone) (1995- );Whack, Tierra;Parquet Courts (Music Group);Grimes (1988- );Holter, Julia (1984- );Maroon 5 (Music Group);Robyn (1979- );6ix9ine (Rapper);Vila Tobella, Rosalia;1975, The (Music Group);Blake, James (1988- );Weezer (Music Group);Van Etten, Sharon;Sons of Kemet (Music Group);Davidson, Marie (1987- )',
#   'column': '',
#   'section': 'Magazine',
#   'byline': 'By THE NEW YORK TIMES MAGAZINE',
#   'type': 'Interactive',
#   'title': 'The Top 25 Songs That Matter Right Now',
#   'abstract': 'Listen to music — from the blockbuster hits, critical darlings and conversation pieces of the moment — few of which take a direct route to the usual joys of pop.',
#   'published_date': '2019-03-07',
#   'source': 'The New York Times',
#   'id': 100000006397390,
#   'asset_id': 100000006397390,
#   'views': 16,
#   'des_facet': ['POP AND ROCK MUSIC', 'RHYTHM AND BLUES (MUSIC)'],
#   'org_facet': ['RAP AND HIP-HOP',
#    'PARQUET COURTS (MUSIC GROUP)',
#    'MAROON 5 (MUSIC GROUP)',
#    '1975, THE (MUSIC GROUP)',
#    'WEEZER (MUSIC GROUP)',
#    'SONS OF KEMET (MUSIC GROUP)'],
#   'per_facet': ['SPRINGSTEEN, BRUCE',
#    'GRANDE, ARIANA',
#    'CAREY, MARIAH',
#    'MEEK MILL (RAPPER)',
#    'LADY GAGA',
#    'SCOTT, TRAVIS (1992- )',
#    'KNOWLES, BEYONCE',
#    'JAY-Z',
#    'JUICE WRLD (RAPPER)',
#    'MUSGRAVES, KACEY',
#    'POST, AUSTIN (POST MALONE) (1995- )',
#    'WHACK, TIERRA',
#    'GRIMES (1988- )',
#    'HOLTER, JULIA (1984- )',
#    'ROBYN (1979- )',
#    '6IX9INE (RAPPER)',
#    'VILA TOBELLA, ROSALIA',
#    'BLAKE, JAMES (1988- )',
#    'VAN ETTEN, SHARON',
#    'DAVIDSON, MARIE (1987- )'],
#   'geo_facet': '',
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': '',
#     'approved_for_syndication': 0,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/10/magazine/10mag-cover-vertical/10mag-cover-vertical-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/10/magazine/10mag-cover-vertical/10mag-cover-vertical-mediumThreeByTwo210-v2.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/10/magazine/10mag-cover-vertical/10mag-cover-vertical-mediumThreeByTwo440-v2.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://interactive/ca81636d-4df7-5f04-9660-148c7ca65d35'},
#  {'url': 'https://www.nytimes.com/2019/03/10/world/americas/venezuela-aid-fire-video.html',
#   'adx_keywords': 'Humanitarian Aid;Guaido, Juan;Maduro, Nicolas;Venezuela;Demonstrations, Protests and Riots;Politics and Government;United States Agency for International Development;Video Recordings, Downloads and Streaming;Rumors and Misinformation',
#   'column': None,
#   'section': 'World',
#   'byline': 'By NICHOLAS CASEY, CHRISTOPH KOETTL and DEBORAH ACOSTA',
#   'type': 'Article',
#   'title': 'Footage Contradicts U.S. Claim That Nicolás Maduro Burned Aid Convoy',
#   'abstract': 'A reconstruction of the moment when a truck bearing humanitarian supplies was set on fire shows the likely cause was a Molotov cocktail thrown by a protester.',
#   'published_date': '2019-03-10',
#   'source': 'The New York Times',
#   'id': 100000006400090,
#   'asset_id': 100000006400090,
#   'views': 17,
#   'des_facet': ['POLITICS AND GOVERNMENT', 'RUMORS AND MISINFORMATION'],
#   'org_facet': ['HUMANITARIAN AID',
#    'DEMONSTRATIONS, PROTESTS AND RIOTS',
#    'UNITED STATES AGENCY FOR INTERNATIONAL DEVELOPMENT',
#    'VIDEO RECORDINGS, DOWNLOADS AND STREAMING'],
#   'per_facet': ['GUAIDO, JUAN', 'MADURO, NICOLAS'],
#   'geo_facet': ['VENEZUELA'],
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Natasha Vásquez/Afp',
#     'approved_for_syndication': 0,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/11/world/americas/11a2-truck/AIDTRUCK-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/11/world/americas/11a2-truck/AIDTRUCK-mediumThreeByTwo210-v2.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/11/world/americas/11a2-truck/AIDTRUCK-mediumThreeByTwo440-v2.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/b8b9ab4e-90c7-57d1-b65f-8fe3b8328674'},
#  {'url': 'https://www.nytimes.com/2019/03/07/opinion/ilhan-omar-anti-semitism.html',
#   'adx_keywords': 'Omar, Ilhan;Anti-Semitism;Israel;Jews and Judaism;Pelosi, Nancy;Democratic Party;House of Representatives;United States Politics and Government',
#   'column': None,
#   'section': 'Opinion',
#   'byline': 'By BRET STEPHENS',
#   'type': 'Article',
#   'title': 'Ilhan Omar Knows Exactly What She Is Doing',
#   'abstract': 'The Minnesota Democrat is bringing Corbynism to the Democratic Party.',
#   'published_date': '2019-03-07',
#   'source': 'The New York Times',
#   'id': 100000006397212,
#   'asset_id': 100000006397212,
#   'views': 18,
#   'des_facet': ['ANTI-SEMITISM',
#    'JEWS AND JUDAISM',
#    'UNITED STATES POLITICS AND GOVERNMENT'],
#   'org_facet': ['DEMOCRATIC PARTY', 'HOUSE OF REPRESENTATIVES'],
#   'per_facet': ['OMAR, ILHAN', 'PELOSI, NANCY'],
#   'geo_facet': ['ISRAEL'],
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Representative Ilhan Omar in Washington on Wednesday.',
#     'copyright': 'Mark Wilson/Getty Images',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/06/opinion/06stephensWeb/06stephensWeb-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/06/opinion/06stephensWeb/06stephensWeb-mediumThreeByTwo210.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/06/opinion/06stephensWeb/06stephensWeb-mediumThreeByTwo440.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/9eaf1564-54c0-551c-9180-9a3f07880c81'},
#  {'url': 'https://www.nytimes.com/interactive/2019/03/24/us/politics/barr-letter-mueller-report.html',
#   'adx_keywords': 'Mueller, Robert S III;Russian Interference in 2016 US Elections and Ties to Trump Associates;Trump, Donald J;Justice Department;Barr, William P',
#   'column': '',
#   'section': 'U.S.',
#   'byline': 'By THE NEW YORK TIMES',
#   'type': 'Interactive',
#   'title': 'Read Attorney General William Barr’s Summary of the Mueller Report',
#   'abstract': 'The letter, by Attorney General William P. Barr, details the main findings of the special counsel’s two-year investigation into Russian interference in the 2016 presidential election.',
#   'published_date': '2019-03-24',
#   'source': 'The New York Times',
#   'id': 100000006374989,
#   'asset_id': 100000006374989,
#   'views': 19,
#   'des_facet': ['RUSSIAN INTERFERENCE IN 2016 US ELECTIONS AND TIES TO TRUMP ASSOCIATES'],
#   'org_facet': ['JUSTICE DEPARTMENT'],
#   'per_facet': ['MUELLER, ROBERT S III', 'TRUMP, DONALD J', 'BARR, WILLIAM P'],
#   'geo_facet': '',
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': None,
#     'copyright': None,
#     'approved_for_syndication': 0,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/24/us/politics/barr-letter-mueller-report-1553456906394/barr-letter-mueller-report-1553456906394-thumbStandard-v3.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/24/us/politics/barr-letter-mueller-report-1553456906394/barr-letter-mueller-report-1553456906394-mediumThreeByTwo210-v3.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/24/us/politics/barr-letter-mueller-report-1553456906394/barr-letter-mueller-report-1553456906394-mediumThreeByTwo440-v3.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://interactive/c3d65284-19ac-57fb-a9a8-56cac730abb0'},
#  {'url': 'https://www.nytimes.com/2019/03/22/us/politics/mueller-report.html',
#   'adx_keywords': 'United States Politics and Government;Russian Interference in 2016 US Elections and Ties to Trump Associates;Presidential Election of 2016;Special Prosecutors (Independent Counsel);Justice Department;Mueller, Robert S III;Trump, Donald J;Barr, William P',
#   'column': None,
#   'section': 'U.S.',
#   'byline': 'By SHARON LaFRANIERE and KATIE BENNER',
#   'type': 'Article',
#   'title': 'Mueller Delivers Report on Trump-Russia Investigation to Attorney General',
#   'abstract': 'Now the attorney general must decide how much of the report — one of the most highly anticipated documents in Washington in a generation — to make public.',
#   'published_date': '2019-03-22',
#   'source': 'The New York Times',
#   'id': 100000006422774,
#   'asset_id': 100000006422774,
#   'views': 20,
#   'des_facet': ['UNITED STATES POLITICS AND GOVERNMENT',
#    'RUSSIAN INTERFERENCE IN 2016 US ELECTIONS AND TIES TO TRUMP ASSOCIATES',
#    'PRESIDENTIAL ELECTION OF 2016'],
#   'org_facet': ['SPECIAL PROSECUTORS (INDEPENDENT COUNSEL)',
#    'JUSTICE DEPARTMENT'],
#   'per_facet': ['MUELLER, ROBERT S III', 'TRUMP, DONALD J', 'BARR, WILLIAM P'],
#   'geo_facet': '',
#   'media': [{'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Justice Department is preparing to receive a report from the special counsel, Robert S. Mueller III, and will decide how much of it to make public.',
#     'copyright': 'Doug Mills/The New York Times',
#     'approved_for_syndication': 1,
#     'media-metadata': [{'url': 'https://static01.nyt.com/images/2019/03/25/us/politics/25a2_railphoto/22dc-mueller-thumbStandard.jpg',
#       'format': 'Standard Thumbnail',
#       'height': 75,
#       'width': 75},
#      {'url': 'https://static01.nyt.com/images/2019/03/25/us/politics/25a2_railphoto/22dc-mueller-1-print-mediumThreeByTwo210-v3.jpg',
#       'format': 'mediumThreeByTwo210',
#       'height': 140,
#       'width': 210},
#      {'url': 'https://static01.nyt.com/images/2019/03/25/us/politics/25a2_railphoto/22dc-mueller-1-print-mediumThreeByTwo440-v3.jpg',
#       'format': 'mediumThreeByTwo440',
#       'height': 293,
#       'width': 440}]}],
#   'uri': 'nyt://article/05d46ff2-3cf7-54e4-bb53-630487c90781'}]

# %%
#translates json data into a Pandas dataframe
most_viewedlist = pd.DataFrame(most_pop_res, columns=['url','column','section','byline', 'type', 'title', 'abstract',
                                                      'published_date','source', 'id', 'asset_id', 'views'])
most_viewedlist
# Out:
#                                                   url column         section  \
# 0   https://www.nytimes.com/2019/03/28/health/woma...   None          Health
# 1   https://www.nytimes.com/2019/03/12/us/felicity...   None            U.S.
# 2   https://www.nytimes.com/2019/03/12/us/college-...   None            U.S.
# 3   https://www.nytimes.com/interactive/2019/arts/...                   Arts
# 4   https://www.nytimes.com/2019/03/16/style/snowp...   None           Style
# 5   https://www.nytimes.com/2019/03/25/smarter-liv...   None  Smarter Living
# 6   https://www.nytimes.com/2019/04/03/us/politics...   None            U.S.
# 7   https://www.nytimes.com/2019/03/21/business/bo...   None        Business
# 8   https://www.nytimes.com/2019/03/14/world/boein...   None           World
# 9   https://www.nytimes.com/2019/03/15/world/asia/...   None           World
# 10  https://www.nytimes.com/2019/03/24/us/politics...   None            U.S.
# 11  https://www.nytimes.com/interactive/2019/03/11...                  World
# 12  https://www.nytimes.com/interactive/2019/arts/...                   Arts
# 13  https://www.nytimes.com/interactive/2019/04/03...               Magazine
# 14  https://www.nytimes.com/2019/03/18/business/tr...   None        Business
# 15  https://www.nytimes.com/interactive/2019/03/07...               Magazine
# 16  https://www.nytimes.com/2019/03/10/world/ameri...   None           World
# 17  https://www.nytimes.com/2019/03/07/opinion/ilh...   None         Opinion
# 18  https://www.nytimes.com/interactive/2019/03/24...                   U.S.
# 19  https://www.nytimes.com/2019/03/22/us/politics...   None            U.S.
#
#                                                byline         type  \
# 0                                   By HEATHER MURPHY      Article
# 1                                  By REBECCA HALLECK      Article
# 2    By JENNIFER MEDINA, KATIE BENNER and KATE TAYLOR      Article
# 3                                     By JASON BAILEY  Interactive
# 4      By CLAIRE CAIN MILLER and JONAH ENGEL BROMWICH      Article
# 5                              By CHARLOTTE LIEBERMAN      Article
# 6   By NICHOLAS FANDOS, MICHAEL S. SCHMIDT and MAR...      Article
# 7                  By HIROKO TABUCHI and DAVID GELLES      Article
# 8                 By SELAM GEBREKIDAN and JAMES GLANZ      Article
# 9                               By THE NEW YORK TIMES      Article
# 10                  By MARK MAZZETTI and KATIE BENNER      Article
# 11  By DENISE LU, ALLISON McCANN, JIN WU and K.K. ...  Interactive
# 12                              By THE NEW YORK TIMES  Interactive
# 13               By JONATHAN MAHLER and JIM RUTENBERG  Interactive
# 14                                    By DAVID ENRICH      Article
# 15                     By THE NEW YORK TIMES MAGAZINE  Interactive
# 16  By NICHOLAS CASEY, CHRISTOPH KOETTL and DEBORA...      Article
# 17                                   By BRET STEPHENS      Article
# 18                              By THE NEW YORK TIMES  Interactive
# 19              By SHARON LaFRANIERE and KATIE BENNER      Article
#
#                                                 title  \
# 0   At 71, She’s Never Felt Pain or Anxiety. Now S...
# 1   Who’s Been Charged in the College Admissions C...
# 2   Actresses, Business Leaders and Other Wealthy ...
# 3             The 50 Best Movies on Netflix Right Now
# 4   How Parents Are Robbing Their Children of Adul...
# 5   Why You Procrastinate (It Has Nothing to Do Wi...
# 6   Some on Mueller’s Team Say Report Was More Dam...
# 7   Doomed Boeing Jets Lacked 2 Safety Features Th...
# 8   Boeing 737 Max Hit Trouble Right Away, Pilot’s...
# 9   Jacinda Ardern Consoles Families After New Zea...
# 10  Mueller Finds No Trump-Russia Conspiracy, but ...
# 11  From 8,600 Flights to Zero: Grounding the Boei...
# 12         The 20 Best TV Dramas Since ‘The Sopranos’
# 13  How Rupert Murdoch’s Empire of Influence Remad...
# 14  A Mar-a-Lago Weekend and an Act of God: Trump’...
# 15             The Top 25 Songs That Matter Right Now
# 16  Footage Contradicts U.S. Claim That Nicolás Ma...
# 17         Ilhan Omar Knows Exactly What She Is Doing
# 18  Read Attorney General William Barr’s Summary o...
# 19  Mueller Delivers Report on Trump-Russia Invest...
#
#                                              abstract published_date  \
# 0   Scientists discovered a previously unidentifie...     2019-03-28
# 1   The actresses Felicity Huffman and Lori Loughl...     2019-03-12
# 2   A sprawling federal investigation accuses 50 p...     2019-03-12
# 3   We’ve plucked out the 50 best films currently ...     2019-03-06
# 4   Today’s “snowplow parents” keep their children...     2019-03-16
# 5   If procrastination isn’t about laziness, then ...     2019-03-25
# 6   Members of the special counsel’s team have tol...     2019-04-03
# 7   Airlines had to pay more for two optional upgr...     2019-03-21
# 8   “Break break, request back to home,” the capta...     2019-03-14
# 9   The attack on two mosques, which appeared to h...     2019-03-15
# 10  The attorney general released the main finding...     2019-03-24
# 11  China was the first major country to ground th...     2019-03-11
# 12  It’s been 20 years since those ducks landed in...     2019-01-10
# 13  Murdoch and his children have toppled governme...     2019-04-03
# 14  Deutsche Bank’s hunger for profits and risk le...     2019-03-18
# 15  Listen to music — from the blockbuster hits, c...     2019-03-07
# 16  A reconstruction of the moment when a truck be...     2019-03-10
# 17  The Minnesota Democrat is bringing Corbynism t...     2019-03-07
# 18  The letter, by Attorney General William P. Bar...     2019-03-24
# 19  Now the attorney general must decide how much ...     2019-03-22
#
#                 source               id         asset_id  views
# 0   The New York Times  100000006432324  100000006432324      1
# 1   The New York Times  100000006406229  100000006406229      2
# 2   The New York Times  100000006406075  100000006406075      3
# 3   The New York Times  100000006330108  100000006330108      4
# 4   The New York Times  100000006411881  100000006411881      5
# 5   The New York Times  100000006416140  100000006416140      6
# 6   The New York Times  100000006441465  100000006441465      7
# 7   The New York Times  100000006421007  100000006421007      8
# 8   The New York Times  100000006410242  100000006410242      9
# 9   The New York Times  100000006412038  100000006412038     10
# 10  The New York Times  100000006425832  100000006425832     11
# 11  The New York Times  100000006404643  100000006404643     12
# 12  The New York Times  100000006297737  100000006297737     13
# 13  The New York Times  100000006439740  100000006439740     14
# 14  The New York Times  100000006408304  100000006408304     15
# 15  The New York Times  100000006397390  100000006397390     16
# 16  The New York Times  100000006400090  100000006400090     17
# 17  The New York Times  100000006397212  100000006397212     18
# 18  The New York Times  100000006374989  100000006374989     19
# 19  The New York Times  100000006422774  100000006422774     20

# %% [markdown]
# #### Dataset 4: ####
# This dataset came from the NYT and lists out the links and metadata of all Times' articles once they are published on the New York Times website (NYTimes.com).

# %%
#use requests library and call get method to access URL and open the API
nyt = requests.get('https://api.nytimes.com/svc/news/v3/content/all/all.json?api-key=GsQu4h8IDfExzCiiJWehGDgRPEQ9Ajka')
print(nyt.text)
# Out:
# {"status":"OK","copyright":"Copyright (c) 2019 The New York Times Company.  All Rights Reserved.","num_results":39898,"results":[{"slug_name":"07Parker","section":"Fashion","subsection":"Weddings","title":"Arielle Parker, Seth Kisch","abstract":"The couple met in 2015 on the dating app Hinge.","url":"https:\/\/www.nytimes.com\/2019\/04\/07\/fashion\/weddings\/arielle-parker-seth-kisch.html","byline":"","thumbnail_standard":"https:\/\/static01.nyt.com\/images\/2019\/04\/07\/fashion\/weddings\/07PARKER\/07PARKER-thumbStandard.jpg","item_type":"Article","source":"The New York Times","updated_date":"2019-04-07T00:01:31-04:00","created_date":"2019-04-07T00:01:31-04:00","published_date":"2019-04-06T20:00:00-04:00","first_published_date":"2019-04-07T00:00:00-04:00","material_type_facet":"News","kicker":null,"subheadline":null,"des_facet":["Weddings and Engagements"],"org_facet":"","per_facet":"","geo_facet":"","related_urls":null,"multimedia":[{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/07\/fashion\/weddings\/07PARKER\/07PARKER-thumbStandard.jpg","format":"Standard Thumbnail","height":75,"width":75,"type":"image","subtype":"photo","caption":"","copyright":""},{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/07\/fashion\/weddings\/07PARKER\/07PARKER-articleInline.jpg","format":"Normal","height":112,"width":190,"type":"image","subtype":"photo","caption":"","copyright":""},{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/07\/fashion\/weddings\/07PARKER\/07PARKER-mediumThreeByTwo210.jpg","format":"mediumThreeByTwo210","height":140,"width":210,"type":"image","subtype":"photo","caption":"","copyright":""},{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/07\/fashion\/weddings\/07PARKER\/07PARKER-mediumThreeByTwo440.jpg","format":"mediumThreeByTwo440","height":293,"width":440,"type":"image","subtype":"photo","caption":"","copyright":""}]},{"slug_name":"07BRAS","section":"Fashion","subsection":"Weddings","title":"Roxanne Bras, Stephen Petraeus","abstract":"The couple met as sophomores in college, in 2006, when they were both Army cadets at M.I.T\u2019s Reserve Officer Training Corps unit.","url":"https:\/\/www.nytimes.com\/2019\/04\/07\/fashion\/weddings\/roxanne-bras-stephen-petraeus.html","byline":"","thumbnail_standard":"https:\/\/static01.nyt.com\/images\/2019\/04\/07\/fashion\/weddings\/07BRAS\/07BRAS-thumbStandard.jpg","item_type":"Article","source":"The New York Times","updated_date":"2019-04-07T00:01:31-04:00","created_date":"2019-04-07T00:01:31-04:00","published_date":"2019-04-06T20:00:00-04:00","first_published_date":"2019-04-07T00:00:00-04:00","material_type_facet":"News","kicker":null,"subheadline":null,"des_facet":["Weddings and Engagements"],"org_facet":"","per_facet":["Petraeus, David H"],"geo_facet":"","related_urls":null,"multimedia":[{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/07\/fashion\/weddings\/07BRAS\/07BRAS-thumbStandard.jpg","format":"Standard Thumbnail","height":75,"width":75,"type":"image","subtype":"photo","caption":"","copyright":"Katherine Shu"},{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/07\/fashion\/weddings\/07BRAS\/07BRAS-articleInline.jpg","format":"Normal","height":112,"width":190,"type":"image","subtype":"photo","caption":"","copyright":"Katherine Shu"},{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/07\/fashion\/weddings\/07BRAS\/07BRAS-mediumThreeByTwo210.jpg","format":"mediumThreeByTwo210","height":140,"width":210,"type":"image","subtype":"photo","caption":"","copyright":"Katherine Shu"},{"url":"https:\/\/static01.nyt.com\/images\/2019\/04\/07\/fashion\/weddings\/07BRAS\/07BRAS-mediumThreeByTwo440.jpg","format":"mediumThreeByTwo440","height":293,"width":440,"type":"image","subtype":"photo","caption":"","copyright":"Katherine Shu"}]},{"slug_name":"07HATCH","section":"Fashion","subsection":"Weddings","title":"Erin Hatch, Benjamin Thomas","abstract":"The bride is the press secretary for the House Committee on Ways and Means; the groom is legislative direc ...

# %%
#translates data into a readable json file
nyt_data = nyt.json()
nyt_data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company.  All Rights Reserved.',
#  'num_results': 39898,
#  'results': [{'slug_name': '07Parker',
#    'section': 'Fashion',
#    'subsection': 'Weddings',
#    'title': 'Arielle Parker, Seth Kisch',
#    'abstract': 'The couple met in 2015 on the dating app Hinge.',
#    'url': 'https://www.nytimes.com/2019/04/07/fashion/weddings/arielle-parker-seth-kisch.html',
#    'byline': '',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07PARKER/07PARKER-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-07T00:01:31-04:00',
#    'created_date': '2019-04-07T00:01:31-04:00',
#    'published_date': '2019-04-06T20:00:00-04:00',
#    'first_published_date': '2019-04-07T00:00:00-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Weddings and Engagements'],
#    'org_facet': '',
#    'per_facet': '',
#    'geo_facet': '',
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07PARKER/07PARKER-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': ''},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07PARKER/07PARKER-articleInline.jpg',
#      'format': 'Normal',
#      'height': 112,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': ''},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07PARKER/07PARKER-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': ''},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07PARKER/07PARKER-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': ''}]},
#   {'slug_name': '07BRAS',
#    'section': 'Fashion',
#    'subsection': 'Weddings',
#    'title': 'Roxanne Bras, Stephen Petraeus',
#    'abstract': 'The couple met as sophomores in college, in 2006, when they were both Army cadets at M.I.T’s Reserve Officer Training Corps unit.',
#    'url': 'https://www.nytimes.com/2019/04/07/fashion/weddings/roxanne-bras-stephen-petraeus.html',
#    'byline': '',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07BRAS/07BRAS-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-07T00:01:31-04:00',
#    'created_date': '2019-04-07T00:01:31-04:00',
#    'published_date': '2019-04-06T20:00:00-04:00',
#    'first_published_date': '2019-04-07T00:00:00-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Weddings and Engagements'],
#    'org_facet': '',
#    'per_facet': ['Petraeus, David H'],
#    'geo_facet': '',
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07BRAS/07BRAS-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Katherine Shu'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07BRAS/07BRAS-articleInline.jpg',
#      'format': 'Normal',
#      'height': 112,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Katherine Shu'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07BRAS/07BRAS-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Katherine Shu'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07BRAS/07BRAS-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Katherine Shu'}]},
#   {'slug_name': '07HATCH',
#    'section': 'Fashion',
#    'subsection': 'Weddings',
#    'title': 'Erin Hatch, Benjamin Thomas',
#    'abstract': 'The bride is the press secretary for the House Committee on Ways and Means; the groom is legislative director for Representative Joaquin Castros.',
#    'url': 'https://www.nytimes.com/2019/04/07/fashion/weddings/erin-hatch-benjamin-thomas.html',
#    'byline': '',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07HATCH/07HATCH-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-07T00:01:31-04:00',
#    'created_date': '2019-04-07T00:01:31-04:00',
#    'published_date': '2019-04-06T20:00:00-04:00',
#    'first_published_date': '2019-04-07T00:00:00-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Weddings and Engagements'],
#    'org_facet': '',
#    'per_facet': '',
#    'geo_facet': '',
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07HATCH/07HATCH-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': ''},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07HATCH/07HATCH-articleInline.jpg',
#      'format': 'Normal',
#      'height': 112,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': ''},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07HATCH/07HATCH-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': ''},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07HATCH/07HATCH-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': ''}]},
#   {'slug_name': '07MARRA',
#    'section': 'Fashion',
#    'subsection': 'Weddings',
#    'title': 'Caroline Marra, Benjamin Hemani',
#    'abstract': 'The couple met in 2011 during the first day of orientation for their master’s program at the Thayer School of Engineering at Dartmouth.',
#    'url': 'https://www.nytimes.com/2019/04/07/fashion/weddings/caroline-marra-benjamin-hemani.html',
#    'byline': '',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07MARRA/07MARRA-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-07T00:01:31-04:00',
#    'created_date': '2019-04-07T00:01:31-04:00',
#    'published_date': '2019-04-06T20:00:00-04:00',
#    'first_published_date': '2019-04-07T00:00:00-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Weddings and Engagements'],
#    'org_facet': '',
#    'per_facet': '',
#    'geo_facet': '',
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07MARRA/07MARRA-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': ''},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07MARRA/07MARRA-articleInline.jpg',
#      'format': 'Normal',
#      'height': 112,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': ''},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07MARRA/07MARRA-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': ''},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07MARRA/07MARRA-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': ''}]},
#   {'slug_name': '07Toback',
#    'section': 'Fashion',
#    'subsection': 'Weddings',
#    'title': 'Jessie Toback, Noah Rothman',
#    'abstract': 'The couple were introduced by the bride’s father and met at Franklin & Marshall College, from which they graduated.',
#    'url': 'https://www.nytimes.com/2019/04/07/fashion/weddings/jessie-toback-noah-rothman.html',
#    'byline': '',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07TOBACK/07TOBACK-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-07T00:01:31-04:00',
#    'created_date': '2019-04-07T00:01:31-04:00',
#    'published_date': '2019-04-06T20:00:00-04:00',
#    'first_published_date': '2019-04-07T00:00:00-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Weddings and Engagements'],
#    'org_facet': '',
#    'per_facet': '',
#    'geo_facet': '',
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07TOBACK/07TOBACK-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Katy Sherman'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07TOBACK/07TOBACK-articleInline.jpg',
#      'format': 'Normal',
#      'height': 112,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Katy Sherman'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07TOBACK/07TOBACK-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Katy Sherman'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07TOBACK/07TOBACK-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Katy Sherman'}]},
#   {'slug_name': '06nhl',
#    'section': 'Sports',
#    'subsection': '',
#    'title': 'Islanders Blank Capitals and Head to Playoffs With Home Edge',
#    'abstract': 'Valtteri Filppula scored twice in his return from injury for the Islanders, who will face Pittsburgh. Carolina clinched the top East wild card, and the Devils closed with a win.',
#    'url': 'https://www.nytimes.com/2019/04/06/sports/nhl-islanders-capitals-devils-hurricanes.html',
#    'byline': 'By THE ASSOCIATED PRESS',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/07/sports/07NHL-print/merlin_153166125_c203778e-f5a4-4c6c-b96f-ccb7c5400597-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-07T00:07:52-04:00',
#    'created_date': '2019-04-06T23:11:18-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T23:09:47-04:00',
#    'material_type_facet': 'News',
#    'kicker': 'N.H.L. Roundup',
#    'subheadline': None,
#    'des_facet': ['Hockey, Ice'],
#    'org_facet': ['Carolina Hurricanes',
#     'Columbus Blue Jackets',
#     'New Jersey Devils',
#     'New York Islanders',
#     'Washington Capitals'],
#    'per_facet': '',
#    'geo_facet': '',
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/sports/07NHL-print/merlin_153166125_c203778e-f5a4-4c6c-b96f-ccb7c5400597-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The Islanders&rsquo; Valtteri Flippula beating Pheonix Copley for one of his two goals against the Capitals on Saturday.',
#      'copyright': 'Geoff Burke/USA Today Sports, via Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/sports/07NHL-print/merlin_153166125_c203778e-f5a4-4c6c-b96f-ccb7c5400597-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The Islanders&rsquo; Valtteri Flippula beating Pheonix Copley for one of his two goals against the Capitals on Saturday.',
#      'copyright': 'Geoff Burke/USA Today Sports, via Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/sports/07NHL-print/merlin_153166125_c203778e-f5a4-4c6c-b96f-ccb7c5400597-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The Islanders&rsquo; Valtteri Flippula beating Pheonix Copley for one of his two goals against the Capitals on Saturday.',
#      'copyright': 'Geoff Burke/USA Today Sports, via Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/04/07/sports/07NHL-print/merlin_153166125_c203778e-f5a4-4c6c-b96f-ccb7c5400597-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The Islanders&rsquo; Valtteri Flippula beating Pheonix Copley for one of his two goals against the Capitals on Saturday.',
#      'copyright': 'Geoff Burke/USA Today Sports, via Reuters'}]},
#   {'slug_name': '06ncaa-game2',
#    'section': 'Sports',
#    'subsection': '',
#    'title': 'N.C.A.A. Final Four: Texas Tech Upsets Michigan State',
#    'abstract': 'Texas Tech’s visit to its first Final Four will continue after a victory over Michigan State sent it to the final against Virginia.',
#    'url': 'https://www.nytimes.com/2019/04/06/sports/ncaa-final-four-michigan-state-texas-tech.html',
#    'byline': 'By BILLY WITZ',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game2TT/merlin_153167151_dab58883-41d5-4f30-b7e0-a602b4988798-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-07T00:06:13-04:00',
#    'created_date': '2019-04-06T23:09:52-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T23:08:21-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['NCAA Basketball Championships (Men)',
#     'Basketball (College)'],
#    'org_facet': ['Texas Tech University', 'Michigan State University'],
#    'per_facet': ['Izzo, Tom'],
#    'geo_facet': '',
#    'related_urls': [{'suggested_link_text': 'N.C.A.A. Final Four: A Shot, a Whistle and a First Final for Virginia',
#      'url': 'https://www.nytimes.com/2019/04/06/sports/ncaa-final-four-virginia-auburn.html'},
#     {'suggested_link_text': 'Putting the Michigan in Michigan State',
#      'url': 'https://www.nytimes.com/2019/04/06/sports/michigan-state-final-four.html'},
#     {'suggested_link_text': 'N.C.A.A. Clock May Be Running Out on Graduate Transfers',
#      'url': 'https://www.nytimes.com/2019/04/04/sports/ncaa-final-four-graduate-transfers.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game2TT/merlin_153167151_dab58883-41d5-4f30-b7e0-a602b4988798-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Texas Tech’s Tariq Owens, left, dunking over Michigan State’s Nick Ward.',
#      'copyright': 'Matt York/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game2TT/merlin_153167151_dab58883-41d5-4f30-b7e0-a602b4988798-articleInline.jpg',
#      'format': 'Normal',
#      'height': 149,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Texas Tech’s Tariq Owens, left, dunking over Michigan State’s Nick Ward.',
#      'copyright': 'Matt York/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game2TT/merlin_153167151_dab58883-41d5-4f30-b7e0-a602b4988798-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Texas Tech’s Tariq Owens, left, dunking over Michigan State’s Nick Ward.',
#      'copyright': 'Matt York/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game2TT/merlin_153167151_dab58883-41d5-4f30-b7e0-a602b4988798-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Texas Tech’s Tariq Owens, left, dunking over Michigan State’s Nick Ward.',
#      'copyright': 'Matt York/Associated Press'}]},
#   {'slug_name': '07corrections',
#    'section': 'Corrections',
#    'subsection': '',
#    'title': 'Corrections: April 7, 2019',
#    'abstract': 'Corrections appearing in print on Sunday, April 7, 2019.',
#    'url': 'https://www.nytimes.com/2019/04/06/pageoneplus/corrections-april-7-2019.html',
#    'byline': '',
#    'thumbnail_standard': '',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-06T23:44:00-04:00',
#    'created_date': '2019-04-06T22:53:06-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T22:51:35-04:00',
#    'material_type_facet': 'Correction',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': '',
#    'org_facet': '',
#    'per_facet': '',
#    'geo_facet': '',
#    'related_urls': None,
#    'multimedia': ''},
#   {'slug_name': '06santaanita',
#    'section': 'Sports',
#    'subsection': '',
#    'title': 'At Santa Anita, at Least for One Day, the Racing Goes Off Safely',
#    'abstract': 'Bob Baffert put two horses into the Kentucky Derby with a 1-2 finish in the Santa Anita Derby. But the California track and the sport will again face more tough questions in the coming week.',
#    'url': 'https://www.nytimes.com/2019/04/06/sports/santa-anita-derby.html',
#    'byline': 'By MIKE TIERNEY',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06santaanita1/06santaanita1-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-06T22:36:28-04:00',
#    'created_date': '2019-04-06T22:36:28-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T22:34:57-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Horse Racing', 'Santa Anita Derby'],
#    'org_facet': ['Deaths (Fatalities)'],
#    'per_facet': ['Baffert, Bob'],
#    'geo_facet': ['Santa Anita Park'],
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06santaanita1/06santaanita1-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Roadster, with Mike Smith aboard, edged Game Winner to capture the Santa Anita Derby on Saturday.',
#      'copyright': 'Benoit Photo, via Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06santaanita1/merlin_153164460_16903f79-aa77-4730-9c37-459523ddd612-articleInline.jpg',
#      'format': 'Normal',
#      'height': 136,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Roadster, with Mike Smith aboard, edged Game Winner to capture the Santa Anita Derby on Saturday.',
#      'copyright': 'Benoit Photo, via Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06santaanita1/merlin_153164460_16903f79-aa77-4730-9c37-459523ddd612-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Roadster, with Mike Smith aboard, edged Game Winner to capture the Santa Anita Derby on Saturday.',
#      'copyright': 'Benoit Photo, via Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06santaanita1/merlin_153164460_16903f79-aa77-4730-9c37-459523ddd612-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Roadster, with Mike Smith aboard, edged Game Winner to capture the Santa Anita Derby on Saturday.',
#      'copyright': 'Benoit Photo, via Associated Press'}]},
#   {'slug_name': '07quoteweb',
#    'section': 'Today’s Paper',
#    'subsection': '',
#    'title': 'Quotation of the Day: Fungus Immune to Drugs Quietly Sweeps the Globe',
#    'abstract': 'Quotation of the Day for Sunday, April 7, 2019.',
#    'url': 'https://www.nytimes.com/2019/04/06/todayspaper/quotation-of-the-day-fungus-immune-to-drugs-quietly-sweeps-the-globe.html',
#    'byline': '',
#    'thumbnail_standard': '',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-06T22:30:20-04:00',
#    'created_date': '2019-04-06T22:05:59-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T22:04:29-04:00',
#    'material_type_facet': 'Quote',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': '',
#    'org_facet': '',
#    'per_facet': '',
#    'geo_facet': '',
#    'related_urls': None,
#    'multimedia': ''},
#   {'slug_name': '06readers-fake-uber-drivers',
#    'section': 'Reader Center',
#    'subsection': '',
#    'title': '‘There Are Bad Actors Out There’: Readers Discuss Safety When Using a Ride-Share',
#    'abstract': 'Times readers share some close calls and offer advice for protecting yourself.',
#    'url': 'https://www.nytimes.com/2019/04/06/reader-center/uber-ride-share-safety-tips.html',
#    'byline': 'By LELA MOORE',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/05/reader-center/05readers-uber-lyft-stickers/merlin_147724509_529d55c8-5368-4539-8bfc-51e32d8a6df3-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-06T20:20:25-04:00',
#    'created_date': '2019-04-06T20:20:25-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T20:18:54-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Car Services and Livery Cabs'],
#    'org_facet': ['Women and Girls', 'Lyft Inc', 'Uber Technologies Inc'],
#    'per_facet': '',
#    'geo_facet': '',
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/reader-center/05readers-uber-lyft-stickers/merlin_147724509_529d55c8-5368-4539-8bfc-51e32d8a6df3-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Richard Vogel/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/reader-center/05readers-uber-lyft-stickers/merlin_147724509_529d55c8-5368-4539-8bfc-51e32d8a6df3-articleInline.jpg',
#      'format': 'Normal',
#      'height': 125,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Richard Vogel/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/reader-center/05readers-uber-lyft-stickers/merlin_147724509_529d55c8-5368-4539-8bfc-51e32d8a6df3-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Richard Vogel/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/05/reader-center/05readers-uber-lyft-stickers/merlin_147724509_529d55c8-5368-4539-8bfc-51e32d8a6df3-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Richard Vogel/Associated Press'}]},
#   {'slug_name': '06ncaa-game1',
#    'section': 'Sports',
#    'subsection': '',
#    'title': 'N.C.A.A. Final Four: A Shot, a Whistle and a First Final for Virginia',
#    'abstract': 'A late foul call, and the resulting three free throws by Kyle Guy in the final second, saved the Cavaliers against Auburn and sent them to the N.C.A.A. championship game.',
#    'url': 'https://www.nytimes.com/2019/04/06/sports/ncaa-final-four-virginia-auburn.html',
#    'byline': 'By MARC TRACY',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game1shot2/merlin_153164889_46cdeff8-a910-4038-b100-a1a367fd9641-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-06T23:44:21-04:00',
#    'created_date': '2019-04-06T20:16:31-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T20:15:01-04:00',
#    'material_type_facet': 'News',
#    'kicker': 'Virginia 63, Auburn 62 | Final Four',
#    'subheadline': None,
#    'des_facet': ['NCAA Basketball Championships (Men)',
#     'Basketball (College)'],
#    'org_facet': ['University of Virginia', 'Auburn University'],
#    'per_facet': '',
#    'geo_facet': '',
#    'related_urls': [{'suggested_link_text': 'How Virginia Has Coped With a One-of-a-Kind Loss',
#      'url': 'https://www.nytimes.com/2019/03/22/sports/virginia-cavaliers-upset.html'},
#     {'suggested_link_text': 'Virginia Fends Off Purdue and Naysayers to Reach the Final Four',
#      'url': 'https://www.nytimes.com/2019/03/31/sports/ncaa-tournament-virginia-purdue.html'},
#     {'suggested_link_text': 'N.C.A.A. Clock May Be Running Out on Graduate Transfers',
#      'url': 'https://www.nytimes.com/2019/04/04/sports/ncaa-final-four-graduate-transfers.html'},
#     {'suggested_link_text': 'The N.C.A.A. Team That Just Can’t Win',
#      'url': 'https://www.nytimes.com/2019/03/20/sports/ncaa-tournament-referees.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game1shot2/merlin_153164889_46cdeff8-a910-4038-b100-a1a367fd9641-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Auburn’s Samir Doughty was called for a foul when he slid under Virginia’s Kyle Guy in the final second.',
#      'copyright': 'Robert Deutsch/USA Today Sports, via Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game1shot2/merlin_153164889_46cdeff8-a910-4038-b100-a1a367fd9641-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Auburn’s Samir Doughty was called for a foul when he slid under Virginia’s Kyle Guy in the final second.',
#      'copyright': 'Robert Deutsch/USA Today Sports, via Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game1shot2/merlin_153164889_46cdeff8-a910-4038-b100-a1a367fd9641-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Auburn’s Samir Doughty was called for a foul when he slid under Virginia’s Kyle Guy in the final second.',
#      'copyright': 'Robert Deutsch/USA Today Sports, via Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game1shot2/merlin_153164889_46cdeff8-a910-4038-b100-a1a367fd9641-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Auburn’s Samir Doughty was called for a foul when he slid under Virginia’s Kyle Guy in the final second.',
#      'copyright': 'Robert Deutsch/USA Today Sports, via Reuters'}]},
#   {'slug_name': '06dc-trump',
#    'section': 'U.S.',
#    'subsection': 'Politics',
#    'title': 'Pushing for Tighter Borders, President Asks Jews for Support',
#    'abstract': 'A speech underlined how many conservative Jewish voters, alarmed by rising threats of anti-Semitism and energized by Mr. Trump’s pro-Israel policies, have embraced President Trump.',
#    'url': 'https://www.nytimes.com/2019/04/06/us/politics/trump-jews-border-asylum.html',
#    'byline': 'By EMILY COCHRANE',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06dc-trump1/06dc-trump1-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-06T23:33:22-04:00',
#    'created_date': '2019-04-06T20:15:57-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T20:14:27-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Anti-Semitism',
#     'Jews and Judaism',
#     'Immigration and Emigration',
#     'Illegal Immigration'],
#    'org_facet': ['Republican Party',
#     'Presidential Election of 2020',
#     'Asylum, Right of',
#     'Republican Jewish Coalition'],
#    'per_facet': ['Trump, Donald J', 'Omar, Ilhan'],
#    'geo_facet': ['Las Vegas (Nev)'],
#    'related_urls': [{'suggested_link_text': 'Eager to Court Jews (and Fracture Democrats), Republicans Push Bills on Anti-Semitism',
#      'url': 'https://www.nytimes.com/2019/03/24/us/politics/senate-republicans-anti-semitism.html'},
#     {'suggested_link_text': 'Trump, No Stranger to Jewish Stereotypes, Rejects Ilhan Omar’s Apology',
#      'url': 'https://www.nytimes.com/2019/02/12/us/politics/trump-omar-anti-semitism.html'},
#     {'suggested_link_text': 'How the Battle Over Israel and Anti-Semitism Is Fracturing American Politics',
#      'url': 'https://www.nytimes.com/2019/03/28/magazine/battle-over-bds-israel-palestinians-antisemitism.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06dc-trump1/06dc-trump1-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Trump, speaking before the Republican Jewish Coalition on Saturday, trumpeted his decisions to move the American Embassy to Jerusalem and to recognize Israel’s authority over the long-contested Golan Heights.',
#      'copyright': 'Al Drago for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06dc-trump1/06dc-trump1-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Trump, speaking before the Republican Jewish Coalition on Saturday, trumpeted his decisions to move the American Embassy to Jerusalem and to recognize Israel’s authority over the long-contested Golan Heights.',
#      'copyright': 'Al Drago for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06dc-trump1/06dc-trump1-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Trump, speaking before the Republican Jewish Coalition on Saturday, trumpeted his decisions to move the American Embassy to Jerusalem and to recognize Israel’s authority over the long-contested Golan Heights.',
#      'copyright': 'Al Drago for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06dc-trump1/06dc-trump1-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Trump, speaking before the Republican Jewish Coalition on Saturday, trumpeted his decisions to move the American Embassy to Jerusalem and to recognize Israel’s authority over the long-contested Golan Heights.',
#      'copyright': 'Al Drago for The New York Times'}]},
#   {'slug_name': '06nba',
#    'section': 'Sports',
#    'subsection': '',
#    'title': 'Nets Inch Up in East Playoff Race With Win Against Bucks',
#    'abstract': 'Eight players scored in double figures for the Nets, who moved into a tie for sixth with Orlando and a game and a half ahead of ninth-place Miami.',
#    'url': 'https://www.nytimes.com/2019/04/06/sports/nba-nets-bucks.html',
#    'byline': 'By THE ASSOCIATED PRESS',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06nba-web2/merlin_153163641_ae8c1c17-d241-4db4-b18e-034a52d919e0-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-06T22:29:33-04:00',
#    'created_date': '2019-04-06T20:03:25-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T20:01:55-04:00',
#    'material_type_facet': 'News',
#    'kicker': 'Nets 133, Bucks 128',
#    'subheadline': None,
#    'des_facet': ['Basketball'],
#    'org_facet': ['Brooklyn Nets', 'Milwaukee Bucks'],
#    'per_facet': '',
#    'geo_facet': '',
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06nba-web2/merlin_153163641_ae8c1c17-d241-4db4-b18e-034a52d919e0-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Joe Harris making the go-ahead 3-pointer for the Nets against the Bucks on Saturday.',
#      'copyright': 'Jeffrey Phelps/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06nba-web2/merlin_153163641_ae8c1c17-d241-4db4-b18e-034a52d919e0-articleInline.jpg',
#      'format': 'Normal',
#      'height': 362,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Joe Harris making the go-ahead 3-pointer for the Nets against the Bucks on Saturday.',
#      'copyright': 'Jeffrey Phelps/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06nba-web2/merlin_153163641_ae8c1c17-d241-4db4-b18e-034a52d919e0-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Joe Harris making the go-ahead 3-pointer for the Nets against the Bucks on Saturday.',
#      'copyright': 'Jeffrey Phelps/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06nba-web2/merlin_153163641_ae8c1c17-d241-4db4-b18e-034a52d919e0-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Joe Harris making the go-ahead 3-pointer for the Nets against the Bucks on Saturday.',
#      'copyright': 'Jeffrey Phelps/Associated Press'}]},
#   {'slug_name': '06booker',
#    'section': 'U.S.',
#    'subsection': 'Politics',
#    'title': 'Cory Booker Campaigns on Baby Bonds Program to Combat Inequality',
#    'abstract': 'Mr. Booker made a detailed case for an economic proposal known as baby bonds, which would create a government-run savings account for every child born in the United States.',
#    'url': 'https://www.nytimes.com/2019/04/06/us/politics/cory-booker-2020-baby-bonds.html',
#    'byline': 'By NICK CORASANITI',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/us/politics/06BOOKER/06BOOKER-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-06T23:15:04-04:00',
#    'created_date': '2019-04-06T19:50:48-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T19:49:17-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Income Inequality',
#     'Presidential Election of 2020',
#     'Primaries and Caucuses'],
#    'org_facet': '',
#    'per_facet': ['Booker, Cory A'],
#    'geo_facet': '',
#    'related_urls': [{'suggested_link_text': 'Biden Didn’t Rush Into 2020. The Race Came to Him Anyway.',
#      'url': 'https://www.nytimes.com/2019/04/06/us/politics/biden-2020.html'},
#     {'suggested_link_text': 'In New York, 2020 Democrats Offer a Range of Views on Racial Justice',
#      'url': 'https://www.nytimes.com/2019/04/05/us/politics/democrats-race-2020.html'},
#     {'suggested_link_text': 'Trump Presses His Argument of a Border Crisis in California Visit',
#      'url': 'https://www.nytimes.com/2019/04/05/us/politics/trump-border-wall.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/us/politics/06BOOKER/06BOOKER-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '“I’m really concerned about the wealth gap in America,” Mr. Booker said Saturday, as he addressed his proposal to curb growing inequality with “baby bonds,” a government-run savings program for children.',
#      'copyright': 'Elizabeth Frantz for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/us/politics/06BOOKER/06BOOKER-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '“I’m really concerned about the wealth gap in America,” Mr. Booker said Saturday, as he addressed his proposal to curb growing inequality with “baby bonds,” a government-run savings program for children.',
#      'copyright': 'Elizabeth Frantz for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/us/politics/06BOOKER/06BOOKER-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '“I’m really concerned about the wealth gap in America,” Mr. Booker said Saturday, as he addressed his proposal to curb growing inequality with “baby bonds,” a government-run savings program for children.',
#      'copyright': 'Elizabeth Frantz for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/us/politics/06BOOKER/06BOOKER-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '“I’m really concerned about the wealth gap in America,” Mr. Booker said Saturday, as he addressed his proposal to curb growing inequality with “baby bonds,” a government-run savings program for children.',
#      'copyright': 'Elizabeth Frantz for The New York Times'}]},
#   {'slug_name': '06xp-childseparation',
#    'section': 'U.S.',
#    'subsection': '',
#    'title': 'U.S. Says It Could Take 2 Years to Identify Up to Thousands of Separated Immigrant Families',
#    'abstract': 'A judge had asked the government to locate children who were separated from their families before the Trump administration’s “zero-tolerance” policy was made public.',
#    'url': 'https://www.nytimes.com/2019/04/06/us/family-separation-trump-administration.html',
#    'byline': 'By JULIA JACOBS',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/us/06xp-childseparation-promo/06xp-childseparation-promo-thumbStandard-v2.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-06T19:49:04-04:00',
#    'created_date': '2019-04-06T19:32:03-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T19:30:33-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Illegal Immigration',
#     'Immigration and Emigration',
#     'Immigration Detention'],
#    'org_facet': ['Customs and Border Protection (US)'],
#    'per_facet': '',
#    'geo_facet': '',
#    'related_urls': [{'suggested_link_text': 'Family Separation May Have Hit Thousands More Migrant Children Than Reported',
#      'url': 'https://www.nytimes.com/2019/01/17/us/family-separation-trump-administration-migrants.html'},
#     {'suggested_link_text': 'The Price Tag of Migrant Family Separation: $80 Million and Rising',
#      'url': 'https://www.nytimes.com/2018/11/20/us/family-separation-migrant-children.html'},
#     {'suggested_link_text': 'Homeland Security Chief Spars With Democrats Over Splitting Migrant Families',
#      'url': 'https://www.nytimes.com/2019/03/06/us/politics/kirstjen-nielsen-house-homeland-security-committee-testimony.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/us/06xp-childseparation-promo/06xp-childseparation-promo-thumbStandard-v2.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Migrants reunited with their children after four months apart waited for buses in July. A federal judge has said up to thousands more families may need to be located so they can be reunified.',
#      'copyright': 'Victor J. Blue for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/us/06xp-childseparation-promo/06xp-childseparation-promo-articleInline-v2.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Migrants reunited with their children after four months apart waited for buses in July. A federal judge has said up to thousands more families may need to be located so they can be reunified.',
#      'copyright': 'Victor J. Blue for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/us/06xp-childseparation-promo/06xp-childseparation-promo-mediumThreeByTwo210-v2.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Migrants reunited with their children after four months apart waited for buses in July. A federal judge has said up to thousands more families may need to be located so they can be reunified.',
#      'copyright': 'Victor J. Blue for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/us/06xp-childseparation-promo/06xp-childseparation-promo-mediumThreeByTwo440-v2.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Migrants reunited with their children after four months apart waited for buses in July. A federal judge has said up to thousands more families may need to be located so they can be reunified.',
#      'copyright': 'Victor J. Blue for The New York Times'}]},
#   {'slug_name': '06lpga',
#    'section': 'Sports',
#    'subsection': '',
#    'title': 'Big Week for Women’s Golf, but Perhaps Not for Progress',
#    'abstract': 'The Augusta National Women’s Amateur having a bigger stage and audience than the L.P.G.A.’s first major this week may not best serve the cause of equality.',
#    'url': 'https://www.nytimes.com/2019/04/06/sports/ana-inspiration-augusta-womens-amateur.html',
#    'byline': 'By KAREN CROUSE',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06lpga-1/06lpga-1-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-06T22:17:08-04:00',
#    'created_date': '2019-04-06T18:09:19-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T18:07:49-04:00',
#    'material_type_facet': 'News',
#    'kicker': 'On Golf',
#    'subheadline': None,
#    'des_facet': ['Golf'],
#    'org_facet': ['Augusta National Golf Club'],
#    'per_facet': ['McDonald, Ally (1992- )',
#     'Molinari, Francesco',
#     'Korda, Jessica'],
#    'geo_facet': '',
#    'related_urls': [{'suggested_link_text': 'ANA Inspiration: In-Kyung Kim Takes Lead 7 Years After a 1-Foot Miss',
#      'url': 'https://www.nytimes.com/2019/04/05/sports/lpga-ana-inspiration.html'},
#     {'suggested_link_text': 'Ally McDonald Takes First-Round Lead in ANA Inspiration',
#      'url': 'https://www.nytimes.com/2019/04/04/sports/lpga-ana-inspiration.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06lpga-1/06lpga-1-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'After Ally McDonald took the first-round lead at the ANA Inspiration on Thursday, two men posted recollections on social media about her “whipping up” on them in the boys’ Mississippi state championship when she was in high school.',
#      'copyright': 'Matt Sullivan/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06lpga-1/merlin_153113553_aa7f6bf1-d0d6-4f2b-887b-fa2241ad4762-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'After Ally McDonald took the first-round lead at the ANA Inspiration on Thursday, two men posted recollections on social media about her “whipping up” on them in the boys’ Mississippi state championship when she was in high school.',
#      'copyright': 'Matt Sullivan/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06lpga-1/06lpga-1-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'After Ally McDonald took the first-round lead at the ANA Inspiration on Thursday, two men posted recollections on social media about her “whipping up” on them in the boys’ Mississippi state championship when she was in high school.',
#      'copyright': 'Matt Sullivan/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06lpga-1/06lpga-1-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'After Ally McDonald took the first-round lead at the ANA Inspiration on Thursday, two men posted recollections on social media about her “whipping up” on them in the boys’ Mississippi state championship when she was in high school.',
#      'copyright': 'Matt Sullivan/Getty Images'}]},
#   {'slug_name': '07wordplay-help',
#    'section': 'Crosswords & Games',
#    'subsection': '',
#    'title': 'Help!',
#    'abstract': 'Peter A. Collins gets stranded on a desert island, but he’s resourceful.',
#    'url': 'https://www.nytimes.com/2019/04/06/crosswords/daily-puzzle-2019-04-07.html',
#    'byline': 'By CAITLIN LOVINGER',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/14/crosswords/14wordplay-lifeguards/14wordplay-lifeguards-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-06T18:01:06-04:00',
#    'created_date': '2019-04-06T17:41:32-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T17:40:01-04:00',
#    'material_type_facet': 'News',
#    'kicker': 'Wordplay',
#    'subheadline': None,
#    'des_facet': ['Crossword Puzzles'],
#    'org_facet': '',
#    'per_facet': '',
#    'geo_facet': '',
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/14/crosswords/14wordplay-lifeguards/14wordplay-lifeguards-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Members of the Ghana National Aquatic Rescue Unit warmed up before rescue and first aid training at Labadi Beach in Accra.',
#      'copyright': 'Cristina Aldehuela/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/14/crosswords/14wordplay-lifeguards/14wordplay-lifeguards-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Members of the Ghana National Aquatic Rescue Unit warmed up before rescue and first aid training at Labadi Beach in Accra.',
#      'copyright': 'Cristina Aldehuela/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/14/crosswords/14wordplay-lifeguards/14wordplay-lifeguards-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Members of the Ghana National Aquatic Rescue Unit warmed up before rescue and first aid training at Labadi Beach in Accra.',
#      'copyright': 'Cristina Aldehuela/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/14/crosswords/14wordplay-lifeguards/14wordplay-lifeguards-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Members of the Ghana National Aquatic Rescue Unit warmed up before rescue and first aid training at Labadi Beach in Accra.',
#      'copyright': 'Cristina Aldehuela/Agence France-Presse — Getty Images'}]},
#   {'slug_name': '06mets',
#    'section': 'Sports',
#    'subsection': '',
#    'title': 'Mets Rally in Eighth to Defeat the Nationals',
#    'abstract': 'The Mets hit five home runs, two by J.D. Davis, but the winning blow was Keon Broxton’s two-out single in the eighth inning, which broke a 5-5 tie.',
#    'url': 'https://www.nytimes.com/2019/04/06/sports/mets-nationals-keon-broxton-jd-davis.html',
#    'byline': 'By KEVIN ARMSTRONG',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06mets-web3/06mets-web3-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-06T18:44:18-04:00',
#    'created_date': '2019-04-06T17:23:22-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T17:21:52-04:00',
#    'material_type_facet': 'News',
#    'kicker': 'Mets 6, Nationals 5',
#    'subheadline': None,
#    'des_facet': ['Baseball'],
#    'org_facet': ['New York Mets', 'Washington Nationals'],
#    'per_facet': ['Broxton, Keon', 'Davis, J.D.'],
#    'geo_facet': '',
#    'related_urls': [{'suggested_link_text': 'The Science of Building a Better Pitcher',
#      'url': 'https://www.nytimes.com/2019/04/06/sports/mlb-pitching-coaches-wes-johnson.html'},
#     {'suggested_link_text': 'The Stat That Turns Mike Trout’s .312 Average Into .626',
#      'url': 'https://www.nytimes.com/2019/04/05/sports/baseball/secondary-average.html'},
#     {'suggested_link_text': 'Carlos Beltran Embraces a Role He Trained His Whole Career For',
#      'url': 'https://www.nytimes.com/2019/04/05/sports/carlos-beltran-yankees.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06mets-web3/06mets-web3-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'J.D. Davis, right, being greeted by Michael Conforto after hitting one of his two home runs for the Mets against the Nationals on Saturday.',
#      'copyright': 'Andy Marlin/USA Today Sports, via Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06mets-web3/merlin_153153162_61c56869-4b60-486d-9f48-4bab092ece0d-articleInline.jpg',
#      'format': 'Normal',
#      'height': 272,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'J.D. Davis, right, being greeted by Michael Conforto after hitting one of his two home runs for the Mets against the Nationals on Saturday.',
#      'copyright': 'Andy Marlin/USA Today Sports, via Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06mets-web3/06mets-web3-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'J.D. Davis, right, being greeted by Michael Conforto after hitting one of his two home runs for the Mets against the Nationals on Saturday.',
#      'copyright': 'Andy Marlin/USA Today Sports, via Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06mets-web3/06mets-web3-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'J.D. Davis, right, being greeted by Michael Conforto after hitting one of his two home runs for the Mets against the Nationals on Saturday.',
#      'copyright': 'Andy Marlin/USA Today Sports, via Reuters'}]},
#   {'slug_name': '06xp-phonescam',
#    'section': 'Business',
#    'subsection': '',
#    'title': 'Scheme to Swap Fake iPhones Adds Up to $900,000 Loss for Apple, Prosecutors Say',
#    'abstract': 'Two college students in Oregon are accused of tricking Apple into replacing nearly 1,500 counterfeit iPhones with genuine ones that were later sold.',
#    'url': 'https://www.nytimes.com/2019/04/06/business/counterfeit-apple-iphone-scam.html',
#    'byline': 'By RICK ROJAS',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/business/06xp-phonescam1/06xp-phonescan1-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-06T20:36:39-04:00',
#    'created_date': '2019-04-06T17:19:19-04:00',
#    'published_date': '2019-04-05T20:00:00-04:00',
#    'first_published_date': '2019-04-06T17:17:48-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Counterfeit Merchandise', 'Guarantees and Warranties'],
#    'org_facet': ['iPhone', 'Apple Inc'],
#    'per_facet': ['Quan Jiang', 'Yangyang Zhou'],
#    'geo_facet': ['China'],
#    'related_urls': [{'suggested_link_text': 'He Tried to Bilk Google and Facebook Out of $100 Million With Fake Invoices',
#      'url': 'https://www.nytimes.com/2019/03/25/business/facebook-google-wire-fraud.html'},
#     {'suggested_link_text': 'Facebook’s Data Deals Are Under Criminal Investigation',
#      'url': 'https://www.nytimes.com/2019/03/13/technology/facebook-data-deals-investigation.html'},
#     {'suggested_link_text': 'Chinese and Iranian Hackers Renew Their Attacks on U.S. Companies',
#      'url': 'https://www.nytimes.com/2019/02/18/technology/hackers-chinese-iran-usa.html'},
#     {'suggested_link_text': 'That Virus Alert on Your Computer? Scammers in India May Be Behind It',
#      'url': 'https://www.nytimes.com/2018/11/28/technology/scams-india-call-center-raids.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/business/06xp-phonescam1/06xp-phonescan1-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The iPhone 7 at an Apple store in Beijing in 2016. Two college students are accused of costing Apple nearly $900,000 in losses with a counterfeiting scheme.',
#      'copyright': 'Thomas Peter/Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/business/06xp-phonescam1/06xp-phonescan1-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The iPhone 7 at an Apple store in Beijing in 2016. Two college students are accused of costing Apple nearly $900,000 in losses with a counterfeiting scheme.',
#      'copyright': 'Thomas Peter/Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/business/06xp-phonescam1/06xp-phonescan1-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The iPhone 7 at an Apple store in Beijing in 2016. Two college students are accused of costing Apple nearly $900,000 in losses with a counterfeiting scheme.',
#      'copyright': 'Thomas Peter/Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/04/06/business/06xp-phonescam1/06xp-phonescan1-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The iPhone 7 at an Apple store in Beijing in 2016. Two college students are accused of costing Apple nearly $900,000 in losses with a counterfeiting scheme.',
#      'copyright': 'Thomas Peter/Reuters'}]}]}

# %%
#extract actual data from the json file
nyt_res = nyt_data['results']
nyt_res
# Out:
# [{'slug_name': '07Parker',
#   'section': 'Fashion',
#   'subsection': 'Weddings',
#   'title': 'Arielle Parker, Seth Kisch',
#   'abstract': 'The couple met in 2015 on the dating app Hinge.',
#   'url': 'https://www.nytimes.com/2019/04/07/fashion/weddings/arielle-parker-seth-kisch.html',
#   'byline': '',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07PARKER/07PARKER-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-07T00:01:31-04:00',
#   'created_date': '2019-04-07T00:01:31-04:00',
#   'published_date': '2019-04-06T20:00:00-04:00',
#   'first_published_date': '2019-04-07T00:00:00-04:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['Weddings and Engagements'],
#   'org_facet': '',
#   'per_facet': '',
#   'geo_facet': '',
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07PARKER/07PARKER-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07PARKER/07PARKER-articleInline.jpg',
#     'format': 'Normal',
#     'height': 112,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07PARKER/07PARKER-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07PARKER/07PARKER-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''}]},
#  {'slug_name': '07BRAS',
#   'section': 'Fashion',
#   'subsection': 'Weddings',
#   'title': 'Roxanne Bras, Stephen Petraeus',
#   'abstract': 'The couple met as sophomores in college, in 2006, when they were both Army cadets at M.I.T’s Reserve Officer Training Corps unit.',
#   'url': 'https://www.nytimes.com/2019/04/07/fashion/weddings/roxanne-bras-stephen-petraeus.html',
#   'byline': '',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07BRAS/07BRAS-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-07T00:01:31-04:00',
#   'created_date': '2019-04-07T00:01:31-04:00',
#   'published_date': '2019-04-06T20:00:00-04:00',
#   'first_published_date': '2019-04-07T00:00:00-04:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['Weddings and Engagements'],
#   'org_facet': '',
#   'per_facet': ['Petraeus, David H'],
#   'geo_facet': '',
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07BRAS/07BRAS-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Katherine Shu'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07BRAS/07BRAS-articleInline.jpg',
#     'format': 'Normal',
#     'height': 112,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Katherine Shu'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07BRAS/07BRAS-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Katherine Shu'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07BRAS/07BRAS-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Katherine Shu'}]},
#  {'slug_name': '07HATCH',
#   'section': 'Fashion',
#   'subsection': 'Weddings',
#   'title': 'Erin Hatch, Benjamin Thomas',
#   'abstract': 'The bride is the press secretary for the House Committee on Ways and Means; the groom is legislative director for Representative Joaquin Castros.',
#   'url': 'https://www.nytimes.com/2019/04/07/fashion/weddings/erin-hatch-benjamin-thomas.html',
#   'byline': '',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07HATCH/07HATCH-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-07T00:01:31-04:00',
#   'created_date': '2019-04-07T00:01:31-04:00',
#   'published_date': '2019-04-06T20:00:00-04:00',
#   'first_published_date': '2019-04-07T00:00:00-04:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['Weddings and Engagements'],
#   'org_facet': '',
#   'per_facet': '',
#   'geo_facet': '',
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07HATCH/07HATCH-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07HATCH/07HATCH-articleInline.jpg',
#     'format': 'Normal',
#     'height': 112,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07HATCH/07HATCH-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07HATCH/07HATCH-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''}]},
#  {'slug_name': '07MARRA',
#   'section': 'Fashion',
#   'subsection': 'Weddings',
#   'title': 'Caroline Marra, Benjamin Hemani',
#   'abstract': 'The couple met in 2011 during the first day of orientation for their master’s program at the Thayer School of Engineering at Dartmouth.',
#   'url': 'https://www.nytimes.com/2019/04/07/fashion/weddings/caroline-marra-benjamin-hemani.html',
#   'byline': '',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07MARRA/07MARRA-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-07T00:01:31-04:00',
#   'created_date': '2019-04-07T00:01:31-04:00',
#   'published_date': '2019-04-06T20:00:00-04:00',
#   'first_published_date': '2019-04-07T00:00:00-04:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['Weddings and Engagements'],
#   'org_facet': '',
#   'per_facet': '',
#   'geo_facet': '',
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07MARRA/07MARRA-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07MARRA/07MARRA-articleInline.jpg',
#     'format': 'Normal',
#     'height': 112,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07MARRA/07MARRA-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07MARRA/07MARRA-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': ''}]},
#  {'slug_name': '07Toback',
#   'section': 'Fashion',
#   'subsection': 'Weddings',
#   'title': 'Jessie Toback, Noah Rothman',
#   'abstract': 'The couple were introduced by the bride’s father and met at Franklin & Marshall College, from which they graduated.',
#   'url': 'https://www.nytimes.com/2019/04/07/fashion/weddings/jessie-toback-noah-rothman.html',
#   'byline': '',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07TOBACK/07TOBACK-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-07T00:01:31-04:00',
#   'created_date': '2019-04-07T00:01:31-04:00',
#   'published_date': '2019-04-06T20:00:00-04:00',
#   'first_published_date': '2019-04-07T00:00:00-04:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['Weddings and Engagements'],
#   'org_facet': '',
#   'per_facet': '',
#   'geo_facet': '',
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07TOBACK/07TOBACK-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Katy Sherman'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07TOBACK/07TOBACK-articleInline.jpg',
#     'format': 'Normal',
#     'height': 112,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Katy Sherman'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07TOBACK/07TOBACK-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Katy Sherman'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/fashion/weddings/07TOBACK/07TOBACK-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Katy Sherman'}]},
#  {'slug_name': '06nhl',
#   'section': 'Sports',
#   'subsection': '',
#   'title': 'Islanders Blank Capitals and Head to Playoffs With Home Edge',
#   'abstract': 'Valtteri Filppula scored twice in his return from injury for the Islanders, who will face Pittsburgh. Carolina clinched the top East wild card, and the Devils closed with a win.',
#   'url': 'https://www.nytimes.com/2019/04/06/sports/nhl-islanders-capitals-devils-hurricanes.html',
#   'byline': 'By THE ASSOCIATED PRESS',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/07/sports/07NHL-print/merlin_153166125_c203778e-f5a4-4c6c-b96f-ccb7c5400597-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-07T00:07:52-04:00',
#   'created_date': '2019-04-06T23:11:18-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T23:09:47-04:00',
#   'material_type_facet': 'News',
#   'kicker': 'N.H.L. Roundup',
#   'subheadline': None,
#   'des_facet': ['Hockey, Ice'],
#   'org_facet': ['Carolina Hurricanes',
#    'Columbus Blue Jackets',
#    'New Jersey Devils',
#    'New York Islanders',
#    'Washington Capitals'],
#   'per_facet': '',
#   'geo_facet': '',
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/07/sports/07NHL-print/merlin_153166125_c203778e-f5a4-4c6c-b96f-ccb7c5400597-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Islanders&rsquo; Valtteri Flippula beating Pheonix Copley for one of his two goals against the Capitals on Saturday.',
#     'copyright': 'Geoff Burke/USA Today Sports, via Reuters'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/sports/07NHL-print/merlin_153166125_c203778e-f5a4-4c6c-b96f-ccb7c5400597-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Islanders&rsquo; Valtteri Flippula beating Pheonix Copley for one of his two goals against the Capitals on Saturday.',
#     'copyright': 'Geoff Burke/USA Today Sports, via Reuters'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/sports/07NHL-print/merlin_153166125_c203778e-f5a4-4c6c-b96f-ccb7c5400597-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Islanders&rsquo; Valtteri Flippula beating Pheonix Copley for one of his two goals against the Capitals on Saturday.',
#     'copyright': 'Geoff Burke/USA Today Sports, via Reuters'},
#    {'url': 'https://static01.nyt.com/images/2019/04/07/sports/07NHL-print/merlin_153166125_c203778e-f5a4-4c6c-b96f-ccb7c5400597-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The Islanders&rsquo; Valtteri Flippula beating Pheonix Copley for one of his two goals against the Capitals on Saturday.',
#     'copyright': 'Geoff Burke/USA Today Sports, via Reuters'}]},
#  {'slug_name': '06ncaa-game2',
#   'section': 'Sports',
#   'subsection': '',
#   'title': 'N.C.A.A. Final Four: Texas Tech Upsets Michigan State',
#   'abstract': 'Texas Tech’s visit to its first Final Four will continue after a victory over Michigan State sent it to the final against Virginia.',
#   'url': 'https://www.nytimes.com/2019/04/06/sports/ncaa-final-four-michigan-state-texas-tech.html',
#   'byline': 'By BILLY WITZ',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game2TT/merlin_153167151_dab58883-41d5-4f30-b7e0-a602b4988798-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-07T00:06:13-04:00',
#   'created_date': '2019-04-06T23:09:52-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T23:08:21-04:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['NCAA Basketball Championships (Men)', 'Basketball (College)'],
#   'org_facet': ['Texas Tech University', 'Michigan State University'],
#   'per_facet': ['Izzo, Tom'],
#   'geo_facet': '',
#   'related_urls': [{'suggested_link_text': 'N.C.A.A. Final Four: A Shot, a Whistle and a First Final for Virginia',
#     'url': 'https://www.nytimes.com/2019/04/06/sports/ncaa-final-four-virginia-auburn.html'},
#    {'suggested_link_text': 'Putting the Michigan in Michigan State',
#     'url': 'https://www.nytimes.com/2019/04/06/sports/michigan-state-final-four.html'},
#    {'suggested_link_text': 'N.C.A.A. Clock May Be Running Out on Graduate Transfers',
#     'url': 'https://www.nytimes.com/2019/04/04/sports/ncaa-final-four-graduate-transfers.html'}],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game2TT/merlin_153167151_dab58883-41d5-4f30-b7e0-a602b4988798-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Texas Tech’s Tariq Owens, left, dunking over Michigan State’s Nick Ward.',
#     'copyright': 'Matt York/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game2TT/merlin_153167151_dab58883-41d5-4f30-b7e0-a602b4988798-articleInline.jpg',
#     'format': 'Normal',
#     'height': 149,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Texas Tech’s Tariq Owens, left, dunking over Michigan State’s Nick Ward.',
#     'copyright': 'Matt York/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game2TT/merlin_153167151_dab58883-41d5-4f30-b7e0-a602b4988798-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Texas Tech’s Tariq Owens, left, dunking over Michigan State’s Nick Ward.',
#     'copyright': 'Matt York/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game2TT/merlin_153167151_dab58883-41d5-4f30-b7e0-a602b4988798-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Texas Tech’s Tariq Owens, left, dunking over Michigan State’s Nick Ward.',
#     'copyright': 'Matt York/Associated Press'}]},
#  {'slug_name': '07corrections',
#   'section': 'Corrections',
#   'subsection': '',
#   'title': 'Corrections: April 7, 2019',
#   'abstract': 'Corrections appearing in print on Sunday, April 7, 2019.',
#   'url': 'https://www.nytimes.com/2019/04/06/pageoneplus/corrections-april-7-2019.html',
#   'byline': '',
#   'thumbnail_standard': '',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-06T23:44:00-04:00',
#   'created_date': '2019-04-06T22:53:06-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T22:51:35-04:00',
#   'material_type_facet': 'Correction',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': '',
#   'org_facet': '',
#   'per_facet': '',
#   'geo_facet': '',
#   'related_urls': None,
#   'multimedia': ''},
#  {'slug_name': '06santaanita',
#   'section': 'Sports',
#   'subsection': '',
#   'title': 'At Santa Anita, at Least for One Day, the Racing Goes Off Safely',
#   'abstract': 'Bob Baffert put two horses into the Kentucky Derby with a 1-2 finish in the Santa Anita Derby. But the California track and the sport will again face more tough questions in the coming week.',
#   'url': 'https://www.nytimes.com/2019/04/06/sports/santa-anita-derby.html',
#   'byline': 'By MIKE TIERNEY',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06santaanita1/06santaanita1-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-06T22:36:28-04:00',
#   'created_date': '2019-04-06T22:36:28-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T22:34:57-04:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['Horse Racing', 'Santa Anita Derby'],
#   'org_facet': ['Deaths (Fatalities)'],
#   'per_facet': ['Baffert, Bob'],
#   'geo_facet': ['Santa Anita Park'],
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06santaanita1/06santaanita1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Roadster, with Mike Smith aboard, edged Game Winner to capture the Santa Anita Derby on Saturday.',
#     'copyright': 'Benoit Photo, via Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06santaanita1/merlin_153164460_16903f79-aa77-4730-9c37-459523ddd612-articleInline.jpg',
#     'format': 'Normal',
#     'height': 136,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Roadster, with Mike Smith aboard, edged Game Winner to capture the Santa Anita Derby on Saturday.',
#     'copyright': 'Benoit Photo, via Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06santaanita1/merlin_153164460_16903f79-aa77-4730-9c37-459523ddd612-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Roadster, with Mike Smith aboard, edged Game Winner to capture the Santa Anita Derby on Saturday.',
#     'copyright': 'Benoit Photo, via Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06santaanita1/merlin_153164460_16903f79-aa77-4730-9c37-459523ddd612-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Roadster, with Mike Smith aboard, edged Game Winner to capture the Santa Anita Derby on Saturday.',
#     'copyright': 'Benoit Photo, via Associated Press'}]},
#  {'slug_name': '07quoteweb',
#   'section': 'Today’s Paper',
#   'subsection': '',
#   'title': 'Quotation of the Day: Fungus Immune to Drugs Quietly Sweeps the Globe',
#   'abstract': 'Quotation of the Day for Sunday, April 7, 2019.',
#   'url': 'https://www.nytimes.com/2019/04/06/todayspaper/quotation-of-the-day-fungus-immune-to-drugs-quietly-sweeps-the-globe.html',
#   'byline': '',
#   'thumbnail_standard': '',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-06T22:30:20-04:00',
#   'created_date': '2019-04-06T22:05:59-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T22:04:29-04:00',
#   'material_type_facet': 'Quote',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': '',
#   'org_facet': '',
#   'per_facet': '',
#   'geo_facet': '',
#   'related_urls': None,
#   'multimedia': ''},
#  {'slug_name': '06readers-fake-uber-drivers',
#   'section': 'Reader Center',
#   'subsection': '',
#   'title': '‘There Are Bad Actors Out There’: Readers Discuss Safety When Using a Ride-Share',
#   'abstract': 'Times readers share some close calls and offer advice for protecting yourself.',
#   'url': 'https://www.nytimes.com/2019/04/06/reader-center/uber-ride-share-safety-tips.html',
#   'byline': 'By LELA MOORE',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/05/reader-center/05readers-uber-lyft-stickers/merlin_147724509_529d55c8-5368-4539-8bfc-51e32d8a6df3-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-06T20:20:25-04:00',
#   'created_date': '2019-04-06T20:20:25-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T20:18:54-04:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['Car Services and Livery Cabs'],
#   'org_facet': ['Women and Girls', 'Lyft Inc', 'Uber Technologies Inc'],
#   'per_facet': '',
#   'geo_facet': '',
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/05/reader-center/05readers-uber-lyft-stickers/merlin_147724509_529d55c8-5368-4539-8bfc-51e32d8a6df3-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Richard Vogel/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/reader-center/05readers-uber-lyft-stickers/merlin_147724509_529d55c8-5368-4539-8bfc-51e32d8a6df3-articleInline.jpg',
#     'format': 'Normal',
#     'height': 125,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Richard Vogel/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/reader-center/05readers-uber-lyft-stickers/merlin_147724509_529d55c8-5368-4539-8bfc-51e32d8a6df3-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Richard Vogel/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/05/reader-center/05readers-uber-lyft-stickers/merlin_147724509_529d55c8-5368-4539-8bfc-51e32d8a6df3-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Richard Vogel/Associated Press'}]},
#  {'slug_name': '06ncaa-game1',
#   'section': 'Sports',
#   'subsection': '',
#   'title': 'N.C.A.A. Final Four: A Shot, a Whistle and a First Final for Virginia',
#   'abstract': 'A late foul call, and the resulting three free throws by Kyle Guy in the final second, saved the Cavaliers against Auburn and sent them to the N.C.A.A. championship game.',
#   'url': 'https://www.nytimes.com/2019/04/06/sports/ncaa-final-four-virginia-auburn.html',
#   'byline': 'By MARC TRACY',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game1shot2/merlin_153164889_46cdeff8-a910-4038-b100-a1a367fd9641-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-06T23:44:21-04:00',
#   'created_date': '2019-04-06T20:16:31-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T20:15:01-04:00',
#   'material_type_facet': 'News',
#   'kicker': 'Virginia 63, Auburn 62 | Final Four',
#   'subheadline': None,
#   'des_facet': ['NCAA Basketball Championships (Men)', 'Basketball (College)'],
#   'org_facet': ['University of Virginia', 'Auburn University'],
#   'per_facet': '',
#   'geo_facet': '',
#   'related_urls': [{'suggested_link_text': 'How Virginia Has Coped With a One-of-a-Kind Loss',
#     'url': 'https://www.nytimes.com/2019/03/22/sports/virginia-cavaliers-upset.html'},
#    {'suggested_link_text': 'Virginia Fends Off Purdue and Naysayers to Reach the Final Four',
#     'url': 'https://www.nytimes.com/2019/03/31/sports/ncaa-tournament-virginia-purdue.html'},
#    {'suggested_link_text': 'N.C.A.A. Clock May Be Running Out on Graduate Transfers',
#     'url': 'https://www.nytimes.com/2019/04/04/sports/ncaa-final-four-graduate-transfers.html'},
#    {'suggested_link_text': 'The N.C.A.A. Team That Just Can’t Win',
#     'url': 'https://www.nytimes.com/2019/03/20/sports/ncaa-tournament-referees.html'}],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game1shot2/merlin_153164889_46cdeff8-a910-4038-b100-a1a367fd9641-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Auburn’s Samir Doughty was called for a foul when he slid under Virginia’s Kyle Guy in the final second.',
#     'copyright': 'Robert Deutsch/USA Today Sports, via Reuters'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game1shot2/merlin_153164889_46cdeff8-a910-4038-b100-a1a367fd9641-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Auburn’s Samir Doughty was called for a foul when he slid under Virginia’s Kyle Guy in the final second.',
#     'copyright': 'Robert Deutsch/USA Today Sports, via Reuters'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game1shot2/merlin_153164889_46cdeff8-a910-4038-b100-a1a367fd9641-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Auburn’s Samir Doughty was called for a foul when he slid under Virginia’s Kyle Guy in the final second.',
#     'copyright': 'Robert Deutsch/USA Today Sports, via Reuters'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06ncaa-game1shot2/merlin_153164889_46cdeff8-a910-4038-b100-a1a367fd9641-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Auburn’s Samir Doughty was called for a foul when he slid under Virginia’s Kyle Guy in the final second.',
#     'copyright': 'Robert Deutsch/USA Today Sports, via Reuters'}]},
#  {'slug_name': '06dc-trump',
#   'section': 'U.S.',
#   'subsection': 'Politics',
#   'title': 'Pushing for Tighter Borders, President Asks Jews for Support',
#   'abstract': 'A speech underlined how many conservative Jewish voters, alarmed by rising threats of anti-Semitism and energized by Mr. Trump’s pro-Israel policies, have embraced President Trump.',
#   'url': 'https://www.nytimes.com/2019/04/06/us/politics/trump-jews-border-asylum.html',
#   'byline': 'By EMILY COCHRANE',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06dc-trump1/06dc-trump1-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-06T23:33:22-04:00',
#   'created_date': '2019-04-06T20:15:57-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T20:14:27-04:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['Anti-Semitism',
#    'Jews and Judaism',
#    'Immigration and Emigration',
#    'Illegal Immigration'],
#   'org_facet': ['Republican Party',
#    'Presidential Election of 2020',
#    'Asylum, Right of',
#    'Republican Jewish Coalition'],
#   'per_facet': ['Trump, Donald J', 'Omar, Ilhan'],
#   'geo_facet': ['Las Vegas (Nev)'],
#   'related_urls': [{'suggested_link_text': 'Eager to Court Jews (and Fracture Democrats), Republicans Push Bills on Anti-Semitism',
#     'url': 'https://www.nytimes.com/2019/03/24/us/politics/senate-republicans-anti-semitism.html'},
#    {'suggested_link_text': 'Trump, No Stranger to Jewish Stereotypes, Rejects Ilhan Omar’s Apology',
#     'url': 'https://www.nytimes.com/2019/02/12/us/politics/trump-omar-anti-semitism.html'},
#    {'suggested_link_text': 'How the Battle Over Israel and Anti-Semitism Is Fracturing American Politics',
#     'url': 'https://www.nytimes.com/2019/03/28/magazine/battle-over-bds-israel-palestinians-antisemitism.html'}],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06dc-trump1/06dc-trump1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'President Trump, speaking before the Republican Jewish Coalition on Saturday, trumpeted his decisions to move the American Embassy to Jerusalem and to recognize Israel’s authority over the long-contested Golan Heights.',
#     'copyright': 'Al Drago for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06dc-trump1/06dc-trump1-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'President Trump, speaking before the Republican Jewish Coalition on Saturday, trumpeted his decisions to move the American Embassy to Jerusalem and to recognize Israel’s authority over the long-contested Golan Heights.',
#     'copyright': 'Al Drago for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06dc-trump1/06dc-trump1-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'President Trump, speaking before the Republican Jewish Coalition on Saturday, trumpeted his decisions to move the American Embassy to Jerusalem and to recognize Israel’s authority over the long-contested Golan Heights.',
#     'copyright': 'Al Drago for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06dc-trump1/06dc-trump1-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'President Trump, speaking before the Republican Jewish Coalition on Saturday, trumpeted his decisions to move the American Embassy to Jerusalem and to recognize Israel’s authority over the long-contested Golan Heights.',
#     'copyright': 'Al Drago for The New York Times'}]},
#  {'slug_name': '06nba',
#   'section': 'Sports',
#   'subsection': '',
#   'title': 'Nets Inch Up in East Playoff Race With Win Against Bucks',
#   'abstract': 'Eight players scored in double figures for the Nets, who moved into a tie for sixth with Orlando and a game and a half ahead of ninth-place Miami.',
#   'url': 'https://www.nytimes.com/2019/04/06/sports/nba-nets-bucks.html',
#   'byline': 'By THE ASSOCIATED PRESS',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06nba-web2/merlin_153163641_ae8c1c17-d241-4db4-b18e-034a52d919e0-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-06T22:29:33-04:00',
#   'created_date': '2019-04-06T20:03:25-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T20:01:55-04:00',
#   'material_type_facet': 'News',
#   'kicker': 'Nets 133, Bucks 128',
#   'subheadline': None,
#   'des_facet': ['Basketball'],
#   'org_facet': ['Brooklyn Nets', 'Milwaukee Bucks'],
#   'per_facet': '',
#   'geo_facet': '',
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06nba-web2/merlin_153163641_ae8c1c17-d241-4db4-b18e-034a52d919e0-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Joe Harris making the go-ahead 3-pointer for the Nets against the Bucks on Saturday.',
#     'copyright': 'Jeffrey Phelps/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06nba-web2/merlin_153163641_ae8c1c17-d241-4db4-b18e-034a52d919e0-articleInline.jpg',
#     'format': 'Normal',
#     'height': 362,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Joe Harris making the go-ahead 3-pointer for the Nets against the Bucks on Saturday.',
#     'copyright': 'Jeffrey Phelps/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06nba-web2/merlin_153163641_ae8c1c17-d241-4db4-b18e-034a52d919e0-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Joe Harris making the go-ahead 3-pointer for the Nets against the Bucks on Saturday.',
#     'copyright': 'Jeffrey Phelps/Associated Press'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06nba-web2/merlin_153163641_ae8c1c17-d241-4db4-b18e-034a52d919e0-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Joe Harris making the go-ahead 3-pointer for the Nets against the Bucks on Saturday.',
#     'copyright': 'Jeffrey Phelps/Associated Press'}]},
#  {'slug_name': '06booker',
#   'section': 'U.S.',
#   'subsection': 'Politics',
#   'title': 'Cory Booker Campaigns on Baby Bonds Program to Combat Inequality',
#   'abstract': 'Mr. Booker made a detailed case for an economic proposal known as baby bonds, which would create a government-run savings account for every child born in the United States.',
#   'url': 'https://www.nytimes.com/2019/04/06/us/politics/cory-booker-2020-baby-bonds.html',
#   'byline': 'By NICK CORASANITI',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/us/politics/06BOOKER/06BOOKER-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-06T23:15:04-04:00',
#   'created_date': '2019-04-06T19:50:48-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T19:49:17-04:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['Income Inequality',
#    'Presidential Election of 2020',
#    'Primaries and Caucuses'],
#   'org_facet': '',
#   'per_facet': ['Booker, Cory A'],
#   'geo_facet': '',
#   'related_urls': [{'suggested_link_text': 'Biden Didn’t Rush Into 2020. The Race Came to Him Anyway.',
#     'url': 'https://www.nytimes.com/2019/04/06/us/politics/biden-2020.html'},
#    {'suggested_link_text': 'In New York, 2020 Democrats Offer a Range of Views on Racial Justice',
#     'url': 'https://www.nytimes.com/2019/04/05/us/politics/democrats-race-2020.html'},
#    {'suggested_link_text': 'Trump Presses His Argument of a Border Crisis in California Visit',
#     'url': 'https://www.nytimes.com/2019/04/05/us/politics/trump-border-wall.html'}],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/us/politics/06BOOKER/06BOOKER-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '“I’m really concerned about the wealth gap in America,” Mr. Booker said Saturday, as he addressed his proposal to curb growing inequality with “baby bonds,” a government-run savings program for children.',
#     'copyright': 'Elizabeth Frantz for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/us/politics/06BOOKER/06BOOKER-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '“I’m really concerned about the wealth gap in America,” Mr. Booker said Saturday, as he addressed his proposal to curb growing inequality with “baby bonds,” a government-run savings program for children.',
#     'copyright': 'Elizabeth Frantz for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/us/politics/06BOOKER/06BOOKER-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '“I’m really concerned about the wealth gap in America,” Mr. Booker said Saturday, as he addressed his proposal to curb growing inequality with “baby bonds,” a government-run savings program for children.',
#     'copyright': 'Elizabeth Frantz for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/us/politics/06BOOKER/06BOOKER-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '“I’m really concerned about the wealth gap in America,” Mr. Booker said Saturday, as he addressed his proposal to curb growing inequality with “baby bonds,” a government-run savings program for children.',
#     'copyright': 'Elizabeth Frantz for The New York Times'}]},
#  {'slug_name': '06xp-childseparation',
#   'section': 'U.S.',
#   'subsection': '',
#   'title': 'U.S. Says It Could Take 2 Years to Identify Up to Thousands of Separated Immigrant Families',
#   'abstract': 'A judge had asked the government to locate children who were separated from their families before the Trump administration’s “zero-tolerance” policy was made public.',
#   'url': 'https://www.nytimes.com/2019/04/06/us/family-separation-trump-administration.html',
#   'byline': 'By JULIA JACOBS',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/us/06xp-childseparation-promo/06xp-childseparation-promo-thumbStandard-v2.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-06T19:49:04-04:00',
#   'created_date': '2019-04-06T19:32:03-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T19:30:33-04:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['Illegal Immigration',
#    'Immigration and Emigration',
#    'Immigration Detention'],
#   'org_facet': ['Customs and Border Protection (US)'],
#   'per_facet': '',
#   'geo_facet': '',
#   'related_urls': [{'suggested_link_text': 'Family Separation May Have Hit Thousands More Migrant Children Than Reported',
#     'url': 'https://www.nytimes.com/2019/01/17/us/family-separation-trump-administration-migrants.html'},
#    {'suggested_link_text': 'The Price Tag of Migrant Family Separation: $80 Million and Rising',
#     'url': 'https://www.nytimes.com/2018/11/20/us/family-separation-migrant-children.html'},
#    {'suggested_link_text': 'Homeland Security Chief Spars With Democrats Over Splitting Migrant Families',
#     'url': 'https://www.nytimes.com/2019/03/06/us/politics/kirstjen-nielsen-house-homeland-security-committee-testimony.html'}],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/us/06xp-childseparation-promo/06xp-childseparation-promo-thumbStandard-v2.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Migrants reunited with their children after four months apart waited for buses in July. A federal judge has said up to thousands more families may need to be located so they can be reunified.',
#     'copyright': 'Victor J. Blue for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/us/06xp-childseparation-promo/06xp-childseparation-promo-articleInline-v2.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Migrants reunited with their children after four months apart waited for buses in July. A federal judge has said up to thousands more families may need to be located so they can be reunified.',
#     'copyright': 'Victor J. Blue for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/us/06xp-childseparation-promo/06xp-childseparation-promo-mediumThreeByTwo210-v2.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Migrants reunited with their children after four months apart waited for buses in July. A federal judge has said up to thousands more families may need to be located so they can be reunified.',
#     'copyright': 'Victor J. Blue for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/us/06xp-childseparation-promo/06xp-childseparation-promo-mediumThreeByTwo440-v2.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Migrants reunited with their children after four months apart waited for buses in July. A federal judge has said up to thousands more families may need to be located so they can be reunified.',
#     'copyright': 'Victor J. Blue for The New York Times'}]},
#  {'slug_name': '06lpga',
#   'section': 'Sports',
#   'subsection': '',
#   'title': 'Big Week for Women’s Golf, but Perhaps Not for Progress',
#   'abstract': 'The Augusta National Women’s Amateur having a bigger stage and audience than the L.P.G.A.’s first major this week may not best serve the cause of equality.',
#   'url': 'https://www.nytimes.com/2019/04/06/sports/ana-inspiration-augusta-womens-amateur.html',
#   'byline': 'By KAREN CROUSE',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06lpga-1/06lpga-1-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-06T22:17:08-04:00',
#   'created_date': '2019-04-06T18:09:19-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T18:07:49-04:00',
#   'material_type_facet': 'News',
#   'kicker': 'On Golf',
#   'subheadline': None,
#   'des_facet': ['Golf'],
#   'org_facet': ['Augusta National Golf Club'],
#   'per_facet': ['McDonald, Ally (1992- )',
#    'Molinari, Francesco',
#    'Korda, Jessica'],
#   'geo_facet': '',
#   'related_urls': [{'suggested_link_text': 'ANA Inspiration: In-Kyung Kim Takes Lead 7 Years After a 1-Foot Miss',
#     'url': 'https://www.nytimes.com/2019/04/05/sports/lpga-ana-inspiration.html'},
#    {'suggested_link_text': 'Ally McDonald Takes First-Round Lead in ANA Inspiration',
#     'url': 'https://www.nytimes.com/2019/04/04/sports/lpga-ana-inspiration.html'}],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06lpga-1/06lpga-1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'After Ally McDonald took the first-round lead at the ANA Inspiration on Thursday, two men posted recollections on social media about her “whipping up” on them in the boys’ Mississippi state championship when she was in high school.',
#     'copyright': 'Matt Sullivan/Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06lpga-1/merlin_153113553_aa7f6bf1-d0d6-4f2b-887b-fa2241ad4762-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'After Ally McDonald took the first-round lead at the ANA Inspiration on Thursday, two men posted recollections on social media about her “whipping up” on them in the boys’ Mississippi state championship when she was in high school.',
#     'copyright': 'Matt Sullivan/Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06lpga-1/06lpga-1-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'After Ally McDonald took the first-round lead at the ANA Inspiration on Thursday, two men posted recollections on social media about her “whipping up” on them in the boys’ Mississippi state championship when she was in high school.',
#     'copyright': 'Matt Sullivan/Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06lpga-1/06lpga-1-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'After Ally McDonald took the first-round lead at the ANA Inspiration on Thursday, two men posted recollections on social media about her “whipping up” on them in the boys’ Mississippi state championship when she was in high school.',
#     'copyright': 'Matt Sullivan/Getty Images'}]},
#  {'slug_name': '07wordplay-help',
#   'section': 'Crosswords & Games',
#   'subsection': '',
#   'title': 'Help!',
#   'abstract': 'Peter A. Collins gets stranded on a desert island, but he’s resourceful.',
#   'url': 'https://www.nytimes.com/2019/04/06/crosswords/daily-puzzle-2019-04-07.html',
#   'byline': 'By CAITLIN LOVINGER',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/14/crosswords/14wordplay-lifeguards/14wordplay-lifeguards-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-06T18:01:06-04:00',
#   'created_date': '2019-04-06T17:41:32-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T17:40:01-04:00',
#   'material_type_facet': 'News',
#   'kicker': 'Wordplay',
#   'subheadline': None,
#   'des_facet': ['Crossword Puzzles'],
#   'org_facet': '',
#   'per_facet': '',
#   'geo_facet': '',
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/14/crosswords/14wordplay-lifeguards/14wordplay-lifeguards-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Members of the Ghana National Aquatic Rescue Unit warmed up before rescue and first aid training at Labadi Beach in Accra.',
#     'copyright': 'Cristina Aldehuela/Agence France-Presse — Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2019/04/14/crosswords/14wordplay-lifeguards/14wordplay-lifeguards-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Members of the Ghana National Aquatic Rescue Unit warmed up before rescue and first aid training at Labadi Beach in Accra.',
#     'copyright': 'Cristina Aldehuela/Agence France-Presse — Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2019/04/14/crosswords/14wordplay-lifeguards/14wordplay-lifeguards-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Members of the Ghana National Aquatic Rescue Unit warmed up before rescue and first aid training at Labadi Beach in Accra.',
#     'copyright': 'Cristina Aldehuela/Agence France-Presse — Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2019/04/14/crosswords/14wordplay-lifeguards/14wordplay-lifeguards-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Members of the Ghana National Aquatic Rescue Unit warmed up before rescue and first aid training at Labadi Beach in Accra.',
#     'copyright': 'Cristina Aldehuela/Agence France-Presse — Getty Images'}]},
#  {'slug_name': '06mets',
#   'section': 'Sports',
#   'subsection': '',
#   'title': 'Mets Rally in Eighth to Defeat the Nationals',
#   'abstract': 'The Mets hit five home runs, two by J.D. Davis, but the winning blow was Keon Broxton’s two-out single in the eighth inning, which broke a 5-5 tie.',
#   'url': 'https://www.nytimes.com/2019/04/06/sports/mets-nationals-keon-broxton-jd-davis.html',
#   'byline': 'By KEVIN ARMSTRONG',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/sports/06mets-web3/06mets-web3-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-06T18:44:18-04:00',
#   'created_date': '2019-04-06T17:23:22-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T17:21:52-04:00',
#   'material_type_facet': 'News',
#   'kicker': 'Mets 6, Nationals 5',
#   'subheadline': None,
#   'des_facet': ['Baseball'],
#   'org_facet': ['New York Mets', 'Washington Nationals'],
#   'per_facet': ['Broxton, Keon', 'Davis, J.D.'],
#   'geo_facet': '',
#   'related_urls': [{'suggested_link_text': 'The Science of Building a Better Pitcher',
#     'url': 'https://www.nytimes.com/2019/04/06/sports/mlb-pitching-coaches-wes-johnson.html'},
#    {'suggested_link_text': 'The Stat That Turns Mike Trout’s .312 Average Into .626',
#     'url': 'https://www.nytimes.com/2019/04/05/sports/baseball/secondary-average.html'},
#    {'suggested_link_text': 'Carlos Beltran Embraces a Role He Trained His Whole Career For',
#     'url': 'https://www.nytimes.com/2019/04/05/sports/carlos-beltran-yankees.html'}],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/sports/06mets-web3/06mets-web3-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'J.D. Davis, right, being greeted by Michael Conforto after hitting one of his two home runs for the Mets against the Nationals on Saturday.',
#     'copyright': 'Andy Marlin/USA Today Sports, via Reuters'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06mets-web3/merlin_153153162_61c56869-4b60-486d-9f48-4bab092ece0d-articleInline.jpg',
#     'format': 'Normal',
#     'height': 272,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'J.D. Davis, right, being greeted by Michael Conforto after hitting one of his two home runs for the Mets against the Nationals on Saturday.',
#     'copyright': 'Andy Marlin/USA Today Sports, via Reuters'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06mets-web3/06mets-web3-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'J.D. Davis, right, being greeted by Michael Conforto after hitting one of his two home runs for the Mets against the Nationals on Saturday.',
#     'copyright': 'Andy Marlin/USA Today Sports, via Reuters'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/sports/06mets-web3/06mets-web3-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'J.D. Davis, right, being greeted by Michael Conforto after hitting one of his two home runs for the Mets against the Nationals on Saturday.',
#     'copyright': 'Andy Marlin/USA Today Sports, via Reuters'}]},
#  {'slug_name': '06xp-phonescam',
#   'section': 'Business',
#   'subsection': '',
#   'title': 'Scheme to Swap Fake iPhones Adds Up to $900,000 Loss for Apple, Prosecutors Say',
#   'abstract': 'Two college students in Oregon are accused of tricking Apple into replacing nearly 1,500 counterfeit iPhones with genuine ones that were later sold.',
#   'url': 'https://www.nytimes.com/2019/04/06/business/counterfeit-apple-iphone-scam.html',
#   'byline': 'By RICK ROJAS',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2019/04/06/business/06xp-phonescam1/06xp-phonescan1-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-04-06T20:36:39-04:00',
#   'created_date': '2019-04-06T17:19:19-04:00',
#   'published_date': '2019-04-05T20:00:00-04:00',
#   'first_published_date': '2019-04-06T17:17:48-04:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['Counterfeit Merchandise', 'Guarantees and Warranties'],
#   'org_facet': ['iPhone', 'Apple Inc'],
#   'per_facet': ['Quan Jiang', 'Yangyang Zhou'],
#   'geo_facet': ['China'],
#   'related_urls': [{'suggested_link_text': 'He Tried to Bilk Google and Facebook Out of $100 Million With Fake Invoices',
#     'url': 'https://www.nytimes.com/2019/03/25/business/facebook-google-wire-fraud.html'},
#    {'suggested_link_text': 'Facebook’s Data Deals Are Under Criminal Investigation',
#     'url': 'https://www.nytimes.com/2019/03/13/technology/facebook-data-deals-investigation.html'},
#    {'suggested_link_text': 'Chinese and Iranian Hackers Renew Their Attacks on U.S. Companies',
#     'url': 'https://www.nytimes.com/2019/02/18/technology/hackers-chinese-iran-usa.html'},
#    {'suggested_link_text': 'That Virus Alert on Your Computer? Scammers in India May Be Behind It',
#     'url': 'https://www.nytimes.com/2018/11/28/technology/scams-india-call-center-raids.html'}],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/06/business/06xp-phonescam1/06xp-phonescan1-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The iPhone 7 at an Apple store in Beijing in 2016. Two college students are accused of costing Apple nearly $900,000 in losses with a counterfeiting scheme.',
#     'copyright': 'Thomas Peter/Reuters'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/business/06xp-phonescam1/06xp-phonescan1-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The iPhone 7 at an Apple store in Beijing in 2016. Two college students are accused of costing Apple nearly $900,000 in losses with a counterfeiting scheme.',
#     'copyright': 'Thomas Peter/Reuters'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/business/06xp-phonescam1/06xp-phonescan1-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The iPhone 7 at an Apple store in Beijing in 2016. Two college students are accused of costing Apple nearly $900,000 in losses with a counterfeiting scheme.',
#     'copyright': 'Thomas Peter/Reuters'},
#    {'url': 'https://static01.nyt.com/images/2019/04/06/business/06xp-phonescam1/06xp-phonescan1-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The iPhone 7 at an Apple store in Beijing in 2016. Two college students are accused of costing Apple nearly $900,000 in losses with a counterfeiting scheme.',
#     'copyright': 'Thomas Peter/Reuters'}]}]

# %%
#translates json data into a Pandas dataframe
nyt_df = pd.DataFrame(nyt_res, columns=['slug_name','section','subsection','title', 'abstract', 'url', 'byline',
                                        'thumbnail_standard','item_type', 'source', 'updated_date', 'created_date',
                                        'published_date', 'first_published_date', 'material_type_facet', 'kicker', 
                                        'subheadline'])
nyt_df
# Out:
#                       slug_name             section subsection  \
# 0                      07Parker             Fashion   Weddings
# 1                        07BRAS             Fashion   Weddings
# 2                       07HATCH             Fashion   Weddings
# 3                       07MARRA             Fashion   Weddings
# 4                      07Toback             Fashion   Weddings
# 5                         06nhl              Sports
# 6                  06ncaa-game2              Sports
# 7                 07corrections         Corrections
# 8                  06santaanita              Sports
# 9                    07quoteweb       Today’s Paper
# 10  06readers-fake-uber-drivers       Reader Center
# 11                 06ncaa-game1              Sports
# 12                   06dc-trump                U.S.   Politics
# 13                        06nba              Sports
# 14                     06booker                U.S.   Politics
# 15         06xp-childseparation                U.S.
# 16                       06lpga              Sports
# 17              07wordplay-help  Crosswords & Games
# 18                       06mets              Sports
# 19               06xp-phonescam            Business
#
#                                                 title  \
# 0                          Arielle Parker, Seth Kisch
# 1                      Roxanne Bras, Stephen Petraeus
# 2                         Erin Hatch, Benjamin Thomas
# 3                     Caroline Marra, Benjamin Hemani
# 4                         Jessie Toback, Noah Rothman
# 5   Islanders Blank Capitals and Head to Playoffs ...
# 6   N.C.A.A. Final Four: Texas Tech Upsets Michiga...
# 7                          Corrections: April 7, 2019
# 8   At Santa Anita, at Least for One Day, the Raci...
# 9   Quotation of the Day: Fungus Immune to Drugs Q...
# 10  ‘There Are Bad Actors Out There’: Readers Disc...
# 11  N.C.A.A. Final Four: A Shot, a Whistle and a F...
# 12  Pushing for Tighter Borders, President Asks Je...
# 13  Nets Inch Up in East Playoff Race With Win Aga...
# 14  Cory Booker Campaigns on Baby Bonds Program to...
# 15  U.S. Says It Could Take 2 Years to Identify Up...
# 16  Big Week for Women’s Golf, but Perhaps Not for...
# 17                                              Help!
# 18       Mets Rally in Eighth to Defeat the Nationals
# 19  Scheme to Swap Fake iPhones Adds Up to $900,00...
#
#                                              abstract  \
# 0     The couple met in 2015 on the dating app Hinge.
# 1   The couple met as sophomores in college, in 20...
# 2   The bride is the press secretary for the House...
# 3   The couple met in 2011 during the first day of...
# 4   The couple were introduced by the bride’s fath...
# 5   Valtteri Filppula scored twice in his return f...
# 6   Texas Tech’s visit to its first Final Four wil...
# 7   Corrections appearing in print on Sunday, Apri...
# 8   Bob Baffert put two horses into the Kentucky D...
# 9     Quotation of the Day for Sunday, April 7, 2019.
# 10  Times readers share some close calls and offer...
# 11  A late foul call, and the resulting three free...
# 12  A speech underlined how many conservative Jewi...
# 13  Eight players scored in double figures for the...
# 14  Mr. Booker made a detailed case for an economi...
# 15  A judge had asked the government to locate chi...
# 16  The Augusta National Women’s Amateur having a ...
# 17  Peter A. Collins gets stranded on a desert isl...
# 18  The Mets hit five home runs, two by J.D. Davis...
# 19  Two college students in Oregon are accused of ...
#
#                                                   url  \
# 0   https://www.nytimes.com/2019/04/07/fashion/wed...
# 1   https://www.nytimes.com/2019/04/07/fashion/wed...
# 2   https://www.nytimes.com/2019/04/07/fashion/wed...
# 3   https://www.nytimes.com/2019/04/07/fashion/wed...
# 4   https://www.nytimes.com/2019/04/07/fashion/wed...
# 5   https://www.nytimes.com/2019/04/06/sports/nhl-...
# 6   https://www.nytimes.com/2019/04/06/sports/ncaa...
# 7   https://www.nytimes.com/2019/04/06/pageoneplus...
# 8   https://www.nytimes.com/2019/04/06/sports/sant...
# 9   https://www.nytimes.com/2019/04/06/todayspaper...
# 10  https://www.nytimes.com/2019/04/06/reader-cent...
# 11  https://www.nytimes.com/2019/04/06/sports/ncaa...
# 12  https://www.nytimes.com/2019/04/06/us/politics...
# 13  https://www.nytimes.com/2019/04/06/sports/nba-...
# 14  https://www.nytimes.com/2019/04/06/us/politics...
# 15  https://www.nytimes.com/2019/04/06/us/family-s...
# 16  https://www.nytimes.com/2019/04/06/sports/ana-...
# 17  https://www.nytimes.com/2019/04/06/crosswords/...
# 18  https://www.nytimes.com/2019/04/06/sports/mets...
# 19  https://www.nytimes.com/2019/04/06/business/co...
#
#                      byline  \
# 0
# 1
# 2
# 3
# 4
# 5   By THE ASSOCIATED PRESS
# 6             By BILLY WITZ
# 7
# 8           By MIKE TIERNEY
# 9
# 10            By LELA MOORE
# 11            By MARC TRACY
# 12        By EMILY COCHRANE
# 13  By THE ASSOCIATED PRESS
# 14       By NICK CORASANITI
# 15          By JULIA JACOBS
# 16          By KAREN CROUSE
# 17      By CAITLIN LOVINGER
# 18       By KEVIN ARMSTRONG
# 19            By RICK ROJAS
#
#                                    thumbnail_standard item_type  \
# 0   https://static01.nyt.com/images/2019/04/07/fas...   Article
# 1   https://static01.nyt.com/images/2019/04/07/fas...   Article
# 2   https://static01.nyt.com/images/2019/04/07/fas...   Article
# 3   https://static01.nyt.com/images/2019/04/07/fas...   Article
# 4   https://static01.nyt.com/images/2019/04/07/fas...   Article
# 5   https://static01.nyt.com/images/2019/04/07/spo...   Article
# 6   https://static01.nyt.com/images/2019/04/06/spo...   Article
# 7                                                       Article
# 8   https://static01.nyt.com/images/2019/04/06/spo...   Article
# 9                                                       Article
# 10  https://static01.nyt.com/images/2019/04/05/rea...   Article
# 11  https://static01.nyt.com/images/2019/04/06/spo...   Article
# 12  https://static01.nyt.com/images/2019/04/06/spo...   Article
# 13  https://static01.nyt.com/images/2019/04/06/spo...   Article
# 14  https://static01.nyt.com/images/2019/04/06/us/...   Article
# 15  https://static01.nyt.com/images/2019/04/06/us/...   Article
# 16  https://static01.nyt.com/images/2019/04/06/spo...   Article
# 17  https://static01.nyt.com/images/2019/04/14/cro...   Article
# 18  https://static01.nyt.com/images/2019/04/06/spo...   Article
# 19  https://static01.nyt.com/images/2019/04/06/bus...   Article
#
#                 source               updated_date               created_date  \
# 0   The New York Times  2019-04-07T00:01:31-04:00  2019-04-07T00:01:31-04:00
# 1   The New York Times  2019-04-07T00:01:31-04:00  2019-04-07T00:01:31-04:00
# 2   The New York Times  2019-04-07T00:01:31-04:00  2019-04-07T00:01:31-04:00
# 3   The New York Times  2019-04-07T00:01:31-04:00  2019-04-07T00:01:31-04:00
# 4   The New York Times  2019-04-07T00:01:31-04:00  2019-04-07T00:01:31-04:00
# 5   The New York Times  2019-04-07T00:07:52-04:00  2019-04-06T23:11:18-04:00
# 6   The New York Times  2019-04-07T00:06:13-04:00  2019-04-06T23:09:52-04:00
# 7   The New York Times  2019-04-06T23:44:00-04:00  2019-04-06T22:53:06-04:00
# 8   The New York Times  2019-04-06T22:36:28-04:00  2019-04-06T22:36:28-04:00
# 9   The New York Times  2019-04-06T22:30:20-04:00  2019-04-06T22:05:59-04:00
# 10  The New York Times  2019-04-06T20:20:25-04:00  2019-04-06T20:20:25-04:00
# 11  The New York Times  2019-04-06T23:44:21-04:00  2019-04-06T20:16:31-04:00
# 12  The New York Times  2019-04-06T23:33:22-04:00  2019-04-06T20:15:57-04:00
# 13  The New York Times  2019-04-06T22:29:33-04:00  2019-04-06T20:03:25-04:00
# 14  The New York Times  2019-04-06T23:15:04-04:00  2019-04-06T19:50:48-04:00
# 15  The New York Times  2019-04-06T19:49:04-04:00  2019-04-06T19:32:03-04:00
# 16  The New York Times  2019-04-06T22:17:08-04:00  2019-04-06T18:09:19-04:00
# 17  The New York Times  2019-04-06T18:01:06-04:00  2019-04-06T17:41:32-04:00
# 18  The New York Times  2019-04-06T18:44:18-04:00  2019-04-06T17:23:22-04:00
# 19  The New York Times  2019-04-06T20:36:39-04:00  2019-04-06T17:19:19-04:00
#
#                published_date       first_published_date material_type_facet  \
# 0   2019-04-06T20:00:00-04:00  2019-04-07T00:00:00-04:00                News
# 1   2019-04-06T20:00:00-04:00  2019-04-07T00:00:00-04:00                News
# 2   2019-04-06T20:00:00-04:00  2019-04-07T00:00:00-04:00                News
# 3   2019-04-06T20:00:00-04:00  2019-04-07T00:00:00-04:00                News
# 4   2019-04-06T20:00:00-04:00  2019-04-07T00:00:00-04:00                News
# 5   2019-04-05T20:00:00-04:00  2019-04-06T23:09:47-04:00                News
# 6   2019-04-05T20:00:00-04:00  2019-04-06T23:08:21-04:00                News
# 7   2019-04-05T20:00:00-04:00  2019-04-06T22:51:35-04:00          Correction
# 8   2019-04-05T20:00:00-04:00  2019-04-06T22:34:57-04:00                News
# 9   2019-04-05T20:00:00-04:00  2019-04-06T22:04:29-04:00               Quote
# 10  2019-04-05T20:00:00-04:00  2019-04-06T20:18:54-04:00                News
# 11  2019-04-05T20:00:00-04:00  2019-04-06T20:15:01-04:00                News
# 12  2019-04-05T20:00:00-04:00  2019-04-06T20:14:27-04:00                News
# 13  2019-04-05T20:00:00-04:00  2019-04-06T20:01:55-04:00                News
# 14  2019-04-05T20:00:00-04:00  2019-04-06T19:49:17-04:00                News
# 15  2019-04-05T20:00:00-04:00  2019-04-06T19:30:33-04:00                News
# 16  2019-04-05T20:00:00-04:00  2019-04-06T18:07:49-04:00                News
# 17  2019-04-05T20:00:00-04:00  2019-04-06T17:40:01-04:00                News
# 18  2019-04-05T20:00:00-04:00  2019-04-06T17:21:52-04:00                News
# 19  2019-04-05T20:00:00-04:00  2019-04-06T17:17:48-04:00                News
#
#                                  kicker subheadline
# 0                                  None        None
# 1                                  None        None
# 2                                  None        None
# 3                                  None        None
# 4                                  None        None
# 5                        N.H.L. Roundup        None
# 6                                  None        None
# 7                                  None        None
# 8                                  None        None
# 9                                  None        None
# 10                                 None        None
# 11  Virginia 63, Auburn 62 | Final Four        None
# 12                                 None        None
# 13                  Nets 133, Bucks 128        None
# 14                                 None        None
# 15                                 None        None
# 16                              On Golf        None
# 17                             Wordplay        None
# 18                  Mets 6, Nationals 5        None
# 19                                 None        None
